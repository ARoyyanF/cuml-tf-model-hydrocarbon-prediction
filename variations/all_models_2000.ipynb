# %% [markdown]
# # Retrieve data

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import time
start_notebook = time.time()

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
import numpy as np

# %%
# Option to generate mock data
generate_mock_data = True # Set to True to generate mock data
max_mock_depth_ft = 2000 # Define maximum depth for mock data

# %%
well_name = "LLB-10"
if not generate_mock_data:
  data = pd.read_csv(f"/content/drive/MyDrive/riset-fttm-gdrive/cuml-tf-model-hydrocarbon-prediction/data/interpreted/interpreted_{well_name}.csv", sep=',')

# %%
if generate_mock_data:
    print(f"Generating mock data up to {max_mock_depth_ft} ft for well {well_name}...")
    mock_depth_step = 0.5
    mock_dept_values = np.arange(0, max_mock_depth_ft, mock_depth_step)
    num_mock_rows = len(mock_dept_values)

    mock_data_dict = {'DEPT': mock_dept_values}

    feature_cols_for_mock = ['CALI','DRHO','GR','MR','NPHI_corr','PEF','RHOB_CORR','ROP']

    for col in feature_cols_for_mock:
        mock_data_dict[col] = np.random.rand(num_mock_rows) * 100

    mock_data_dict['hydrocarbon_formation_class'] = np.random.randint(0, 2, num_mock_rows)

    data = pd.DataFrame(mock_data_dict)

    print(f"Mock data generated for well {well_name} with {num_mock_rows} rows and columns: {list(data.columns)}.")
    print("Mock data head:")
    print(data.head())
# Out:
# Generating mock data up to 2000 ft for well LLB-10...
# Mock data generated for well LLB-10 with 4000 rows and columns: ['DEPT', 'CALI', 'DRHO', 'GR', 'MR', 'NPHI_corr', 'PEF', 'RHOB_CORR', 'ROP', 'hydrocarbon_formation_class'].
# Mock data head:
#    DEPT       CALI       DRHO         GR         MR  NPHI_corr        PEF  \
# 0   0.0  13.156173  24.212938  99.270183  29.786569  93.945542  57.228274
# 1   0.5  83.924623  29.264532  68.936129  66.596715  43.410529  43.919074
# 2   1.0  10.225861   7.634280  25.500884  78.619175  61.916237  49.375863
# 3   1.5  35.388677  56.721644  55.943448  91.834707  80.496584  73.490852
# 4   2.0   9.846118  91.354466  25.975949   1.009307  41.301262   3.873288
#
#    RHOB_CORR        ROP  hydrocarbon_formation_class
# 0  53.150100  17.688094                            0
# 1  12.339948   5.173911                            0
# 2  28.531215  21.775875                            1
# 3  19.957293  76.522407                            0
# 4  18.762791  69.481797                            1

# %%
df=data[['CALI','DRHO','GR','MR','NPHI_corr','PEF','RHOB_CORR','ROP']]
df
# Out:
#            CALI       DRHO         GR         MR  NPHI_corr        PEF  \
# 0     13.156173  24.212938  99.270183  29.786569  93.945542  57.228274
# 1     83.924623  29.264532  68.936129  66.596715  43.410529  43.919074
# 2     10.225861   7.634280  25.500884  78.619175  61.916237  49.375863
# 3     35.388677  56.721644  55.943448  91.834707  80.496584  73.490852
# 4      9.846118  91.354466  25.975949   1.009307  41.301262   3.873288
# ...         ...        ...        ...        ...        ...        ...
# 3995  12.377180  43.242198  58.788386  31.409569  21.340701  67.509056
# 3996  36.379111  51.866771  42.653728  16.345391  81.672739  52.680491
# 3997  10.797680  23.208006  81.487734  53.746556   5.248253  34.917443
# 3998  89.150731  95.910103  58.967343  41.636342  83.839448  72.962274
# 3999  97.400102  86.760006  35.702621  38.007872   1.440259  33.731008
#
#       RHOB_CORR        ROP
# 0     53.150100  17.688094
# 1     12.339948   5.173911
# 2     28.531215  21.775875
# 3     19.957293  76.522407
# 4     18.762791  69.481797
# ...         ...        ...
# 3995  35.846903  48.418302
# 3996  28.438116  99.885668
# 3997  33.241933  29.563356
# 3998  10.979553  42.353518
# 3999  93.209433  72.617746
#
# [4000 rows x 8 columns]

# %% [markdown]
# # Data Preparation

# %% [markdown]
# ## Train/Test Splitting

# %%
# Misalkan 'data' adalah DataFrame Anda dan 'df' adalah fitur yang telah Anda ekstrak
X = df  # Fitur
y = data['hydrocarbon_formation_class']  # Label

# Split data menjadi training dan testing set
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, stratify=y, random_state=42)

# %%
X_train.describe()
# Out:
#               CALI         DRHO           GR           MR    NPHI_corr  \
# count  3200.000000  3200.000000  3200.000000  3200.000000  3200.000000
# mean     50.672307    49.185718    49.756072    51.000384    50.766464
# std      28.725595    29.221800    28.846461    28.546017    28.774914
# min       0.022665     0.011628     0.017555     0.012765     0.080148
# 25%      26.697170    23.618973    24.175798    26.430957    25.849694
# 50%      51.296776    48.404041    50.000755    50.766493    51.794074
# 75%      75.177244    75.019247    74.573844    75.611052    75.154228
# max      99.935279    99.983052    99.999715    99.982861    99.966638
#
#                PEF    RHOB_CORR          ROP
# count  3200.000000  3200.000000  3200.000000
# mean     49.743247    49.727332    49.997025
# std      28.554344    28.746433    29.532821
# min       0.007791     0.068630     0.002281
# 25%      24.745851    25.209585    23.463101
# 50%      49.662260    49.915131    49.978672
# 75%      73.669048    74.401917    76.449276
# max      99.975914    99.996557    99.990173

# %% [markdown]
# ## Apply Quantile Transformation

# %%
from sklearn.preprocessing import QuantileTransformer
def transform_quantile(X_train, X_test, X):
    qt_transformer = QuantileTransformer(output_distribution='normal')
    dfs = [X_train, X_test, X]
    qt_dfs = [None,None,None]
    for i, df in enumerate(dfs):
        if (i == 0): #only perform fit_transform on training data
            qt_dfs[i] = pd.DataFrame(qt_transformer.fit_transform(df))
        else:
            qt_dfs[i] = pd.DataFrame(qt_transformer.transform(df))
        qt_dfs[i].columns = df.columns.values
        qt_dfs[i].index = df.index.values
    return qt_dfs[0], qt_dfs[1], qt_dfs[2] #X_train, X_test, X

# %%
X_train, X_test, X = transform_quantile(X_train, X_test, X)

# %% [markdown]
# ## Feature Scaling
#
# karena menggunakan Quatile transformation dengan output gaussian, masing masing kolom secara otomatis ditransformasi ke distribusi normal baku, atau distribusi normal dengan rataan nol dan standar deviasi 1, oleh karena itu tidak diperlukan tambahan scaling.

# %%
X_train.describe()
# Out:
#               CALI         DRHO           GR           MR    NPHI_corr  \
# count  3200.000000  3200.000000  3200.000000  3200.000000  3200.000000
# mean     -0.000045    -0.000125     0.000146    -0.000066     0.000055
# std       1.007258     1.005787     1.006120     1.005429     1.006240
# min      -5.199338    -5.199338    -5.199338    -5.199338    -5.199338
# 25%      -0.674276    -0.674426    -0.673833    -0.674182    -0.675014
# 50%       0.000606     0.000147     0.000116    -0.000800     0.000669
# 75%       0.675908     0.675239     0.674162     0.674351     0.674102
# max       5.199338     5.199338     5.199338     5.199338     5.199338
#
#                PEF    RHOB_CORR          ROP
# count  3200.000000  3200.000000  3200.000000
# mean     -0.000121    -0.000068     0.000348
# std       1.006665     1.006148     1.007077
# min      -5.199338    -5.199338    -5.199338
# 25%      -0.675035    -0.676089    -0.674305
# 50%       0.000536     0.000625     0.000291
# 75%       0.674389     0.674031     0.675145
# max       5.199338     5.199338     5.199338

# %% [markdown]
# # Training setup

# %%
import time
import numpy as np
from sklearn.model_selection import GridSearchCV


sk_train_accuracy={}
sk_test_accuracy={}

cu_train_accuracy={}
cu_test_accuracy={}

sk_crossValidation_accuracy={}
cu_crossValidation_accuracy={}

sk_models = {} #sklearn models
cu_models = {} #cuml models

sk_times = {}
cu_times = {}

sk_pred = {}
cu_pred = {}

sk_pred_times = {}
cu_pred_times = {}

# %% [markdown]
# # Models

# %% [markdown]
# ## SVM

# %%
model_name = "SVM"

# %%
from sklearn.svm import SVC as SklearnSVC
# Attempt to import cuML's SVC
try:
    from cuml.svm import SVC as cuMLSVC
    has_cuml = True
except ImportError:
    has_cuml = False

# %%
# Parameter grid for both models
param_grid = {
    'C': [0.1, 1, 10],
    'gamma': ['scale', 'auto']
}

# 1) scikit-learn SVM with GridSearchCV
sk_models[model_name] = GridSearchCV(
    estimator=SklearnSVC(kernel='rbf'),
    param_grid=param_grid,
    cv=5,
    verbose=3,
    n_jobs=-1
)

time_start = time.time()
sk_models[model_name].fit(X_train, y_train)
time_end = time.time()
sk_times[model_name] = time_end - time_start

# 2) cuML SVM with the same GridSearchCV
if has_cuml:
    cu_models[model_name] = GridSearchCV(
        estimator=cuMLSVC(kernel='rbf'),
        param_grid=param_grid,
        cv=5,
        verbose=3,
        # Note: cuML estimator runs on GPU; this grid search runs on CPU orchestrating GPU calls
        n_jobs=1  # avoid multiprocessing issues with GPU
    )

    time_start = time.time()
    cu_models[model_name].fit(X_train, y_train)
    time_end = time.time()
    cu_times[model_name] = time_end - time_start
    print(f"cuml GridSearchCV training time ({model_name}) : {cu_times[model_name]:.2f} seconds")
    print(f"cuml Best parameters ({model_name}): {cu_models[model_name].best_params_}")
else:
    print("cuML is not installed or GPU not available. Please install RAPIDS cuML to run this benchmark.")

print(f"scikit-learn GridSearchCV training time ({model_name}) : {sk_times[model_name]:.2f} seconds")
print(f"scikit-learn Best parameters ({model_name}): {sk_models[model_name].best_params_}")
# Out:
# Fitting 5 folds for each of 6 candidates, totalling 30 fits
# Fitting 5 folds for each of 6 candidates, totalling 30 fits
# [CV 1/5] END ................C=0.1, gamma=scale;, score=0.512 total time=   4.0s
# [CV 2/5] END ................C=0.1, gamma=scale;, score=0.511 total time=   0.1s
# [CV 3/5] END ................C=0.1, gamma=scale;, score=0.508 total time=   0.1s
# [CV 4/5] END ................C=0.1, gamma=scale;, score=0.509 total time=   0.1s
# [CV 5/5] END ................C=0.1, gamma=scale;, score=0.517 total time=   0.1s
# [CV 1/5] END .................C=0.1, gamma=auto;, score=0.512 total time=   0.1s
# [CV 2/5] END .................C=0.1, gamma=auto;, score=0.511 total time=   0.0s
# [CV 3/5] END .................C=0.1, gamma=auto;, score=0.509 total time=   0.1s
# [CV 4/5] END .................C=0.1, gamma=auto;, score=0.509 total time=   0.1s
# [CV 5/5] END .................C=0.1, gamma=auto;, score=0.517 total time=   0.1s
# [CV 1/5] END ..................C=1, gamma=scale;, score=0.516 total time=   0.1s
# [CV 2/5] END ..................C=1, gamma=scale;, score=0.511 total time=   0.1s
# [CV 3/5] END ..................C=1, gamma=scale;, score=0.491 total time=   0.1s
# [CV 4/5] END ..................C=1, gamma=scale;, score=0.508 total time=   0.1s
# [CV 5/5] END ..................C=1, gamma=scale;, score=0.500 total time=   0.1s
# [CV 1/5] END ...................C=1, gamma=auto;, score=0.517 total time=   0.1s
# [CV 2/5] END ...................C=1, gamma=auto;, score=0.512 total time=   0.1s
# [CV 3/5] END ...................C=1, gamma=auto;, score=0.489 total time=   0.1s
# [CV 4/5] END ...................C=1, gamma=auto;, score=0.508 total time=   0.1s
# [CV 5/5] END ...................C=1, gamma=auto;, score=0.500 total time=   0.1s
# [CV 1/5] END .................C=10, gamma=scale;, score=0.544 total time=   0.4s
# [CV 2/5] END .................C=10, gamma=scale;, score=0.500 total time=   0.4s
# [CV 3/5] END .................C=10, gamma=scale;, score=0.492 total time=   0.4s
# [CV 4/5] END .................C=10, gamma=scale;, score=0.525 total time=   0.4s
# [CV 5/5] END .................C=10, gamma=scale;, score=0.527 total time=   0.4s
# [CV 1/5] END ..................C=10, gamma=auto;, score=0.548 total time=   0.4s
# [CV 2/5] END ..................C=10, gamma=auto;, score=0.497 total time=   0.4s
# [CV 3/5] END ..................C=10, gamma=auto;, score=0.492 total time=   0.4s
# [CV 4/5] END ..................C=10, gamma=auto;, score=0.522 total time=   0.4s
# [CV 5/5] END ..................C=10, gamma=auto;, score=0.525 total time=   0.4s
# cuml GridSearchCV training time (SVM) : 9.67 seconds
# cuml Best parameters (SVM): {'C': 10, 'gamma': 'scale'}
# scikit-learn GridSearchCV training time (SVM) : 13.49 seconds
# scikit-learn Best parameters (SVM): {'C': 10, 'gamma': 'scale'}

# %% [markdown]
# ## K-Nearest Neighbors

# %%
model_name = "KNN"

# %%
from sklearn.neighbors import KNeighborsClassifier as SklearnKNeighborsClassifier
# Attempt to import cuML's KNeighborsClassifier
try:
    from cuml.neighbors import KNeighborsClassifier as cuMLKNeighborsClassifier
    # has_cuml is already defined from SVM section, assuming if SVM cuml is available, KNN cuml is too.
except ImportError:
    # If cuML was previously found but KNN specific part is missing, update has_cuml for KNN context if necessary
    # For simplicity, we rely on the initial has_cuml check. If specific components are missing,
    # the cuML KNN block will be skipped or error out, which is acceptable.
    # A more robust check could be:
    # try: from cuml.svm import SVC as cuMLSVC; has_cuml_svm = True except: has_cuml_svm = False
    # try: from cuml.neighbors import KNeighborsClassifier as cuMLKNeighborsClassifier; has_cuml_knn = True except: has_cuml_knn = False
    pass # Rely on global has_cuml

# %%
# Parameter grid for KNN
param_grid_knn = {
    'n_neighbors': [3, 5, 7, 9, 11],
    'weights': ['uniform', 'distance'],
    'metric': ['euclidean', 'manhattan']
}

# 1) scikit-learn KNN with GridSearchCV
sk_models[model_name] = GridSearchCV(
    estimator=SklearnKNeighborsClassifier(),
    param_grid=param_grid_knn,
    cv=5,
    verbose=3,
    n_jobs=-1
)

time_start = time.time()
sk_models[model_name].fit(X_train, y_train)
time_end = time.time()
sk_times[model_name] = time_end - time_start

# 2) cuML KNN with the same GridSearchCV (adapted for cuML)
if has_cuml:
    try:
        # Ensure cuMLKNeighborsClassifier was imported
        cuMLKNeighborsClassifier

        cu_models[model_name] = GridSearchCV(
            estimator=cuMLKNeighborsClassifier(), # cuML KNN
            param_grid=param_grid_knn, # Using the same grid, ensure params are compatible
            cv=5,
            verbose=3,
            n_jobs=1 # Potentially can be >1 if managed carefully, but 1 is safer for GPU resources with GridSearchCV
        )

        time_start = time.time()
        # cuML's KNN might prefer numpy arrays or cuDF dataframes
        # X_train and y_train are pandas, which cuml usually handles.
        # If issues arise, convert: X_train_cu = X_train.to_numpy(), y_train_cu = y_train.to_numpy()
        cu_models[model_name].fit(X_train, y_train)
        time_end = time.time()
        cu_times[model_name] = time_end - time_start
        print(f"cuml GridSearchCV training time ({model_name}) : {cu_times[model_name]:.2f} seconds")
        print(f"cuml Best parameters ({model_name}): {cu_models[model_name].best_params_}")
    except NameError: # handles if cuMLKNeighborsClassifier was not imported
        print(f"cuML KNeighborsClassifier not available. Skipping cuML {model_name} training.")
    except Exception as e:
        print(f"An error occurred during cuML {model_name} training: {e}")
        # Optionally, remove the model key if setup failed partway
        if model_name in cu_models: del cu_models[model_name]
        if model_name in cu_times: del cu_times[model_name]

else:
    print(f"cuML is not installed or GPU not available. Skipping cuML {model_name} benchmark.")

print(f"scikit-learn GridSearchCV training time ({model_name}) : {sk_times[model_name]:.2f} seconds")
print(f"scikit-learn Best parameters ({model_name}): {sk_models[model_name].best_params_}")
# Out:
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# [2025-05-14 15:42:34.460] [CUML] [info] Unused keyword parameter: n_jobs during cuML estimator initialization
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# [2025-05-14 15:42:34.462] [CUML] [info] Unused keyword parameter: n_jobs during cuML estimator initialization
# [CV 1/5] END metric=euclidean, n_neighbors=3, weights=uniform;, score=0.517 total time=   1.3s
# [2025-05-14 15:42:35.724] [CUML] [info] Unused keyword parameter: n_jobs during cuML estimator initialization
# [CV 2/5] END metric=euclidean, n_neighbors=3, weights=uniform;, score=0.475 total time=   0.0s
# [2025-05-14 15:42:35.734] [CUML] [info] Unused keyword parameter: n_jobs during cuML estimator initialization
# [CV 3/5] END metric=euclidean, n_neighbors=3, weights=uniform;, score=0.514 total time=   0.0s
# [2025-05-14 15:42:35.744] [CUML] [info] Unused keyword parameter: n_jobs during cuML estimator initialization
# [CV 4/5] END metric=euclidean, n_neighbors=3, weights=uniform;, score=0.508 total time=   0.0s
# [2025-05-14 15:42:35.752] [CUML] [info] Unused keyword parameter: n_jobs during cuML estimator initialization
# [CV 5/5] END metric=euclidean, n_neighbors=3, weights=uniform;, score=0.520 total time=   0.0s
# [2025-05-14 15:42:35.761] [CUML] [info] Unused keyword parameter: n_jobs during cuML estimator initialization
# [CV 1/5] END metric=euclidean, n_neighbors=3, weights=distance;, score=0.517 total time=   0.0s
# [2025-05-14 15:42:35.769] [CUML] [info] Unused keyword parameter: n_jobs during cuML estimator initialization
# [CV 2/5] END metric=euclidean, n_neighbors=3, weights=distance;, score=0.475 total time=   0.0s
# [2025-05-14 15:42:35.777] [CUML] [info] Unused keyword parameter: n_jobs during cuML estimator initialization
# [CV 3/5] END metric=euclidean, n_neighbors=3, weights=distance;, score=0.514 total time=   0.0s
# [2025-05-14 15:42:35.786] [CUML] [info] Unused keyword parameter: n_jobs during cuML estimator initialization
# [CV 4/5] END metric=euclidean, n_neighbors=3, weights=distance;, score=0.508 total time=   0.0s
# [2025-05-14 15:42:35.795] [CUML] [info] Unused keyword parameter: n_jobs during cuML estimator initialization
# [CV 5/5] END metric=euclidean, n_neighbors=3, weights=distance;, score=0.520 total time=   0.0s
# [2025-05-14 15:42:35.804] [CUML] [info] Unused keyword parameter: n_jobs during cuML estimator initialization
# [CV 1/5] END metric=euclidean, n_neighbors=5, weights=uniform;, score=0.505 total time=   0.0s
# [2025-05-14 15:42:35.812] [CUML] [info] Unused keyword parameter: n_jobs during cuML estimator initialization
# [CV 2/5] END metric=euclidean, n_neighbors=5, weights=uniform;, score=0.450 total time=   0.0s
# [2025-05-14 15:42:35.820] [CUML] [info] Unused keyword parameter: n_jobs during cuML estimator initialization
# [CV 3/5] END metric=euclidean, n_neighbors=5, weights=uniform;, score=0.500 total time=   0.0s
# [2025-05-14 15:42:35.830] [CUML] [info] Unused keyword parameter: n_jobs during cuML estimator initialization
# [CV 4/5] END metric=euclidean, n_neighbors=5, weights=uniform;, score=0.505 total time=   0.0s
# [2025-05-14 15:42:35.843] [CUML] [info] Unused keyword parameter: n_jobs during cuML estimator initialization
# [CV 5/5] END metric=euclidean, n_neighbors=5, weights=uniform;, score=0.500 total time=   0.0s
# [2025-05-14 15:42:35.856] [CUML] [info] Unused keyword parameter: n_jobs during cuML estimator initialization
# [CV 1/5] END metric=euclidean, n_neighbors=5, weights=distance;, score=0.505 total time=   0.0s
# [2025-05-14 15:42:35.867] [CUML] [info] Unused keyword parameter: n_jobs during cuML estimator initialization
# [CV 2/5] END metric=euclidean, n_neighbors=5, weights=distance;, score=0.450 total time=   0.0s
# [2025-05-14 15:42:35.876] [CUML] [info] Unused keyword parameter: n_jobs during cuML estimator initialization
# [CV 3/5] END metric=euclidean, n_neighbors=5, weights=distance;, score=0.500 total time=   0.0s
# [2025-05-14 15:42:35.885] [CUML] [info] Unused keyword parameter: n_jobs during cuML estimator initialization
# [CV 4/5] END metric=euclidean, n_neighbors=5, weights=distance;, score=0.505 total time=   0.0s
# [2025-05-14 15:42:35.894] [CUML] [info] Unused keyword parameter: n_jobs during cuML estimator initialization
# [CV 5/5] END metric=euclidean, n_neighbors=5, weights=distance;, score=0.500 total time=   0.0s
# [2025-05-14 15:42:35.902] [CUML] [info] Unused keyword parameter: n_jobs during cuML estimator initialization
# [CV 1/5] END metric=euclidean, n_neighbors=7, weights=uniform;, score=0.495 total time=   0.0s
# [2025-05-14 15:42:35.911] [CUML] [info] Unused keyword parameter: n_jobs during cuML estimator initialization
# [CV 2/5] END metric=euclidean, n_neighbors=7, weights=uniform;, score=0.484 total time=   0.0s
# [2025-05-14 15:42:35.921] [CUML] [info] Unused keyword parameter: n_jobs during cuML estimator initialization
# [CV 3/5] END metric=euclidean, n_neighbors=7, weights=uniform;, score=0.505 total time=   0.0s
# [2025-05-14 15:42:35.932] [CUML] [info] Unused keyword parameter: n_jobs during cuML estimator initialization
# [CV 4/5] END metric=euclidean, n_neighbors=7, weights=uniform;, score=0.528 total time=   0.0s
# [2025-05-14 15:42:35.942] [CUML] [info] Unused keyword parameter: n_jobs during cuML estimator initialization
# [CV 5/5] END metric=euclidean, n_neighbors=7, weights=uniform;, score=0.536 total time=   0.0s
# [2025-05-14 15:42:35.950] [CUML] [info] Unused keyword parameter: n_jobs during cuML estimator initialization
# [CV 1/5] END metric=euclidean, n_neighbors=7, weights=distance;, score=0.495 total time=   0.0s
# [2025-05-14 15:42:35.959] [CUML] [info] Unused keyword parameter: n_jobs during cuML estimator initialization
# [CV 2/5] END metric=euclidean, n_neighbors=7, weights=distance;, score=0.484 total time=   0.0s
# [2025-05-14 15:42:35.967] [CUML] [info] Unused keyword parameter: n_jobs during cuML estimator initialization
# [CV 3/5] END metric=euclidean, n_neighbors=7, weights=distance;, score=0.505 total time=   0.0s
# [2025-05-14 15:42:35.976] [CUML] [info] Unused keyword parameter: n_jobs during cuML estimator initialization
# [CV 4/5] END metric=euclidean, n_neighbors=7, weights=distance;, score=0.528 total time=   0.0s
# [2025-05-14 15:42:35.986] [CUML] [info] Unused keyword parameter: n_jobs during cuML estimator initialization
# [CV 5/5] END metric=euclidean, n_neighbors=7, weights=distance;, score=0.536 total time=   0.0s
# [2025-05-14 15:42:35.994] [CUML] [info] Unused keyword parameter: n_jobs during cuML estimator initialization
# [CV 1/5] END metric=euclidean, n_neighbors=9, weights=uniform;, score=0.503 total time=   0.0s
# [2025-05-14 15:42:36.003] [CUML] [info] Unused keyword parameter: n_jobs during cuML estimator initialization
# [CV 2/5] END metric=euclidean, n_neighbors=9, weights=uniform;, score=0.475 total time=   0.0s
# [2025-05-14 15:42:36.012] [CUML] [info] Unused keyword parameter: n_jobs during cuML estimator initialization
# [CV 3/5] END metric=euclidean, n_neighbors=9, weights=uniform;, score=0.495 total time=   0.0s
# [2025-05-14 15:42:36.021] [CUML] [info] Unused keyword parameter: n_jobs during cuML estimator initialization
# [CV 4/5] END metric=euclidean, n_neighbors=9, weights=uniform;, score=0.519 total time=   0.0s
# [2025-05-14 15:42:36.030] [CUML] [info] Unused keyword parameter: n_jobs during cuML estimator initialization
# [CV 5/5] END metric=euclidean, n_neighbors=9, weights=uniform;, score=0.502 total time=   0.0s
# [2025-05-14 15:42:36.038] [CUML] [info] Unused keyword parameter: n_jobs during cuML estimator initialization
# [CV 1/5] END metric=euclidean, n_neighbors=9, weights=distance;, score=0.503 total time=   0.0s
# [2025-05-14 15:42:36.050] [CUML] [info] Unused keyword parameter: n_jobs during cuML estimator initialization
# [CV 2/5] END metric=euclidean, n_neighbors=9, weights=distance;, score=0.475 total time=   0.0s
# [2025-05-14 15:42:36.062] [CUML] [info] Unused keyword parameter: n_jobs during cuML estimator initialization
# [CV 3/5] END metric=euclidean, n_neighbors=9, weights=distance;, score=0.495 total time=   0.0s
# [2025-05-14 15:42:36.072] [CUML] [info] Unused keyword parameter: n_jobs during cuML estimator initialization
# [CV 4/5] END metric=euclidean, n_neighbors=9, weights=distance;, score=0.519 total time=   0.0s
# [2025-05-14 15:42:36.081] [CUML] [info] Unused keyword parameter: n_jobs during cuML estimator initialization
# [CV 5/5] END metric=euclidean, n_neighbors=9, weights=distance;, score=0.502 total time=   0.0s
# [2025-05-14 15:42:36.090] [CUML] [info] Unused keyword parameter: n_jobs during cuML estimator initialization
# [CV 1/5] END metric=euclidean, n_neighbors=11, weights=uniform;, score=0.488 total time=   0.0s
# [2025-05-14 15:42:36.099] [CUML] [info] Unused keyword parameter: n_jobs during cuML estimator initialization
# [CV 2/5] END metric=euclidean, n_neighbors=11, weights=uniform;, score=0.464 total time=   0.0s
# [2025-05-14 15:42:36.109] [CUML] [info] Unused keyword parameter: n_jobs during cuML estimator initialization
# [CV 3/5] END metric=euclidean, n_neighbors=11, weights=uniform;, score=0.495 total time=   0.0s
# [2025-05-14 15:42:36.118] [CUML] [info] Unused keyword parameter: n_jobs during cuML estimator initialization
# [CV 4/5] END metric=euclidean, n_neighbors=11, weights=uniform;, score=0.519 total time=   0.0s
# [2025-05-14 15:42:36.127] [CUML] [info] Unused keyword parameter: n_jobs during cuML estimator initialization
# [CV 5/5] END metric=euclidean, n_neighbors=11, weights=uniform;, score=0.517 total time=   0.0s
# [2025-05-14 15:42:36.138] [CUML] [info] Unused keyword parameter: n_jobs during cuML estimator initialization
# [CV 1/5] END metric=euclidean, n_neighbors=11, weights=distance;, score=0.488 total time=   0.0s
# [2025-05-14 15:42:36.147] [CUML] [info] Unused keyword parameter: n_jobs during cuML estimator initialization
# [CV 2/5] END metric=euclidean, n_neighbors=11, weights=distance;, score=0.464 total time=   0.0s
# [2025-05-14 15:42:36.156] [CUML] [info] Unused keyword parameter: n_jobs during cuML estimator initialization
# [CV 3/5] END metric=euclidean, n_neighbors=11, weights=distance;, score=0.495 total time=   0.0s
# [2025-05-14 15:42:36.164] [CUML] [info] Unused keyword parameter: n_jobs during cuML estimator initialization
# [CV 4/5] END metric=euclidean, n_neighbors=11, weights=distance;, score=0.519 total time=   0.0s
# [2025-05-14 15:42:36.172] [CUML] [info] Unused keyword parameter: n_jobs during cuML estimator initialization
# [CV 5/5] END metric=euclidean, n_neighbors=11, weights=distance;, score=0.517 total time=   0.0s
# [2025-05-14 15:42:36.181] [CUML] [info] Unused keyword parameter: n_jobs during cuML estimator initialization
# [CV 1/5] END metric=manhattan, n_neighbors=3, weights=uniform;, score=0.519 total time=   0.1s
# [2025-05-14 15:42:36.284] [CUML] [info] Unused keyword parameter: n_jobs during cuML estimator initialization
# [CV 2/5] END metric=manhattan, n_neighbors=3, weights=uniform;, score=0.514 total time=   0.0s
# [2025-05-14 15:42:36.293] [CUML] [info] Unused keyword parameter: n_jobs during cuML estimator initialization
# [CV 3/5] END metric=manhattan, n_neighbors=3, weights=uniform;, score=0.466 total time=   0.0s
# [2025-05-14 15:42:36.303] [CUML] [info] Unused keyword parameter: n_jobs during cuML estimator initialization
# [CV 4/5] END metric=manhattan, n_neighbors=3, weights=uniform;, score=0.492 total time=   0.0s
# [2025-05-14 15:42:36.313] [CUML] [info] Unused keyword parameter: n_jobs during cuML estimator initialization
# [CV 5/5] END metric=manhattan, n_neighbors=3, weights=uniform;, score=0.503 total time=   0.0s
# [2025-05-14 15:42:36.323] [CUML] [info] Unused keyword parameter: n_jobs during cuML estimator initialization
# [CV 1/5] END metric=manhattan, n_neighbors=3, weights=distance;, score=0.519 total time=   0.0s
# [2025-05-14 15:42:36.332] [CUML] [info] Unused keyword parameter: n_jobs during cuML estimator initialization
# [CV 2/5] END metric=manhattan, n_neighbors=3, weights=distance;, score=0.514 total time=   0.0s
# [2025-05-14 15:42:36.342] [CUML] [info] Unused keyword parameter: n_jobs during cuML estimator initialization
# [CV 3/5] END metric=manhattan, n_neighbors=3, weights=distance;, score=0.466 total time=   0.0s
# [2025-05-14 15:42:36.351] [CUML] [info] Unused keyword parameter: n_jobs during cuML estimator initialization
# [CV 4/5] END metric=manhattan, n_neighbors=3, weights=distance;, score=0.492 total time=   0.0s
# [2025-05-14 15:42:36.361] [CUML] [info] Unused keyword parameter: n_jobs during cuML estimator initialization
# [CV 5/5] END metric=manhattan, n_neighbors=3, weights=distance;, score=0.503 total time=   0.0s
# [2025-05-14 15:42:36.370] [CUML] [info] Unused keyword parameter: n_jobs during cuML estimator initialization
# [CV 1/5] END metric=manhattan, n_neighbors=5, weights=uniform;, score=0.502 total time=   0.0s
# [2025-05-14 15:42:36.378] [CUML] [info] Unused keyword parameter: n_jobs during cuML estimator initialization
# [CV 2/5] END metric=manhattan, n_neighbors=5, weights=uniform;, score=0.498 total time=   0.0s
# [2025-05-14 15:42:36.388] [CUML] [info] Unused keyword parameter: n_jobs during cuML estimator initialization
# [CV 3/5] END metric=manhattan, n_neighbors=5, weights=uniform;, score=0.483 total time=   0.0s
# [2025-05-14 15:42:36.397] [CUML] [info] Unused keyword parameter: n_jobs during cuML estimator initialization
# [CV 4/5] END metric=manhattan, n_neighbors=5, weights=uniform;, score=0.500 total time=   0.0s
# [2025-05-14 15:42:36.406] [CUML] [info] Unused keyword parameter: n_jobs during cuML estimator initialization
# [CV 5/5] END metric=manhattan, n_neighbors=5, weights=uniform;, score=0.503 total time=   0.0s
# [2025-05-14 15:42:36.415] [CUML] [info] Unused keyword parameter: n_jobs during cuML estimator initialization
# [CV 1/5] END metric=manhattan, n_neighbors=5, weights=distance;, score=0.502 total time=   0.0s
# [2025-05-14 15:42:36.425] [CUML] [info] Unused keyword parameter: n_jobs during cuML estimator initialization
# [CV 2/5] END metric=manhattan, n_neighbors=5, weights=distance;, score=0.498 total time=   0.0s
# [2025-05-14 15:42:36.434] [CUML] [info] Unused keyword parameter: n_jobs during cuML estimator initialization
# [CV 3/5] END metric=manhattan, n_neighbors=5, weights=distance;, score=0.483 total time=   0.0s
# [2025-05-14 15:42:36.443] [CUML] [info] Unused keyword parameter: n_jobs during cuML estimator initialization
# [CV 4/5] END metric=manhattan, n_neighbors=5, weights=distance;, score=0.500 total time=   0.0s
# [2025-05-14 15:42:36.452] [CUML] [info] Unused keyword parameter: n_jobs during cuML estimator initialization
# [CV 5/5] END metric=manhattan, n_neighbors=5, weights=distance;, score=0.503 total time=   0.0s
# [2025-05-14 15:42:36.460] [CUML] [info] Unused keyword parameter: n_jobs during cuML estimator initialization
# [CV 1/5] END metric=manhattan, n_neighbors=7, weights=uniform;, score=0.486 total time=   0.0s
# [2025-05-14 15:42:36.469] [CUML] [info] Unused keyword parameter: n_jobs during cuML estimator initialization
# [CV 2/5] END metric=manhattan, n_neighbors=7, weights=uniform;, score=0.478 total time=   0.0s
# [2025-05-14 15:42:36.478] [CUML] [info] Unused keyword parameter: n_jobs during cuML estimator initialization
# [CV 3/5] END metric=manhattan, n_neighbors=7, weights=uniform;, score=0.472 total time=   0.0s
# [2025-05-14 15:42:36.487] [CUML] [info] Unused keyword parameter: n_jobs during cuML estimator initialization
# [CV 4/5] END metric=manhattan, n_neighbors=7, weights=uniform;, score=0.523 total time=   0.0s
# [2025-05-14 15:42:36.496] [CUML] [info] Unused keyword parameter: n_jobs during cuML estimator initialization
# [CV 5/5] END metric=manhattan, n_neighbors=7, weights=uniform;, score=0.509 total time=   0.0s
# [2025-05-14 15:42:36.505] [CUML] [info] Unused keyword parameter: n_jobs during cuML estimator initialization
# [CV 1/5] END metric=manhattan, n_neighbors=7, weights=distance;, score=0.486 total time=   0.0s
# [2025-05-14 15:42:36.514] [CUML] [info] Unused keyword parameter: n_jobs during cuML estimator initialization
# [CV 2/5] END metric=manhattan, n_neighbors=7, weights=distance;, score=0.478 total time=   0.0s
# [2025-05-14 15:42:36.523] [CUML] [info] Unused keyword parameter: n_jobs during cuML estimator initialization
# [CV 3/5] END metric=manhattan, n_neighbors=7, weights=distance;, score=0.472 total time=   0.0s
# [2025-05-14 15:42:36.533] [CUML] [info] Unused keyword parameter: n_jobs during cuML estimator initialization
# [CV 4/5] END metric=manhattan, n_neighbors=7, weights=distance;, score=0.523 total time=   0.0s
# [2025-05-14 15:42:36.541] [CUML] [info] Unused keyword parameter: n_jobs during cuML estimator initialization
# [CV 5/5] END metric=manhattan, n_neighbors=7, weights=distance;, score=0.509 total time=   0.0s
# [2025-05-14 15:42:36.553] [CUML] [info] Unused keyword parameter: n_jobs during cuML estimator initialization
# [CV 1/5] END metric=manhattan, n_neighbors=9, weights=uniform;, score=0.511 total time=   0.0s
# [2025-05-14 15:42:36.563] [CUML] [info] Unused keyword parameter: n_jobs during cuML estimator initialization
# [CV 2/5] END metric=manhattan, n_neighbors=9, weights=uniform;, score=0.473 total time=   0.0s
# [2025-05-14 15:42:36.572] [CUML] [info] Unused keyword parameter: n_jobs during cuML estimator initialization
# [CV 3/5] END metric=manhattan, n_neighbors=9, weights=uniform;, score=0.458 total time=   0.0s
# [2025-05-14 15:42:36.581] [CUML] [info] Unused keyword parameter: n_jobs during cuML estimator initialization
# [CV 4/5] END metric=manhattan, n_neighbors=9, weights=uniform;, score=0.514 total time=   0.0s
# [2025-05-14 15:42:36.590] [CUML] [info] Unused keyword parameter: n_jobs during cuML estimator initialization
# [CV 5/5] END metric=manhattan, n_neighbors=9, weights=uniform;, score=0.491 total time=   0.0s
# [2025-05-14 15:42:36.601] [CUML] [info] Unused keyword parameter: n_jobs during cuML estimator initialization
# [CV 1/5] END metric=manhattan, n_neighbors=9, weights=distance;, score=0.511 total time=   0.0s
# [2025-05-14 15:42:36.611] [CUML] [info] Unused keyword parameter: n_jobs during cuML estimator initialization
# [CV 2/5] END metric=manhattan, n_neighbors=9, weights=distance;, score=0.473 total time=   0.0s
# [2025-05-14 15:42:36.620] [CUML] [info] Unused keyword parameter: n_jobs during cuML estimator initialization
# [CV 3/5] END metric=manhattan, n_neighbors=9, weights=distance;, score=0.458 total time=   0.0s
# [2025-05-14 15:42:36.629] [CUML] [info] Unused keyword parameter: n_jobs during cuML estimator initialization
# [CV 4/5] END metric=manhattan, n_neighbors=9, weights=distance;, score=0.514 total time=   0.0s
# [2025-05-14 15:42:36.638] [CUML] [info] Unused keyword parameter: n_jobs during cuML estimator initialization
# [CV 5/5] END metric=manhattan, n_neighbors=9, weights=distance;, score=0.491 total time=   0.0s
# [2025-05-14 15:42:36.647] [CUML] [info] Unused keyword parameter: n_jobs during cuML estimator initialization
# [CV 1/5] END metric=manhattan, n_neighbors=11, weights=uniform;, score=0.503 total time=   0.0s
# [2025-05-14 15:42:36.655] [CUML] [info] Unused keyword parameter: n_jobs during cuML estimator initialization
# [CV 2/5] END metric=manhattan, n_neighbors=11, weights=uniform;, score=0.491 total time=   0.0s
# [2025-05-14 15:42:36.664] [CUML] [info] Unused keyword parameter: n_jobs during cuML estimator initialization
# [CV 3/5] END metric=manhattan, n_neighbors=11, weights=uniform;, score=0.477 total time=   0.0s
# [2025-05-14 15:42:36.673] [CUML] [info] Unused keyword parameter: n_jobs during cuML estimator initialization
# [CV 4/5] END metric=manhattan, n_neighbors=11, weights=uniform;, score=0.519 total time=   0.0s
# [2025-05-14 15:42:36.682] [CUML] [info] Unused keyword parameter: n_jobs during cuML estimator initialization
# [CV 5/5] END metric=manhattan, n_neighbors=11, weights=uniform;, score=0.505 total time=   0.0s
# [2025-05-14 15:42:36.691] [CUML] [info] Unused keyword parameter: n_jobs during cuML estimator initialization
# [CV 1/5] END metric=manhattan, n_neighbors=11, weights=distance;, score=0.503 total time=   0.0s
# [2025-05-14 15:42:36.701] [CUML] [info] Unused keyword parameter: n_jobs during cuML estimator initialization
# [CV 2/5] END metric=manhattan, n_neighbors=11, weights=distance;, score=0.491 total time=   0.0s
# [2025-05-14 15:42:36.711] [CUML] [info] Unused keyword parameter: n_jobs during cuML estimator initialization
# [CV 3/5] END metric=manhattan, n_neighbors=11, weights=distance;, score=0.477 total time=   0.0s
# [2025-05-14 15:42:36.720] [CUML] [info] Unused keyword parameter: n_jobs during cuML estimator initialization
# [CV 4/5] END metric=manhattan, n_neighbors=11, weights=distance;, score=0.519 total time=   0.0s
# [2025-05-14 15:42:36.729] [CUML] [info] Unused keyword parameter: n_jobs during cuML estimator initialization
# [CV 5/5] END metric=manhattan, n_neighbors=11, weights=distance;, score=0.505 total time=   0.0s
# [2025-05-14 15:42:36.739] [CUML] [info] Unused keyword parameter: n_jobs during cuML estimator initialization
# cuml GridSearchCV training time (KNN) : 2.28 seconds
# cuml Best parameters (KNN): {'metric': 'euclidean', 'n_neighbors': 7, 'weights': 'uniform'}
# scikit-learn GridSearchCV training time (KNN) : 5.73 seconds
# scikit-learn Best parameters (KNN): {'metric': 'euclidean', 'n_neighbors': 7, 'weights': 'distance'}

# %% [markdown]
# ## Random Forest

# %%
model_name = "RandomForest"

# %%
from sklearn.ensemble import RandomForestClassifier as SklearnRandomForestClassifier
# Attempt to import cuML's RandomForestClassifier
try:
    from cuml.ensemble import RandomForestClassifier as cuMLRandomForestClassifier
    # has_cuml is already defined, assuming if previous cuML models are available, RF is too.
except ImportError:
    # Pass, relying on global has_cuml. Specific check for cuMLRandomForestClassifier will happen in the training block.
    pass

# %%
# Parameter grid for Random Forest
param_grid_rf = {
    'n_estimators': [100, 200], # Number of trees in the forest
    'max_depth': [None, 10, 20],    # Maximum depth of the tree
    'min_samples_split': [2, 5], # Minimum number of samples required to split an internal node
    'min_samples_leaf': [1, 2],   # Minimum number of samples required to be at a leaf node
    # 'max_features': ['auto', 'sqrt'] # Number of features to consider when looking for the best split (cuML might have different defaults/options)
    # For cuML compatibility, specific parameters like 'max_features' might need adjustment or careful selection.
    # cuML RandomForestClassifier has slightly different parameter names or accepted values for some arguments.
    # e.g. max_features in cuML can be int, float, or 'auto' (auto is sqrt(n_features)).
}

# 1) scikit-learn RandomForest with GridSearchCV
sk_models[model_name] = GridSearchCV(
    estimator=SklearnRandomForestClassifier(random_state=42),
    param_grid=param_grid_rf,
    cv=5, # Using 3-fold CV for RF due to potentially longer training times
    verbose=3,
    n_jobs=-1
)

time_start = time.time()
sk_models[model_name].fit(X_train, y_train)
time_end = time.time()
sk_times[model_name] = time_end - time_start


# 2) cuML RandomForest with GridSearchCV (adapted for cuML)
if has_cuml:
    try:
        # Ensure cuMLRandomForestClassifier was imported
        cuMLRandomForestClassifier

        # cuML specific parameter adjustments if necessary.
        # For example, cuML's RandomForestClassifier might not support all string options for max_features like sklearn.
        # It typically supports int (number of features) or float (fraction of features). 'auto' is often sqrt(n_features).
        # Let's use a simplified grid or ensure compatibility.
        # The provided param_grid_rf should generally work if 'max_features' is omitted or set to a compatible value.

        cu_models[model_name] = GridSearchCV(
            estimator=cuMLRandomForestClassifier(random_state=42), # cuML RandomForest
            param_grid=param_grid_rf, # Ensure parameters are compatible with cuML RF
            cv=5, # Using 3-fold CV
            verbose=3,
            n_jobs=1 # Safer for GPU resources with GridSearchCV
        )

        time_start = time.time()
        cu_models[model_name].fit(X_train, y_train) # X_train, y_train are pandas, cuML handles this
        time_end = time.time()
        cu_times[model_name] = time_end - time_start
        print(f"cuml GridSearchCV training time ({model_name}) : {cu_times[model_name]:.2f} seconds")
        print(f"cuml Best parameters ({model_name}): {cu_models[model_name].best_params_}")
    except NameError:
        print(f"cuML RandomForestClassifier not available. Skipping cuML {model_name} training.")
    except Exception as e:
        print(f"An error occurred during cuML {model_name} training: {e}")
        if model_name in cu_models: del cu_models[model_name]
        if model_name in cu_times: del cu_times[model_name]
else:
    print(f"cuML is not installed or GPU not available. Skipping cuML {model_name} benchmark.")

print(f"scikit-learn GridSearchCV training time ({model_name}) : {sk_times[model_name]:.2f} seconds")
print(f"scikit-learn Best parameters ({model_name}): {sk_models[model_name].best_params_}")
# Out:
# Fitting 5 folds for each of 24 candidates, totalling 120 fits
# /usr/local/lib/python3.11/dist-packages/cuml/internals/api_decorators.py:368: UserWarning: For reproducible results in Random Forest Classifier or for almost reproducible results in Random Forest Regressor, n_streams=1 is recommended. If n_streams is > 1, results may vary due to stream/thread timing differences, even when random_state is set
#   return init_func(self, *args, **kwargs)
# /usr/local/lib/python3.11/dist-packages/cuml/internals/api_decorators.py:368: UserWarning: For reproducible results in Random Forest Classifier or for almost reproducible results in Random Forest Regressor, n_streams=1 is recommended. If n_streams is > 1, results may vary due to stream/thread timing differences, even when random_state is set
#   return init_func(self, *args, **kwargs)
# /usr/local/lib/python3.11/dist-packages/cuml/internals/api_decorators.py:368: UserWarning: For reproducible results in Random Forest Classifier or for almost reproducible results in Random Forest Regressor, n_streams=1 is recommended. If n_streams is > 1, results may vary due to stream/thread timing differences, even when random_state is set
#   return init_func(self, *args, **kwargs)
# Fitting 5 folds for each of 24 candidates, totalling 120 fits
# [CV 1/5] END max_depth=None, min_samples_leaf=1, min_samples_split=2, n_estimators=100;, score=nan total time=   0.2s
# [CV 2/5] END max_depth=None, min_samples_leaf=1, min_samples_split=2, n_estimators=100;, score=nan total time=   0.0s
# [CV 3/5] END max_depth=None, min_samples_leaf=1, min_samples_split=2, n_estimators=100;, score=nan total time=   0.0s
# [CV 4/5] END max_depth=None, min_samples_leaf=1, min_samples_split=2, n_estimators=100;, score=nan total time=   0.0s
# [CV 5/5] END max_depth=None, min_samples_leaf=1, min_samples_split=2, n_estimators=100;, score=nan total time=   0.0s
# [CV 1/5] END max_depth=None, min_samples_leaf=1, min_samples_split=2, n_estimators=200;, score=nan total time=   0.0s
# [CV 2/5] END max_depth=None, min_samples_leaf=1, min_samples_split=2, n_estimators=200;, score=nan total time=   0.0s
# [CV 3/5] END max_depth=None, min_samples_leaf=1, min_samples_split=2, n_estimators=200;, score=nan total time=   0.0s
# [CV 4/5] END max_depth=None, min_samples_leaf=1, min_samples_split=2, n_estimators=200;, score=nan total time=   0.0s
# [CV 5/5] END max_depth=None, min_samples_leaf=1, min_samples_split=2, n_estimators=200;, score=nan total time=   0.0s
# [CV 1/5] END max_depth=None, min_samples_leaf=1, min_samples_split=5, n_estimators=100;, score=nan total time=   0.0s
# [CV 2/5] END max_depth=None, min_samples_leaf=1, min_samples_split=5, n_estimators=100;, score=nan total time=   0.0s
# [CV 3/5] END max_depth=None, min_samples_leaf=1, min_samples_split=5, n_estimators=100;, score=nan total time=   0.0s
# [CV 4/5] END max_depth=None, min_samples_leaf=1, min_samples_split=5, n_estimators=100;, score=nan total time=   0.0s
# [CV 5/5] END max_depth=None, min_samples_leaf=1, min_samples_split=5, n_estimators=100;, score=nan total time=   0.0s
# [CV 1/5] END max_depth=None, min_samples_leaf=1, min_samples_split=5, n_estimators=200;, score=nan total time=   0.0s
# [CV 2/5] END max_depth=None, min_samples_leaf=1, min_samples_split=5, n_estimators=200;, score=nan total time=   0.0s
# [CV 3/5] END max_depth=None, min_samples_leaf=1, min_samples_split=5, n_estimators=200;, score=nan total time=   0.0s
# [CV 4/5] END max_depth=None, min_samples_leaf=1, min_samples_split=5, n_estimators=200;, score=nan total time=   0.0s
# [CV 5/5] END max_depth=None, min_samples_leaf=1, min_samples_split=5, n_estimators=200;, score=nan total time=   0.0s
# [CV 1/5] END max_depth=None, min_samples_leaf=2, min_samples_split=2, n_estimators=100;, score=nan total time=   0.0s
# [CV 2/5] END max_depth=None, min_samples_leaf=2, min_samples_split=2, n_estimators=100;, score=nan total time=   0.0s
# [CV 3/5] END max_depth=None, min_samples_leaf=2, min_samples_split=2, n_estimators=100;, score=nan total time=   0.0s
# [CV 4/5] END max_depth=None, min_samples_leaf=2, min_samples_split=2, n_estimators=100;, score=nan total time=   0.0s
# [CV 5/5] END max_depth=None, min_samples_leaf=2, min_samples_split=2, n_estimators=100;, score=nan total time=   0.0s
# [CV 1/5] END max_depth=None, min_samples_leaf=2, min_samples_split=2, n_estimators=200;, score=nan total time=   0.0s
# [CV 2/5] END max_depth=None, min_samples_leaf=2, min_samples_split=2, n_estimators=200;, score=nan total time=   0.0s
# [CV 3/5] END max_depth=None, min_samples_leaf=2, min_samples_split=2, n_estimators=200;, score=nan total time=   0.0s
# [CV 4/5] END max_depth=None, min_samples_leaf=2, min_samples_split=2, n_estimators=200;, score=nan total time=   0.0s
# [CV 5/5] END max_depth=None, min_samples_leaf=2, min_samples_split=2, n_estimators=200;, score=nan total time=   0.0s
# [CV 1/5] END max_depth=None, min_samples_leaf=2, min_samples_split=5, n_estimators=100;, score=nan total time=   0.0s
# [CV 2/5] END max_depth=None, min_samples_leaf=2, min_samples_split=5, n_estimators=100;, score=nan total time=   0.0s
# [CV 3/5] END max_depth=None, min_samples_leaf=2, min_samples_split=5, n_estimators=100;, score=nan total time=   0.0s
# [CV 4/5] END max_depth=None, min_samples_leaf=2, min_samples_split=5, n_estimators=100;, score=nan total time=   0.0s
# [CV 5/5] END max_depth=None, min_samples_leaf=2, min_samples_split=5, n_estimators=100;, score=nan total time=   0.0s
# [CV 1/5] END max_depth=None, min_samples_leaf=2, min_samples_split=5, n_estimators=200;, score=nan total time=   0.0s
# [CV 2/5] END max_depth=None, min_samples_leaf=2, min_samples_split=5, n_estimators=200;, score=nan total time=   0.0s
# [CV 3/5] END max_depth=None, min_samples_leaf=2, min_samples_split=5, n_estimators=200;, score=nan total time=   0.0s
# [CV 4/5] END max_depth=None, min_samples_leaf=2, min_samples_split=5, n_estimators=200;, score=nan total time=   0.0s
# [CV 5/5] END max_depth=None, min_samples_leaf=2, min_samples_split=5, n_estimators=200;, score=nan total time=   0.0s
# [CV 1/5] END max_depth=10, min_samples_leaf=1, min_samples_split=2, n_estimators=100;, score=0.505 total time=   0.4s
# [CV 2/5] END max_depth=10, min_samples_leaf=1, min_samples_split=2, n_estimators=100;, score=0.516 total time=   0.2s
# [CV 3/5] END max_depth=10, min_samples_leaf=1, min_samples_split=2, n_estimators=100;, score=0.497 total time=   0.2s
# [CV 4/5] END max_depth=10, min_samples_leaf=1, min_samples_split=2, n_estimators=100;, score=0.478 total time=   0.2s
# [CV 5/5] END max_depth=10, min_samples_leaf=1, min_samples_split=2, n_estimators=100;, score=0.492 total time=   0.2s
# [CV 1/5] END max_depth=10, min_samples_leaf=1, min_samples_split=2, n_estimators=200;, score=0.505 total time=   0.3s
# [CV 2/5] END max_depth=10, min_samples_leaf=1, min_samples_split=2, n_estimators=200;, score=0.500 total time=   0.4s
# [CV 3/5] END max_depth=10, min_samples_leaf=1, min_samples_split=2, n_estimators=200;, score=0.519 total time=   0.4s
# [CV 4/5] END max_depth=10, min_samples_leaf=1, min_samples_split=2, n_estimators=200;, score=0.495 total time=   0.4s
# [CV 5/5] END max_depth=10, min_samples_leaf=1, min_samples_split=2, n_estimators=200;, score=0.492 total time=   0.4s
# [CV 1/5] END max_depth=10, min_samples_leaf=1, min_samples_split=5, n_estimators=100;, score=0.520 total time=   0.2s
# [CV 2/5] END max_depth=10, min_samples_leaf=1, min_samples_split=5, n_estimators=100;, score=0.486 total time=   0.2s
# [CV 3/5] END max_depth=10, min_samples_leaf=1, min_samples_split=5, n_estimators=100;, score=0.503 total time=   0.2s
# [CV 4/5] END max_depth=10, min_samples_leaf=1, min_samples_split=5, n_estimators=100;, score=0.502 total time=   0.2s
# [CV 5/5] END max_depth=10, min_samples_leaf=1, min_samples_split=5, n_estimators=100;, score=0.502 total time=   0.2s
# [CV 1/5] END max_depth=10, min_samples_leaf=1, min_samples_split=5, n_estimators=200;, score=0.492 total time=   0.4s
# [CV 2/5] END max_depth=10, min_samples_leaf=1, min_samples_split=5, n_estimators=200;, score=0.492 total time=   0.4s
# [CV 3/5] END max_depth=10, min_samples_leaf=1, min_samples_split=5, n_estimators=200;, score=0.511 total time=   0.4s
# [CV 4/5] END max_depth=10, min_samples_leaf=1, min_samples_split=5, n_estimators=200;, score=0.502 total time=   0.4s
# [CV 5/5] END max_depth=10, min_samples_leaf=1, min_samples_split=5, n_estimators=200;, score=0.494 total time=   0.4s
# [CV 1/5] END max_depth=10, min_samples_leaf=2, min_samples_split=2, n_estimators=100;, score=0.538 total time=   0.2s
# [CV 2/5] END max_depth=10, min_samples_leaf=2, min_samples_split=2, n_estimators=100;, score=0.497 total time=   0.2s
# [CV 3/5] END max_depth=10, min_samples_leaf=2, min_samples_split=2, n_estimators=100;, score=0.503 total time=   0.2s
# [CV 4/5] END max_depth=10, min_samples_leaf=2, min_samples_split=2, n_estimators=100;, score=0.511 total time=   0.2s
# [CV 5/5] END max_depth=10, min_samples_leaf=2, min_samples_split=2, n_estimators=100;, score=0.503 total time=   0.2s
# [CV 1/5] END max_depth=10, min_samples_leaf=2, min_samples_split=2, n_estimators=200;, score=0.502 total time=   0.4s
# [CV 2/5] END max_depth=10, min_samples_leaf=2, min_samples_split=2, n_estimators=200;, score=0.489 total time=   0.4s
# [CV 3/5] END max_depth=10, min_samples_leaf=2, min_samples_split=2, n_estimators=200;, score=0.512 total time=   0.4s
# [CV 4/5] END max_depth=10, min_samples_leaf=2, min_samples_split=2, n_estimators=200;, score=0.509 total time=   0.4s
# [CV 5/5] END max_depth=10, min_samples_leaf=2, min_samples_split=2, n_estimators=200;, score=0.498 total time=   0.5s
# [CV 1/5] END max_depth=10, min_samples_leaf=2, min_samples_split=5, n_estimators=100;, score=0.541 total time=   0.2s
# [CV 2/5] END max_depth=10, min_samples_leaf=2, min_samples_split=5, n_estimators=100;, score=0.486 total time=   0.2s
# [CV 3/5] END max_depth=10, min_samples_leaf=2, min_samples_split=5, n_estimators=100;, score=0.505 total time=   0.3s
# [CV 4/5] END max_depth=10, min_samples_leaf=2, min_samples_split=5, n_estimators=100;, score=0.519 total time=   0.2s
# [CV 5/5] END max_depth=10, min_samples_leaf=2, min_samples_split=5, n_estimators=100;, score=0.514 total time=   0.2s
# [CV 1/5] END max_depth=10, min_samples_leaf=2, min_samples_split=5, n_estimators=200;, score=0.517 total time=   0.4s
# [CV 2/5] END max_depth=10, min_samples_leaf=2, min_samples_split=5, n_estimators=200;, score=0.486 total time=   0.4s
# [CV 3/5] END max_depth=10, min_samples_leaf=2, min_samples_split=5, n_estimators=200;, score=0.508 total time=   0.3s
# [CV 4/5] END max_depth=10, min_samples_leaf=2, min_samples_split=5, n_estimators=200;, score=0.530 total time=   0.3s
# [CV 5/5] END max_depth=10, min_samples_leaf=2, min_samples_split=5, n_estimators=200;, score=0.498 total time=   0.3s
# [CV 1/5] END max_depth=20, min_samples_leaf=1, min_samples_split=2, n_estimators=100;, score=0.505 total time=   0.2s
# [CV 2/5] END max_depth=20, min_samples_leaf=1, min_samples_split=2, n_estimators=100;, score=0.500 total time=   0.2s
# [CV 3/5] END max_depth=20, min_samples_leaf=1, min_samples_split=2, n_estimators=100;, score=0.500 total time=   0.2s
# [CV 4/5] END max_depth=20, min_samples_leaf=1, min_samples_split=2, n_estimators=100;, score=0.502 total time=   0.2s
# [CV 5/5] END max_depth=20, min_samples_leaf=1, min_samples_split=2, n_estimators=100;, score=0.502 total time=   0.2s
# [CV 1/5] END max_depth=20, min_samples_leaf=1, min_samples_split=2, n_estimators=200;, score=0.503 total time=   0.5s
# [CV 2/5] END max_depth=20, min_samples_leaf=1, min_samples_split=2, n_estimators=200;, score=0.511 total time=   0.5s
# [CV 3/5] END max_depth=20, min_samples_leaf=1, min_samples_split=2, n_estimators=200;, score=0.502 total time=   0.5s
# [CV 4/5] END max_depth=20, min_samples_leaf=1, min_samples_split=2, n_estimators=200;, score=0.492 total time=   0.4s
# [CV 5/5] END max_depth=20, min_samples_leaf=1, min_samples_split=2, n_estimators=200;, score=0.508 total time=   0.5s
# [CV 1/5] END max_depth=20, min_samples_leaf=1, min_samples_split=5, n_estimators=100;, score=0.519 total time=   0.2s
# [CV 2/5] END max_depth=20, min_samples_leaf=1, min_samples_split=5, n_estimators=100;, score=0.500 total time=   0.2s
# [CV 3/5] END max_depth=20, min_samples_leaf=1, min_samples_split=5, n_estimators=100;, score=0.514 total time=   0.2s
# [CV 4/5] END max_depth=20, min_samples_leaf=1, min_samples_split=5, n_estimators=100;, score=0.503 total time=   0.2s
# [CV 5/5] END max_depth=20, min_samples_leaf=1, min_samples_split=5, n_estimators=100;, score=0.516 total time=   0.2s
# [CV 1/5] END max_depth=20, min_samples_leaf=1, min_samples_split=5, n_estimators=200;, score=0.520 total time=   0.4s
# [CV 2/5] END max_depth=20, min_samples_leaf=1, min_samples_split=5, n_estimators=200;, score=0.478 total time=   0.4s
# [CV 3/5] END max_depth=20, min_samples_leaf=1, min_samples_split=5, n_estimators=200;, score=0.494 total time=   0.4s
# [CV 4/5] END max_depth=20, min_samples_leaf=1, min_samples_split=5, n_estimators=200;, score=0.505 total time=   0.4s
# [CV 5/5] END max_depth=20, min_samples_leaf=1, min_samples_split=5, n_estimators=200;, score=0.522 total time=   0.4s
# [CV 1/5] END max_depth=20, min_samples_leaf=2, min_samples_split=2, n_estimators=100;, score=0.520 total time=   0.2s
# [CV 2/5] END max_depth=20, min_samples_leaf=2, min_samples_split=2, n_estimators=100;, score=0.494 total time=   0.2s
# [CV 3/5] END max_depth=20, min_samples_leaf=2, min_samples_split=2, n_estimators=100;, score=0.500 total time=   0.2s
# [CV 4/5] END max_depth=20, min_samples_leaf=2, min_samples_split=2, n_estimators=100;, score=0.516 total time=   0.2s
# [CV 5/5] END max_depth=20, min_samples_leaf=2, min_samples_split=2, n_estimators=100;, score=0.498 total time=   0.2s
# [CV 1/5] END max_depth=20, min_samples_leaf=2, min_samples_split=2, n_estimators=200;, score=0.527 total time=   0.5s
# [CV 2/5] END max_depth=20, min_samples_leaf=2, min_samples_split=2, n_estimators=200;, score=0.505 total time=   0.4s
# [CV 3/5] END max_depth=20, min_samples_leaf=2, min_samples_split=2, n_estimators=200;, score=0.500 total time=   0.5s
# [CV 4/5] END max_depth=20, min_samples_leaf=2, min_samples_split=2, n_estimators=200;, score=0.509 total time=   0.5s
# [CV 5/5] END max_depth=20, min_samples_leaf=2, min_samples_split=2, n_estimators=200;, score=0.517 total time=   0.5s
# [CV 1/5] END max_depth=20, min_samples_leaf=2, min_samples_split=5, n_estimators=100;, score=0.512 total time=   0.3s
# [CV 2/5] END max_depth=20, min_samples_leaf=2, min_samples_split=5, n_estimators=100;, score=0.506 total time=   0.3s
# [CV 3/5] END max_depth=20, min_samples_leaf=2, min_samples_split=5, n_estimators=100;, score=0.505 total time=   0.4s
# [CV 4/5] END max_depth=20, min_samples_leaf=2, min_samples_split=5, n_estimators=100;, score=0.527 total time=   0.3s
# [CV 5/5] END max_depth=20, min_samples_leaf=2, min_samples_split=5, n_estimators=100;, score=0.506 total time=   0.3s
# [CV 1/5] END max_depth=20, min_samples_leaf=2, min_samples_split=5, n_estimators=200;, score=0.505 total time=   0.4s
# [CV 2/5] END max_depth=20, min_samples_leaf=2, min_samples_split=5, n_estimators=200;, score=0.495 total time=   0.4s
# [CV 3/5] END max_depth=20, min_samples_leaf=2, min_samples_split=5, n_estimators=200;, score=0.497 total time=   0.4s
# [CV 4/5] END max_depth=20, min_samples_leaf=2, min_samples_split=5, n_estimators=200;, score=0.527 total time=   0.4s
# [CV 5/5] END max_depth=20, min_samples_leaf=2, min_samples_split=5, n_estimators=200;, score=0.488 total time=   0.4s
# cuml GridSearchCV training time (RandomForest) : 26.58 seconds
# cuml Best parameters (RandomForest): {'max_depth': 10, 'min_samples_leaf': 2, 'min_samples_split': 5, 'n_estimators': 100}
# scikit-learn GridSearchCV training time (RandomForest) : 113.03 seconds
# scikit-learn Best parameters (RandomForest): {'max_depth': None, 'min_samples_leaf': 2, 'min_samples_split': 2, 'n_estimators': 200}
# /usr/local/lib/python3.11/dist-packages/sklearn/model_selection/_validation.py:528: FitFailedWarning:
# 40 fits failed out of a total of 120.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 40 fits failed with the following error:
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.11/dist-packages/sklearn/model_selection/_validation.py", line 866, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/usr/local/lib/python3.11/dist-packages/nvtx/nvtx.py", line 122, in inner
#     result = func(*args, **kwargs)
#              ^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/cuml/internals/api_decorators.py", line 193, in wrapper
#     ret = func(*args, **kwargs)
#           ^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/cuml/internals/api_decorators.py", line 416, in dispatch
#     return self.dispatch_func(func_name, gpu_func, *args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/cuml/internals/api_decorators.py", line 195, in wrapper
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "base.pyx", line 764, in cuml.internals.base.UniversalBase.dispatch_func
#   File "randomforestclassifier.pyx", line 493, in cuml.ensemble.randomforestclassifier.RandomForestClassifier.fit
# TypeError: an integer is required
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# /usr/local/lib/python3.11/dist-packages/sklearn/model_selection/_search.py:1108: UserWarning: One or more of the test scores are non-finite: [       nan        nan        nan        nan        nan        nan
#         nan        nan 0.4975     0.5021875  0.50249999 0.498125
#  0.51031251 0.50218748 0.5128125  0.5078125  0.50156249 0.503125
#  0.51031251 0.50375    0.505625   0.51156249 0.51125001 0.5021875 ]
#   warnings.warn(

# %% [markdown]
# # Prediction & Model Evaluation

# %%
from sklearn.metrics import accuracy_score, confusion_matrix, ConfusionMatrixDisplay
import matplotlib.pyplot as plt

# --- Comparison and Evaluation ---
model_names = list(sk_models.keys()) # Assuming cu_models will have the same keys if cuML is available

for model_name in model_names:
    print(f"--- Evaluating: {model_name} ---")

    # --- scikit-learn model ---
    if model_name in sk_models:
        print("\n-- scikit-learn --")
        best_sk_model = sk_models[model_name].best_estimator_

        # Predictions
        y_pred_train_sk = best_sk_model.predict(X_train)
        y_pred_test_sk = best_sk_model.predict(X_test)
        start_time = time.time()
        sk_pred[model_name] = best_sk_model.predict(X)
        end_time = time.time()
        sk_pred_times[model_name] = end_time - start_time
        print(f"Prediction Duration: {sk_pred_times[model_name]:.2f} seconds")

        # Accuracy
        train_accuracy_sk = accuracy_score(y_train, y_pred_train_sk)
        test_accuracy_sk = accuracy_score(y_test, y_pred_test_sk)
        sk_train_accuracy[model_name] = train_accuracy_sk
        sk_test_accuracy[model_name] = test_accuracy_sk
        print(f"Train Accuracy: {train_accuracy_sk:.4f}")
        print(f"Test Accuracy: {test_accuracy_sk:.4f}")

        # Cross-validation score
        cv_score_sk = sk_models[model_name].best_score_
        sk_crossValidation_accuracy[model_name] = cv_score_sk
        print(f"Best Cross-Validation Score: {cv_score_sk:.4f}")

        # Duration
        print(f"Training Duration: {sk_times[model_name]:.2f} seconds")

        # Confusion Matrix
        print("Confusion Matrix (Test Set):")
        cm_sk = confusion_matrix(y_test, y_pred_test_sk)
        disp_sk = ConfusionMatrixDisplay(confusion_matrix=cm_sk, display_labels=best_sk_model.classes_)
        disp_sk.plot()
        plt.title(f"scikit-learn {model_name} - Confusion Matrix")
        plt.show()


    # --- cuML model ---
    print("\n-- cuML --")
    if has_cuml and model_name in cu_models:
        best_cu_model = cu_models[model_name].best_estimator_

        # Predictions

        # Note: cuML predict might require cuDF DataFrame or NumPy array
        # Ensuring X_train and X_test are in a compatible format (e.g., NumPy)
        # If they are pandas DataFrames, cuML usually handles them, but explicit conversion can be safer.
        y_pred_train_cu = best_cu_model.predict(X_train.to_numpy() if hasattr(X_train, 'to_numpy') else X_train)
        y_pred_test_cu = best_cu_model.predict(X_test.to_numpy() if hasattr(X_test, 'to_numpy') else X_test)
        start_time = time.time()
        cu_pred[model_name] = best_cu_model.predict(X.to_numpy() if hasattr(X, 'to_numpy') else X)
        end_time = time.time()
        cu_pred_times[model_name] = end_time - start_time
        print(f"Prediction Duration: {cu_pred_times[model_name]:.2f} seconds")

        # If predictions are cuPy arrays, convert them to NumPy for scikit-learn metrics
        if hasattr(y_pred_train_cu, 'get'): # Check if it's a cuPy array
            y_pred_train_cu = y_pred_train_cu.get()
        if hasattr(y_pred_test_cu, 'get'): # Check if it's a cuPy array
            y_pred_test_cu = y_pred_test_cu.get()


        # Accuracy
        train_accuracy_cu = accuracy_score(y_train, y_pred_train_cu) # y_train is pandas Series, compatible
        test_accuracy_cu = accuracy_score(y_test, y_pred_test_cu)   # y_test is pandas Series, compatible
        cu_train_accuracy[model_name] = train_accuracy_cu
        cu_test_accuracy[model_name] = test_accuracy_cu
        print(f"Train Accuracy: {train_accuracy_cu:.4f}")
        print(f"Test Accuracy: {test_accuracy_cu:.4f}")

        # Cross-validation score
        cv_score_cu = cu_models[model_name].best_score_
        cu_crossValidation_accuracy[f"cu_{model_name}"] = cv_score_cu
        print(f"Best Cross-Validation Score: {cv_score_cu:.4f}")

        # Duration
        # if model_name in cu_times: # Check if cu_times was populated
        print(f"Training Duration: {cu_times[model_name]:.2f} seconds")

        # Confusion Matrix
        print("Confusion Matrix (Test Set):")
        cm_cu = confusion_matrix(y_test, y_pred_test_cu)
        # Ensure classes are correctly obtained for cuML model if different from sklearn
        # For SVC, .classes_ should be available after fitting.
        disp_cu = ConfusionMatrixDisplay(confusion_matrix=cm_cu, display_labels=best_cu_model.classes_)
        disp_cu.plot()
        plt.title(f"cuML {model_name} - Confusion Matrix")
        plt.show()
    else:
        print(f"cuML {model_name} was not run as cuML model for it is not available.")

    print("\n" + "="*40 + "\n")

print("\nSummary of Accuracies and Times:")
print("scikit-learn Train Accuracies:", sk_train_accuracy)
print("CuML Train Accuracies:", cu_train_accuracy)
print("scikit-learn Test Accuracies:", sk_test_accuracy)
print("CuML Test Accuracies:", cu_test_accuracy)
print("scikit-learn Cross-Validation Accuracies:", sk_crossValidation_accuracy)
print("CuML Cross-Validation Accuracies:", cu_crossValidation_accuracy)
print("scikit-learn Training Times:", sk_times)
print("cuML Training Times:", cu_times)
print("scikit-learn Prediction Times:", sk_pred_times)
print("cuML Prediction Times:", cu_pred_times)
# Out:
# --- Evaluating: SVM ---
#
# -- scikit-learn --
# Prediction Duration: 0.47 seconds
# Train Accuracy: 0.7284
# Test Accuracy: 0.5075
# Best Cross-Validation Score: 0.5178
# Training Duration: 13.49 seconds
# Confusion Matrix (Test Set):
# -- cuML --
# Prediction Duration: 0.00 seconds
# Train Accuracy: 0.7288
# Test Accuracy: 0.5075
# Best Cross-Validation Score: 0.5175
# Training Duration: 9.67 seconds
# Confusion Matrix (Test Set):
# ========================================
#
# --- Evaluating: KNN ---
#
# -- scikit-learn --
# Prediction Duration: 0.14 seconds
# Train Accuracy: 1.0000
# Test Accuracy: 0.4813
# Best Cross-Validation Score: 0.5103
# Training Duration: 5.73 seconds
# Confusion Matrix (Test Set):
# -- cuML --
# Prediction Duration: 0.00 seconds
# Train Accuracy: 0.6475
# Test Accuracy: 0.4788
# Best Cross-Validation Score: 0.5097
# Training Duration: 2.28 seconds
# Confusion Matrix (Test Set):
# ========================================
#
# --- Evaluating: RandomForest ---
#
# -- scikit-learn --
# Prediction Duration: 0.10 seconds
# Train Accuracy: 1.0000
# Test Accuracy: 0.5025
# Best Cross-Validation Score: 0.5203
# Training Duration: 113.03 seconds
# Confusion Matrix (Test Set):
# -- cuML --
# Prediction Duration: 0.01 seconds
# Train Accuracy: 0.9444
# Test Accuracy: 0.5088
# Best Cross-Validation Score: 0.5128
# Training Duration: 26.58 seconds
# Confusion Matrix (Test Set):
# ========================================
#
#
# Summary of Accuracies and Times:
# scikit-learn Train Accuracies: {'SVM': 0.7284375, 'KNN': 1.0, 'RandomForest': 1.0}
# CuML Train Accuracies: {'SVM': 0.72875, 'KNN': 0.6475, 'RandomForest': 0.944375}
# scikit-learn Test Accuracies: {'SVM': 0.5075, 'KNN': 0.48125, 'RandomForest': 0.5025}
# CuML Test Accuracies: {'SVM': 0.5075, 'KNN': 0.47875, 'RandomForest': 0.50875}
# scikit-learn Cross-Validation Accuracies: {'SVM': np.float64(0.5178125), 'KNN': np.float64(0.5103125000000001), 'RandomForest': np.float64(0.5203125)}
# CuML Cross-Validation Accuracies: {'cu_SVM': np.float64(0.5174999952316284), 'cu_KNN': np.float64(0.5096874952316284), 'cu_RandomForest': np.float64(0.5128125011920929)}
# scikit-learn Training Times: {'SVM': 13.490140199661255, 'KNN': 5.728456735610962, 'RandomForest': 113.02871179580688}
# cuML Training Times: {'SVM': 9.66906189918518, 'KNN': 2.282802104949951, 'RandomForest': 26.57648277282715}
# scikit-learn Prediction Times: {'SVM': 0.46759605407714844, 'KNN': 0.1364150047302246, 'RandomForest': 0.10255885124206543}
# cuML Prediction Times: {'SVM': 0.0048291683197021484, 'KNN': 0.004548311233520508, 'RandomForest': 0.006226062774658203}

# %%
import matplotlib.pyplot as plt
import matplotlib.colors as mcolors
import numpy as np
import pandas as pd

# Ensure all necessary variables are defined from previous cells:
# data, df, y, sk_pred, cu_pred, has_cuml (for cuML models)
# X (to get the index for aligning predictions if they are numpy arrays)

if 'DEPT' not in data.columns:
    print("Error: 'DEPT' column not found in data DataFrame. Cannot generate depth plots.")
else:
    depth_column = data['DEPT']
    feature_names = df.columns.tolist()

    # Prepare labels and predictions (same as before)
    true_labels = y
    all_predictions_to_plot = {}
    all_predictions_to_plot['True Labels'] = true_labels
    for model_name, preds in sk_pred.items():
        all_predictions_to_plot[f'SK: {model_name}'] = preds
    if has_cuml and cu_pred:
        for model_name, preds_cu in cu_pred.items():
            if hasattr(preds_cu, 'get'):
                preds_np = preds_cu.get()
            else:
                preds_np = preds_cu
            all_predictions_to_plot[f'CU: {model_name}'] = preds_np

    # Define colors for classes (same as before)
    if isinstance(true_labels, np.ndarray):
        unique_classes = np.sort(np.unique(true_labels))
    else:
        unique_classes = np.sort(true_labels.unique())

    if len(unique_classes) == 1:
        plot_colors = ['gold']
    elif len(unique_classes) == 2:
        plot_colors = ['gold', 'darkorange']
    else:
        cmap_tab10 = plt.cm.get_cmap('tab10', len(unique_classes))
        plot_colors = [mcolors.to_hex(cmap_tab10(i)) for i in range(len(unique_classes))]

    class_to_int = {cls: i for i, cls in enumerate(unique_classes)}
    cmap_listed = mcolors.ListedColormap(plot_colors[:len(unique_classes)])


    # --- Figure 1: feature Tracks ---
    num_feature_plots = len(feature_names)
    if num_feature_plots > 0:
        fig_features, axes_features = plt.subplots(1, num_feature_plots, figsize=(num_feature_plots * 2.5, 10), sharey=True)
        if num_feature_plots == 1: # Handle single feature case for axes indexing
            axes_features = [axes_features]
        fig_features.suptitle("Feature Tracks", fontsize=16, y=0.98)

        for i, feature_name in enumerate(feature_names):
            ax = axes_features[i]
            ax.plot(data[feature_name].loc[X.index], depth_column.loc[X.index])
            ax.set_title(feature_name, fontsize=10)
            ax.set_xlabel("Value", fontsize=8)
            if i == 0:
                ax.set_ylabel("DEPT (feet)", fontsize=10)
            ax.grid(True, linestyle='--', alpha=0.7)
            ax.tick_params(axis='x', labelsize=8)
            ax.tick_params(axis='y', labelsize=8)

        axes_features[0].invert_yaxis()
        plt.tight_layout(rect=[0, 0.03, 1, 0.95])
        plt.show()
    else:
        print("No features to plot for feature tracks.")

    # --- Figure 2: scaled feature Tracks ---
    num_feature_plots = len(feature_names)
    if num_feature_plots > 0:
        fig_features, axes_features = plt.subplots(1, num_feature_plots, figsize=(num_feature_plots * 2.5, 10), sharey=True)
        if num_feature_plots == 1: # Handle single feature case for axes indexing
            axes_features = [axes_features]
        fig_features.suptitle("Scaled Feature Tracks", fontsize=16, y=0.98)

        for i, feature_name in enumerate(feature_names):
            ax = axes_features[i]
            ax.plot(X[feature_name].loc[X.index], depth_column.loc[X.index])
            ax.set_title(feature_name, fontsize=10)
            ax.set_xlabel("Value", fontsize=8)
            if i == 0:
                ax.set_ylabel("DEPT (feet)", fontsize=10)
            ax.grid(True, linestyle='--', alpha=0.7)
            ax.tick_params(axis='x', labelsize=8)
            ax.tick_params(axis='y', labelsize=8)

        axes_features[0].invert_yaxis()
        plt.tight_layout(rect=[0, 0.03, 1, 0.95])
        plt.show()
    else:
        print("No features to plot for scaled feature tracks.")

    # --- Figure 3: Classification Tracks ---
    num_classification_plots = len(all_predictions_to_plot)
    if num_classification_plots > 0:
        # Adjust figsize: width per plot can be smaller for classification tracks
        fig_class, axes_class = plt.subplots(1, num_classification_plots, figsize=(num_classification_plots * 1.2, 10), sharey=True)
        if num_classification_plots == 1: # Handle single classification plot case
            axes_class = [axes_class]
        fig_class.suptitle("Classification Tracks", fontsize=16, y=0.98)

        plot_order = ['True Labels'] + [k for k in all_predictions_to_plot.keys() if k != 'True Labels']

        for i, title in enumerate(plot_order):
            predictions_data = all_predictions_to_plot[title]
            ax = axes_class[i]

            if isinstance(predictions_data, pd.Series):
                if not predictions_data.index.equals(X.index):
                    # This should ideally not happen with consistent data handling
                    # For safety, one might reindex or ensure alignment upstream
                    print(f"Warning: Index mismatch for {title}. Plotting may be incorrect.")
                mapped_preds = predictions_data.map(class_to_int).fillna(-1)
            elif isinstance(predictions_data, np.ndarray):
                temp_series = pd.Series(predictions_data, index=X.index)
                mapped_preds = temp_series.map(class_to_int).fillna(-1)
            else:
                print(f"Warning: Data for {title} is of unexpected type: {type(predictions_data)}")
                continue

            labels_int = mapped_preds.values.reshape(-1, 1)
            vmin = 0
            vmax = len(plot_colors) - 1

            ax.imshow(labels_int, aspect='auto', cmap=cmap_listed,
                      extent=[0, 1, depth_column.loc[X.index].max(), depth_column.loc[X.index].min()],
                      interpolation='none', vmin=vmin, vmax=vmax)

            if title == 'True Labels':
                ax.set_title("True Class", fontsize=10)
            else:
                ax.set_title(title, fontsize=10)

            ax.set_xticks([])
            ax.set_xlabel("")
            ax.tick_params(axis='y', labelsize=8)
            if i == 0: # Set Y-axis label only for the first plot in this figure
                ax.set_ylabel("DEPT (feet)", fontsize=10)


        axes_class[0].invert_yaxis()

        if unique_classes is not None and len(unique_classes) > 0:
            patches = [plt.Rectangle((0,0),1,1, color=plot_colors[class_to_int[cls]]) for cls in unique_classes]
            legend_labels = [str(cls) for cls in unique_classes]
            fig_class.legend(patches, legend_labels, loc='lower center', ncol=len(unique_classes), bbox_to_anchor=(0.5, -0.02), title="Classes")

        plt.tight_layout(rect=[0, 0.03, 1, 0.93])
        plt.show()
    else:
        print("No classification data to plot.")

# %% [markdown]
# # Shutdown colab runtime

# %%
# Execution time
end_notebook = time.time()
print(f"Total notebook execution time: {end_notebook - start_notebook:.2f} seconds")
# Out:
# Total notebook execution time: 187.33 seconds

# %%
from google.colab import runtime
runtime.unassign()
