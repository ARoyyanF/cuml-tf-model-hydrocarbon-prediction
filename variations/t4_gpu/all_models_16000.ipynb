# %% [markdown]
# # Retrieve data

# %%
try:
    from google.colab import drive
    is_running_on_colab = True
except ImportError:
    is_running_on_colab = False

if is_running_on_colab:
    # Mount Google Drive
    drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import time
start_notebook = time.time()

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
import numpy as np

# %%
# Option to generate mock data
generate_mock_data = True # Set to True to generate mock data
max_mock_depth_ft = 16000 # Define maximum depth for mock data

# %%
well_name = "LLB-10"
if not generate_mock_data:
  if is_running_on_colab:
    # Load data from Google Drive, if running on Google Colab
    colab_repo_dir = "/content/drive/MyDrive/riset-fttm-gdrive/cuml-tf-model-hydrocarbon-prediction"
    data = pd.read_csv(f"{colab_repo_dir}/data/interpreted/interpreted_{well_name}.csv", sep=',')
  else:
    # Load data from local directory
    data = pd.read_csv(f"./data/interpreted/interpreted_{well_name}.csv", sep=',')

# %%
if generate_mock_data:
    print(f"Generating mock data up to {max_mock_depth_ft} ft for well {well_name}...")
    mock_depth_step = 0.5
    mock_dept_values = np.arange(0, max_mock_depth_ft, mock_depth_step)
    num_mock_rows = len(mock_dept_values)

    mock_data_dict = {'DEPT': mock_dept_values}

    feature_cols_for_mock = ['CALI','DRHO','GR','MR','NPHI_corr','PEF','RHOB_CORR','ROP']

    for col in feature_cols_for_mock:
        mock_data_dict[col] = np.random.rand(num_mock_rows) * 100

    mock_data_dict['hydrocarbon_formation_class'] = np.random.randint(0, 2, num_mock_rows)

    data = pd.DataFrame(mock_data_dict)

    print(f"Mock data generated for well {well_name} with {num_mock_rows} rows and columns: {list(data.columns)}.")
    print("Mock data head:")
    print(data.head())
# Out:
# Generating mock data up to 16000 ft for well LLB-10...
# Mock data generated for well LLB-10 with 32000 rows and columns: ['DEPT', 'CALI', 'DRHO', 'GR', 'MR', 'NPHI_corr', 'PEF', 'RHOB_CORR', 'ROP', 'hydrocarbon_formation_class'].
# Mock data head:
#    DEPT       CALI       DRHO         GR         MR  NPHI_corr        PEF  \
# 0   0.0  95.119045   4.771034  44.717764   6.740808  25.676020  90.810223
# 1   0.5  27.567513  45.991361  89.310608   6.000279  84.961487  97.563400
# 2   1.0  27.660755  85.720304  38.876630  93.454672  54.235005   4.203983
# 3   1.5  79.450420  13.368562  84.951271  83.434666  64.409224  78.455484
# 4   2.0  94.031568   3.292260  43.657969  13.720570  13.409297  19.052353
#
#    RHOB_CORR        ROP  hydrocarbon_formation_class
# 0  90.180515  98.135994                            1
# 1  52.724655  98.961578                            0
# 2  30.374511  40.539066                            1
# 3  22.007664  47.871229                            1
# 4   1.748664  76.861953                            1

# %%
df=data[['CALI','DRHO','GR','MR','NPHI_corr','PEF','RHOB_CORR','ROP']]
df
# Out:
#             CALI       DRHO         GR         MR  NPHI_corr        PEF  \
# 0      95.119045   4.771034  44.717764   6.740808  25.676020  90.810223
# 1      27.567513  45.991361  89.310608   6.000279  84.961487  97.563400
# 2      27.660755  85.720304  38.876630  93.454672  54.235005   4.203983
# 3      79.450420  13.368562  84.951271  83.434666  64.409224  78.455484
# 4      94.031568   3.292260  43.657969  13.720570  13.409297  19.052353
# ...          ...        ...        ...        ...        ...        ...
# 31995  86.475037  97.955957  76.602605  62.037750  18.546931   9.062525
# 31996  72.844260  30.385049   4.485571  74.710602  58.157068  84.057636
# 31997  85.985856  49.836234  58.780968  77.719861  17.287156  32.302609
# 31998  23.381703  39.101900  76.739176  97.015367  42.467079  67.805585
# 31999  57.334386  41.464148  90.592296  35.858654  99.787888  98.739717
#
#        RHOB_CORR        ROP
# 0      90.180515  98.135994
# 1      52.724655  98.961578
# 2      30.374511  40.539066
# 3      22.007664  47.871229
# 4       1.748664  76.861953
# ...          ...        ...
# 31995  25.587073  92.785662
# 31996  56.149007  49.591366
# 31997  74.016508  33.567252
# 31998   8.972551  38.152708
# 31999  23.807631  51.547636
#
# [32000 rows x 8 columns]

# %% [markdown]
# # Data Preparation

# %% [markdown]
# ## Train/Test Splitting

# %%
# Misalkan 'data' adalah DataFrame Anda dan 'df' adalah fitur yang telah Anda ekstrak
X = df  # Fitur
y = data['hydrocarbon_formation_class']  # Label

# Split data menjadi training dan testing set
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, stratify=y, random_state=42)

# %%
X_train.describe()
# Out:
#                CALI          DRHO            GR            MR     NPHI_corr  \
# count  25600.000000  25600.000000  25600.000000  25600.000000  25600.000000
# mean      50.168709     49.981232     49.865638     50.042016     50.144429
# std       28.921894     28.910892     28.931634     28.801407     28.991820
# min        0.008289      0.010337      0.002094      0.001931      0.000538
# 25%       25.121274     24.961637     25.027130     25.363421     25.047156
# 50%       50.280674     49.916315     49.571655     50.064139     50.228950
# 75%       75.505520     74.722440     74.920917     74.894273     75.272016
# max       99.999899     99.998079     99.997647     99.999831     99.998942
#
#                 PEF     RHOB_CORR           ROP
# count  25600.000000  25600.000000  25600.000000
# mean      50.028644     50.156422     50.089272
# std       28.762216     29.004124     29.146841
# min        0.009583      0.007712      0.000123
# 25%       25.456215     24.692508     24.527067
# 50%       49.870623     50.393043     50.382911
# 75%       74.963444     75.366099     75.478085
# max       99.999036     99.999921     99.995507

# %% [markdown]
# ## Apply Quantile Transformation

# %%
from sklearn.preprocessing import QuantileTransformer
def transform_quantile(X_train, X_test, X):
    qt_transformer = QuantileTransformer(output_distribution='normal')
    dfs = [X_train, X_test, X]
    qt_dfs = [None,None,None]
    for i, df in enumerate(dfs):
        if (i == 0): #only perform fit_transform on training data
            qt_dfs[i] = pd.DataFrame(qt_transformer.fit_transform(df))
        else:
            qt_dfs[i] = pd.DataFrame(qt_transformer.transform(df))
        qt_dfs[i].columns = df.columns.values
        qt_dfs[i].index = df.index.values
    return qt_dfs[0], qt_dfs[1], qt_dfs[2] #X_train, X_test, X

# %%
X_train, X_test, X = transform_quantile(X_train, X_test, X)

# %% [markdown]
# ## Feature Scaling
#
# karena menggunakan Quatile transformation dengan output gaussian, masing masing kolom secara otomatis ditransformasi ke distribusi normal baku, atau distribusi normal dengan rataan nol dan standar deviasi 1, oleh karena itu tidak diperlukan tambahan scaling.

# %%
X_train.describe()
# Out:
#                CALI          DRHO            GR            MR     NPHI_corr  \
# count  25600.000000  25600.000000  25600.000000  25600.000000  25600.000000
# mean      -0.006587     -0.006426     -0.012563      0.007948      0.010420
# std        1.005980      0.998547      1.006277      1.009080      0.997251
# min       -5.199338     -5.199338     -5.199338     -5.199338     -5.199338
# 25%       -0.676982     -0.676024     -0.686763     -0.668903     -0.662699
# 50%       -0.010222     -0.003621     -0.008239      0.003923      0.016887
# 75%        0.667166      0.668561      0.666591      0.674725      0.688792
# max        5.199338      5.199338      5.199338      5.199338      5.199338
#
#                 PEF     RHOB_CORR           ROP
# count  25600.000000  25600.000000  25600.000000
# mean      -0.000342     -0.003742      0.001304
# std        0.997992      0.996625      0.997195
# min       -5.199338     -5.199338     -5.199338
# 25%       -0.680223     -0.674406     -0.666076
# 50%        0.003176     -0.009393     -0.003452
# 75%        0.673317      0.665789      0.675692
# max        5.199338      5.199338      5.199338

# %% [markdown]
# # Training setup

# %%
import time
import numpy as np
from sklearn.model_selection import GridSearchCV


sk_train_accuracy={}
sk_test_accuracy={}

cu_train_accuracy={}
cu_test_accuracy={}

sk_crossValidation_accuracy={}
cu_crossValidation_accuracy={}

sk_models = {} #sklearn models
cu_models = {} #cuml models

sk_times = {}
cu_times = {}

sk_pred = {}
cu_pred = {}

sk_pred_times = {}
cu_pred_times = {}

# %%
# test CuML availability & is working
try:
    import cuml
    kmeans = cuml.KMeans(n_clusters=2)
    # Create minimal dummy data
    dummy_data = np.array([[1, 2], [1.5, 1.8], [5, 8], [8, 8]])
    kmeans.fit(dummy_data)
    # Attempt to fit the model
    has_cuml = True
    print("cuML is found and working")
except ImportError:
    has_cuml = False
    print("cuML not found. Please ensure cuML is installed.")
except Exception as e:
    has_cuml = False
    print(f"cuML couldn't be initialized or used. Error: {e}")
# Out:
# cuML is found and working
# /usr/local/lib/python3.11/dist-packages/cuml/internals/api_decorators.py:195: FutureWarning: The default value of `n_init` will change from 1 to 'auto' in 25.04. Set the value of `n_init` explicitly to suppress this warning.
#   return func(*args, **kwargs)

# %% [markdown]
# # Models

# %% [markdown]
# ## SVM

# %%
model_name = "SVM"

# %%
from sklearn.svm import SVC as SklearnSVC
# Attempt to import cuML's SVC
try:
    from cuml.svm import SVC as cuMLSVC
except ImportError:
    print("cuML SVC not available. Please ensure cuML is installed and compatible with your environment.")

# %%
# Parameter grid for both models
param_grid = {
    'C': [0.1, 1, 10],
    'gamma': ['scale', 'auto']
}

# 1) scikit-learn SVM with GridSearchCV
sk_models[model_name] = GridSearchCV(
    estimator=SklearnSVC(kernel='rbf'),
    param_grid=param_grid,
    cv=5,
    verbose=3,
    n_jobs=-1
)

time_start = time.time()
sk_models[model_name].fit(X_train, y_train)
time_end = time.time()
sk_times[model_name] = time_end - time_start

# 2) cuML SVM with the same GridSearchCV
if has_cuml:
    cu_models[model_name] = GridSearchCV(
        estimator=cuMLSVC(kernel='rbf'),
        param_grid=param_grid,
        cv=5,
        verbose=3,
        # Note: cuML estimator runs on GPU; this grid search runs on CPU orchestrating GPU calls
        n_jobs=1  # avoid multiprocessing issues with GPU
    )

    time_start = time.time()
    cu_models[model_name].fit(X_train, y_train)
    time_end = time.time()
    cu_times[model_name] = time_end - time_start
    print(f"cuml GridSearchCV training time ({model_name}) : {cu_times[model_name]:.2f} seconds")
    print(f"cuml Best parameters ({model_name}): {cu_models[model_name].best_params_}")
else:
    print("cuML is not installed or GPU not available. Please install RAPIDS cuML to run this benchmark.")

print(f"scikit-learn GridSearchCV training time ({model_name}) : {sk_times[model_name]:.2f} seconds")
print(f"scikit-learn Best parameters ({model_name}): {sk_models[model_name].best_params_}")
# Out:
# Fitting 5 folds for each of 6 candidates, totalling 30 fits
# Fitting 5 folds for each of 6 candidates, totalling 30 fits
# [CV 1/5] END ................C=0.1, gamma=scale;, score=0.503 total time=   4.2s
# [CV 2/5] END ................C=0.1, gamma=scale;, score=0.504 total time=   0.5s
# [CV 3/5] END ................C=0.1, gamma=scale;, score=0.498 total time=   0.5s
# [CV 4/5] END ................C=0.1, gamma=scale;, score=0.499 total time=   0.5s
# [CV 5/5] END ................C=0.1, gamma=scale;, score=0.502 total time=   0.5s
# [CV 1/5] END .................C=0.1, gamma=auto;, score=0.503 total time=   0.5s
# [CV 2/5] END .................C=0.1, gamma=auto;, score=0.504 total time=   0.5s
# [CV 3/5] END .................C=0.1, gamma=auto;, score=0.499 total time=   0.5s
# [CV 4/5] END .................C=0.1, gamma=auto;, score=0.499 total time=   0.5s
# [CV 5/5] END .................C=0.1, gamma=auto;, score=0.502 total time=   0.5s
# [CV 1/5] END ..................C=1, gamma=scale;, score=0.495 total time=   0.7s
# [CV 2/5] END ..................C=1, gamma=scale;, score=0.501 total time=   0.7s
# [CV 3/5] END ..................C=1, gamma=scale;, score=0.502 total time=   0.8s
# [CV 4/5] END ..................C=1, gamma=scale;, score=0.495 total time=   0.8s
# [CV 5/5] END ..................C=1, gamma=scale;, score=0.493 total time=   0.8s
# [CV 1/5] END ...................C=1, gamma=auto;, score=0.495 total time=   0.9s
# [CV 2/5] END ...................C=1, gamma=auto;, score=0.503 total time=   0.9s
# [CV 3/5] END ...................C=1, gamma=auto;, score=0.502 total time=   0.9s
# [CV 4/5] END ...................C=1, gamma=auto;, score=0.495 total time=   0.8s
# [CV 5/5] END ...................C=1, gamma=auto;, score=0.492 total time=   0.8s
# [CV 1/5] END .................C=10, gamma=scale;, score=0.499 total time=   5.4s
# [CV 2/5] END .................C=10, gamma=scale;, score=0.496 total time=   5.0s
# [CV 3/5] END .................C=10, gamma=scale;, score=0.500 total time=   5.0s
# [CV 4/5] END .................C=10, gamma=scale;, score=0.501 total time=   5.0s
# [CV 5/5] END .................C=10, gamma=scale;, score=0.503 total time=   5.0s
# [CV 1/5] END ..................C=10, gamma=auto;, score=0.499 total time=   5.1s
# [CV 2/5] END ..................C=10, gamma=auto;, score=0.496 total time=   4.8s
# [CV 3/5] END ..................C=10, gamma=auto;, score=0.500 total time=   5.1s
# [CV 4/5] END ..................C=10, gamma=auto;, score=0.501 total time=   4.8s
# [CV 5/5] END ..................C=10, gamma=auto;, score=0.502 total time=   5.0s
# cuml GridSearchCV training time (SVM) : 67.48 seconds
# cuml Best parameters (SVM): {'C': 0.1, 'gamma': 'scale'}
# scikit-learn GridSearchCV training time (SVM) : 692.15 seconds
# scikit-learn Best parameters (SVM): {'C': 0.1, 'gamma': 'scale'}

# %% [markdown]
# ## K-Nearest Neighbors

# %%
model_name = "KNN"

# %%
from sklearn.neighbors import KNeighborsClassifier as SklearnKNeighborsClassifier
# Attempt to import cuML's KNeighborsClassifier
try:
    from cuml.neighbors import KNeighborsClassifier as cuMLKNeighborsClassifier
    # has_cuml is already defined from SVM section, assuming if SVM cuml is available, KNN cuml is too.
except ImportError:
    # If cuML was previously found but KNN specific part is missing, update has_cuml for KNN context if necessary
    # For simplicity, we rely on the initial has_cuml check. If specific components are missing,
    # the cuML KNN block will be skipped or error out, which is acceptable.
    # A more robust check could be:
    # try: from cuml.svm import SVC as cuMLSVC; has_cuml_svm = True except: has_cuml_svm = False
    # try: from cuml.neighbors import KNeighborsClassifier as cuMLKNeighborsClassifier; has_cuml_knn = True except: has_cuml_knn = False
    pass # Rely on global has_cuml

# %%
# Parameter grid for KNN
param_grid_knn = {
    'n_neighbors': [3, 5, 7, 9, 11],
    'weights': ['uniform', 'distance'],
    'metric': ['euclidean', 'manhattan']
}

# 1) scikit-learn KNN with GridSearchCV
sk_models[model_name] = GridSearchCV(
    estimator=SklearnKNeighborsClassifier(),
    param_grid=param_grid_knn,
    cv=5,
    verbose=3,
    n_jobs=-1
)

time_start = time.time()
sk_models[model_name].fit(X_train, y_train)
time_end = time.time()
sk_times[model_name] = time_end - time_start

# 2) cuML KNN with the same GridSearchCV (adapted for cuML)
if has_cuml:
    try:
        # Ensure cuMLKNeighborsClassifier was imported
        cuMLKNeighborsClassifier

        cu_models[model_name] = GridSearchCV(
            estimator=cuMLKNeighborsClassifier(), # cuML KNN
            param_grid=param_grid_knn, # Using the same grid, ensure params are compatible
            cv=5,
            verbose=3,
            n_jobs=1 # Potentially can be >1 if managed carefully, but 1 is safer for GPU resources with GridSearchCV
        )

        time_start = time.time()
        # cuML's KNN might prefer numpy arrays or cuDF dataframes
        # X_train and y_train are pandas, which cuml usually handles.
        # If issues arise, convert: X_train_cu = X_train.to_numpy(), y_train_cu = y_train.to_numpy()
        cu_models[model_name].fit(X_train, y_train)
        time_end = time.time()
        cu_times[model_name] = time_end - time_start
        print(f"cuml GridSearchCV training time ({model_name}) : {cu_times[model_name]:.2f} seconds")
        print(f"cuml Best parameters ({model_name}): {cu_models[model_name].best_params_}")
    except NameError: # handles if cuMLKNeighborsClassifier was not imported
        print(f"cuML KNeighborsClassifier not available. Skipping cuML {model_name} training.")
    except Exception as e:
        print(f"An error occurred during cuML {model_name} training: {e}")
        # Optionally, remove the model key if setup failed partway
        if model_name in cu_models: del cu_models[model_name]
        if model_name in cu_times: del cu_times[model_name]

else:
    print(f"cuML is not installed or GPU not available. Skipping cuML {model_name} benchmark.")

print(f"scikit-learn GridSearchCV training time ({model_name}) : {sk_times[model_name]:.2f} seconds")
print(f"scikit-learn Best parameters ({model_name}): {sk_models[model_name].best_params_}")
# Out:
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# [2025-05-27 15:45:45.853] [CUML] [info] Unused keyword parameter: n_jobs during cuML estimator initialization
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# [2025-05-27 15:45:45.856] [CUML] [info] Unused keyword parameter: n_jobs during cuML estimator initialization
# [CV 1/5] END metric=euclidean, n_neighbors=3, weights=uniform;, score=0.494 total time=   1.1s
# [2025-05-27 15:45:46.986] [CUML] [info] Unused keyword parameter: n_jobs during cuML estimator initialization
# [CV 2/5] END metric=euclidean, n_neighbors=3, weights=uniform;, score=0.498 total time=   0.0s
# [2025-05-27 15:45:47.006] [CUML] [info] Unused keyword parameter: n_jobs during cuML estimator initialization
# [CV 3/5] END metric=euclidean, n_neighbors=3, weights=uniform;, score=0.495 total time=   0.0s
# [2025-05-27 15:45:47.025] [CUML] [info] Unused keyword parameter: n_jobs during cuML estimator initialization
# [CV 4/5] END metric=euclidean, n_neighbors=3, weights=uniform;, score=0.501 total time=   0.0s
# [2025-05-27 15:45:47.043] [CUML] [info] Unused keyword parameter: n_jobs during cuML estimator initialization
# [CV 5/5] END metric=euclidean, n_neighbors=3, weights=uniform;, score=0.504 total time=   0.0s
# [2025-05-27 15:45:47.060] [CUML] [info] Unused keyword parameter: n_jobs during cuML estimator initialization
# [CV 1/5] END metric=euclidean, n_neighbors=3, weights=distance;, score=0.494 total time=   0.0s
# [2025-05-27 15:45:47.078] [CUML] [info] Unused keyword parameter: n_jobs during cuML estimator initialization
# [CV 2/5] END metric=euclidean, n_neighbors=3, weights=distance;, score=0.498 total time=   0.0s
# [2025-05-27 15:45:47.095] [CUML] [info] Unused keyword parameter: n_jobs during cuML estimator initialization
# [CV 3/5] END metric=euclidean, n_neighbors=3, weights=distance;, score=0.495 total time=   0.0s
# [2025-05-27 15:45:47.113] [CUML] [info] Unused keyword parameter: n_jobs during cuML estimator initialization
# [CV 4/5] END metric=euclidean, n_neighbors=3, weights=distance;, score=0.501 total time=   0.0s
# [2025-05-27 15:45:47.130] [CUML] [info] Unused keyword parameter: n_jobs during cuML estimator initialization
# [CV 5/5] END metric=euclidean, n_neighbors=3, weights=distance;, score=0.504 total time=   0.0s
# [2025-05-27 15:45:47.148] [CUML] [info] Unused keyword parameter: n_jobs during cuML estimator initialization
# [CV 1/5] END metric=euclidean, n_neighbors=5, weights=uniform;, score=0.489 total time=   0.0s
# [2025-05-27 15:45:47.166] [CUML] [info] Unused keyword parameter: n_jobs during cuML estimator initialization
# [CV 2/5] END metric=euclidean, n_neighbors=5, weights=uniform;, score=0.492 total time=   0.0s
# [2025-05-27 15:45:47.184] [CUML] [info] Unused keyword parameter: n_jobs during cuML estimator initialization
# [CV 3/5] END metric=euclidean, n_neighbors=5, weights=uniform;, score=0.497 total time=   0.0s
# [2025-05-27 15:45:47.204] [CUML] [info] Unused keyword parameter: n_jobs during cuML estimator initialization
# [CV 4/5] END metric=euclidean, n_neighbors=5, weights=uniform;, score=0.492 total time=   0.0s
# [2025-05-27 15:45:47.222] [CUML] [info] Unused keyword parameter: n_jobs during cuML estimator initialization
# [CV 5/5] END metric=euclidean, n_neighbors=5, weights=uniform;, score=0.506 total time=   0.0s
# [2025-05-27 15:45:47.240] [CUML] [info] Unused keyword parameter: n_jobs during cuML estimator initialization
# [CV 1/5] END metric=euclidean, n_neighbors=5, weights=distance;, score=0.489 total time=   0.0s
# [2025-05-27 15:45:47.258] [CUML] [info] Unused keyword parameter: n_jobs during cuML estimator initialization
# [CV 2/5] END metric=euclidean, n_neighbors=5, weights=distance;, score=0.492 total time=   0.0s
# [2025-05-27 15:45:47.276] [CUML] [info] Unused keyword parameter: n_jobs during cuML estimator initialization
# [CV 3/5] END metric=euclidean, n_neighbors=5, weights=distance;, score=0.497 total time=   0.0s
# [2025-05-27 15:45:47.295] [CUML] [info] Unused keyword parameter: n_jobs during cuML estimator initialization
# [CV 4/5] END metric=euclidean, n_neighbors=5, weights=distance;, score=0.492 total time=   0.0s
# [2025-05-27 15:45:47.312] [CUML] [info] Unused keyword parameter: n_jobs during cuML estimator initialization
# [CV 5/5] END metric=euclidean, n_neighbors=5, weights=distance;, score=0.506 total time=   0.0s
# [2025-05-27 15:45:47.330] [CUML] [info] Unused keyword parameter: n_jobs during cuML estimator initialization
# [CV 1/5] END metric=euclidean, n_neighbors=7, weights=uniform;, score=0.488 total time=   0.0s
# [2025-05-27 15:45:47.349] [CUML] [info] Unused keyword parameter: n_jobs during cuML estimator initialization
# [CV 2/5] END metric=euclidean, n_neighbors=7, weights=uniform;, score=0.488 total time=   0.0s
# [2025-05-27 15:45:47.367] [CUML] [info] Unused keyword parameter: n_jobs during cuML estimator initialization
# [CV 3/5] END metric=euclidean, n_neighbors=7, weights=uniform;, score=0.495 total time=   0.0s
# [2025-05-27 15:45:47.383] [CUML] [info] Unused keyword parameter: n_jobs during cuML estimator initialization
# [CV 4/5] END metric=euclidean, n_neighbors=7, weights=uniform;, score=0.495 total time=   0.0s
# [2025-05-27 15:45:47.400] [CUML] [info] Unused keyword parameter: n_jobs during cuML estimator initialization
# [CV 5/5] END metric=euclidean, n_neighbors=7, weights=uniform;, score=0.504 total time=   0.0s
# [2025-05-27 15:45:47.417] [CUML] [info] Unused keyword parameter: n_jobs during cuML estimator initialization
# [CV 1/5] END metric=euclidean, n_neighbors=7, weights=distance;, score=0.488 total time=   0.0s
# [2025-05-27 15:45:47.434] [CUML] [info] Unused keyword parameter: n_jobs during cuML estimator initialization
# [CV 2/5] END metric=euclidean, n_neighbors=7, weights=distance;, score=0.488 total time=   0.0s
# [2025-05-27 15:45:47.451] [CUML] [info] Unused keyword parameter: n_jobs during cuML estimator initialization
# [CV 3/5] END metric=euclidean, n_neighbors=7, weights=distance;, score=0.495 total time=   0.0s
# [2025-05-27 15:45:47.468] [CUML] [info] Unused keyword parameter: n_jobs during cuML estimator initialization
# [CV 4/5] END metric=euclidean, n_neighbors=7, weights=distance;, score=0.495 total time=   0.0s
# [2025-05-27 15:45:47.486] [CUML] [info] Unused keyword parameter: n_jobs during cuML estimator initialization
# [CV 5/5] END metric=euclidean, n_neighbors=7, weights=distance;, score=0.504 total time=   0.0s
# [2025-05-27 15:45:47.502] [CUML] [info] Unused keyword parameter: n_jobs during cuML estimator initialization
# [CV 1/5] END metric=euclidean, n_neighbors=9, weights=uniform;, score=0.496 total time=   0.0s
# [2025-05-27 15:45:47.520] [CUML] [info] Unused keyword parameter: n_jobs during cuML estimator initialization
# [CV 2/5] END metric=euclidean, n_neighbors=9, weights=uniform;, score=0.488 total time=   0.0s
# [2025-05-27 15:45:47.536] [CUML] [info] Unused keyword parameter: n_jobs during cuML estimator initialization
# [CV 3/5] END metric=euclidean, n_neighbors=9, weights=uniform;, score=0.488 total time=   0.0s
# [2025-05-27 15:45:47.554] [CUML] [info] Unused keyword parameter: n_jobs during cuML estimator initialization
# [CV 4/5] END metric=euclidean, n_neighbors=9, weights=uniform;, score=0.498 total time=   0.0s
# [2025-05-27 15:45:47.569] [CUML] [info] Unused keyword parameter: n_jobs during cuML estimator initialization
# [CV 5/5] END metric=euclidean, n_neighbors=9, weights=uniform;, score=0.504 total time=   0.0s
# [2025-05-27 15:45:47.585] [CUML] [info] Unused keyword parameter: n_jobs during cuML estimator initialization
# [CV 1/5] END metric=euclidean, n_neighbors=9, weights=distance;, score=0.496 total time=   0.0s
# [2025-05-27 15:45:47.603] [CUML] [info] Unused keyword parameter: n_jobs during cuML estimator initialization
# [CV 2/5] END metric=euclidean, n_neighbors=9, weights=distance;, score=0.488 total time=   0.0s
# [2025-05-27 15:45:47.620] [CUML] [info] Unused keyword parameter: n_jobs during cuML estimator initialization
# [CV 3/5] END metric=euclidean, n_neighbors=9, weights=distance;, score=0.488 total time=   0.0s
# [2025-05-27 15:45:47.638] [CUML] [info] Unused keyword parameter: n_jobs during cuML estimator initialization
# [CV 4/5] END metric=euclidean, n_neighbors=9, weights=distance;, score=0.498 total time=   0.0s
# [2025-05-27 15:45:47.654] [CUML] [info] Unused keyword parameter: n_jobs during cuML estimator initialization
# [CV 5/5] END metric=euclidean, n_neighbors=9, weights=distance;, score=0.504 total time=   0.0s
# [2025-05-27 15:45:47.670] [CUML] [info] Unused keyword parameter: n_jobs during cuML estimator initialization
# [CV 1/5] END metric=euclidean, n_neighbors=11, weights=uniform;, score=0.484 total time=   0.0s
# [2025-05-27 15:45:47.685] [CUML] [info] Unused keyword parameter: n_jobs during cuML estimator initialization
# [CV 2/5] END metric=euclidean, n_neighbors=11, weights=uniform;, score=0.488 total time=   0.0s
# [2025-05-27 15:45:47.701] [CUML] [info] Unused keyword parameter: n_jobs during cuML estimator initialization
# [CV 3/5] END metric=euclidean, n_neighbors=11, weights=uniform;, score=0.489 total time=   0.0s
# [2025-05-27 15:45:47.722] [CUML] [info] Unused keyword parameter: n_jobs during cuML estimator initialization
# [CV 4/5] END metric=euclidean, n_neighbors=11, weights=uniform;, score=0.486 total time=   0.0s
# [2025-05-27 15:45:47.741] [CUML] [info] Unused keyword parameter: n_jobs during cuML estimator initialization
# [CV 5/5] END metric=euclidean, n_neighbors=11, weights=uniform;, score=0.494 total time=   0.0s
# [2025-05-27 15:45:47.758] [CUML] [info] Unused keyword parameter: n_jobs during cuML estimator initialization
# [CV 1/5] END metric=euclidean, n_neighbors=11, weights=distance;, score=0.484 total time=   0.0s
# [2025-05-27 15:45:47.774] [CUML] [info] Unused keyword parameter: n_jobs during cuML estimator initialization
# [CV 2/5] END metric=euclidean, n_neighbors=11, weights=distance;, score=0.488 total time=   0.0s
# [2025-05-27 15:45:47.790] [CUML] [info] Unused keyword parameter: n_jobs during cuML estimator initialization
# [CV 3/5] END metric=euclidean, n_neighbors=11, weights=distance;, score=0.489 total time=   0.0s
# [2025-05-27 15:45:47.806] [CUML] [info] Unused keyword parameter: n_jobs during cuML estimator initialization
# [CV 4/5] END metric=euclidean, n_neighbors=11, weights=distance;, score=0.486 total time=   0.0s
# [2025-05-27 15:45:47.821] [CUML] [info] Unused keyword parameter: n_jobs during cuML estimator initialization
# [CV 5/5] END metric=euclidean, n_neighbors=11, weights=distance;, score=0.494 total time=   0.0s
# [2025-05-27 15:45:47.840] [CUML] [info] Unused keyword parameter: n_jobs during cuML estimator initialization
# [CV 1/5] END metric=manhattan, n_neighbors=3, weights=uniform;, score=0.503 total time=   0.1s
# [2025-05-27 15:45:47.957] [CUML] [info] Unused keyword parameter: n_jobs during cuML estimator initialization
# [CV 2/5] END metric=manhattan, n_neighbors=3, weights=uniform;, score=0.494 total time=   0.0s
# [2025-05-27 15:45:47.980] [CUML] [info] Unused keyword parameter: n_jobs during cuML estimator initialization
# [CV 3/5] END metric=manhattan, n_neighbors=3, weights=uniform;, score=0.489 total time=   0.0s
# [2025-05-27 15:45:48.000] [CUML] [info] Unused keyword parameter: n_jobs during cuML estimator initialization
# [CV 4/5] END metric=manhattan, n_neighbors=3, weights=uniform;, score=0.495 total time=   0.0s
# [2025-05-27 15:45:48.020] [CUML] [info] Unused keyword parameter: n_jobs during cuML estimator initialization
# [CV 5/5] END metric=manhattan, n_neighbors=3, weights=uniform;, score=0.510 total time=   0.0s
# [2025-05-27 15:45:48.041] [CUML] [info] Unused keyword parameter: n_jobs during cuML estimator initialization
# [CV 1/5] END metric=manhattan, n_neighbors=3, weights=distance;, score=0.503 total time=   0.0s
# [2025-05-27 15:45:48.063] [CUML] [info] Unused keyword parameter: n_jobs during cuML estimator initialization
# [CV 2/5] END metric=manhattan, n_neighbors=3, weights=distance;, score=0.494 total time=   0.0s
# [2025-05-27 15:45:48.085] [CUML] [info] Unused keyword parameter: n_jobs during cuML estimator initialization
# [CV 3/5] END metric=manhattan, n_neighbors=3, weights=distance;, score=0.489 total time=   0.0s
# [2025-05-27 15:45:48.105] [CUML] [info] Unused keyword parameter: n_jobs during cuML estimator initialization
# [CV 4/5] END metric=manhattan, n_neighbors=3, weights=distance;, score=0.495 total time=   0.0s
# [2025-05-27 15:45:48.125] [CUML] [info] Unused keyword parameter: n_jobs during cuML estimator initialization
# [CV 5/5] END metric=manhattan, n_neighbors=3, weights=distance;, score=0.510 total time=   0.0s
# [2025-05-27 15:45:48.145] [CUML] [info] Unused keyword parameter: n_jobs during cuML estimator initialization
# [CV 1/5] END metric=manhattan, n_neighbors=5, weights=uniform;, score=0.495 total time=   0.0s
# [2025-05-27 15:45:48.164] [CUML] [info] Unused keyword parameter: n_jobs during cuML estimator initialization
# [CV 2/5] END metric=manhattan, n_neighbors=5, weights=uniform;, score=0.492 total time=   0.0s
# [2025-05-27 15:45:48.181] [CUML] [info] Unused keyword parameter: n_jobs during cuML estimator initialization
# [CV 3/5] END metric=manhattan, n_neighbors=5, weights=uniform;, score=0.493 total time=   0.0s
# [2025-05-27 15:45:48.198] [CUML] [info] Unused keyword parameter: n_jobs during cuML estimator initialization
# [CV 4/5] END metric=manhattan, n_neighbors=5, weights=uniform;, score=0.496 total time=   0.0s
# [2025-05-27 15:45:48.215] [CUML] [info] Unused keyword parameter: n_jobs during cuML estimator initialization
# [CV 5/5] END metric=manhattan, n_neighbors=5, weights=uniform;, score=0.506 total time=   0.0s
# [2025-05-27 15:45:48.232] [CUML] [info] Unused keyword parameter: n_jobs during cuML estimator initialization
# [CV 1/5] END metric=manhattan, n_neighbors=5, weights=distance;, score=0.495 total time=   0.0s
# [2025-05-27 15:45:48.250] [CUML] [info] Unused keyword parameter: n_jobs during cuML estimator initialization
# [CV 2/5] END metric=manhattan, n_neighbors=5, weights=distance;, score=0.492 total time=   0.0s
# [2025-05-27 15:45:48.267] [CUML] [info] Unused keyword parameter: n_jobs during cuML estimator initialization
# [CV 3/5] END metric=manhattan, n_neighbors=5, weights=distance;, score=0.493 total time=   0.0s
# [2025-05-27 15:45:48.284] [CUML] [info] Unused keyword parameter: n_jobs during cuML estimator initialization
# [CV 4/5] END metric=manhattan, n_neighbors=5, weights=distance;, score=0.496 total time=   0.0s
# [2025-05-27 15:45:48.302] [CUML] [info] Unused keyword parameter: n_jobs during cuML estimator initialization
# [CV 5/5] END metric=manhattan, n_neighbors=5, weights=distance;, score=0.506 total time=   0.0s
# [2025-05-27 15:45:48.318] [CUML] [info] Unused keyword parameter: n_jobs during cuML estimator initialization
# [CV 1/5] END metric=manhattan, n_neighbors=7, weights=uniform;, score=0.497 total time=   0.0s
# [2025-05-27 15:45:48.336] [CUML] [info] Unused keyword parameter: n_jobs during cuML estimator initialization
# [CV 2/5] END metric=manhattan, n_neighbors=7, weights=uniform;, score=0.496 total time=   0.0s
# [2025-05-27 15:45:48.354] [CUML] [info] Unused keyword parameter: n_jobs during cuML estimator initialization
# [CV 3/5] END metric=manhattan, n_neighbors=7, weights=uniform;, score=0.496 total time=   0.0s
# [2025-05-27 15:45:48.370] [CUML] [info] Unused keyword parameter: n_jobs during cuML estimator initialization
# [CV 4/5] END metric=manhattan, n_neighbors=7, weights=uniform;, score=0.495 total time=   0.0s
# [2025-05-27 15:45:48.386] [CUML] [info] Unused keyword parameter: n_jobs during cuML estimator initialization
# [CV 5/5] END metric=manhattan, n_neighbors=7, weights=uniform;, score=0.497 total time=   0.0s
# [2025-05-27 15:45:48.402] [CUML] [info] Unused keyword parameter: n_jobs during cuML estimator initialization
# [CV 1/5] END metric=manhattan, n_neighbors=7, weights=distance;, score=0.497 total time=   0.0s
# [2025-05-27 15:45:48.418] [CUML] [info] Unused keyword parameter: n_jobs during cuML estimator initialization
# [CV 2/5] END metric=manhattan, n_neighbors=7, weights=distance;, score=0.496 total time=   0.0s
# [2025-05-27 15:45:48.434] [CUML] [info] Unused keyword parameter: n_jobs during cuML estimator initialization
# [CV 3/5] END metric=manhattan, n_neighbors=7, weights=distance;, score=0.496 total time=   0.0s
# [2025-05-27 15:45:48.451] [CUML] [info] Unused keyword parameter: n_jobs during cuML estimator initialization
# [CV 4/5] END metric=manhattan, n_neighbors=7, weights=distance;, score=0.495 total time=   0.0s
# [2025-05-27 15:45:48.471] [CUML] [info] Unused keyword parameter: n_jobs during cuML estimator initialization
# [CV 5/5] END metric=manhattan, n_neighbors=7, weights=distance;, score=0.497 total time=   0.0s
# [2025-05-27 15:45:48.488] [CUML] [info] Unused keyword parameter: n_jobs during cuML estimator initialization
# [CV 1/5] END metric=manhattan, n_neighbors=9, weights=uniform;, score=0.496 total time=   0.0s
# [2025-05-27 15:45:48.504] [CUML] [info] Unused keyword parameter: n_jobs during cuML estimator initialization
# [CV 2/5] END metric=manhattan, n_neighbors=9, weights=uniform;, score=0.498 total time=   0.0s
# [2025-05-27 15:45:48.520] [CUML] [info] Unused keyword parameter: n_jobs during cuML estimator initialization
# [CV 3/5] END metric=manhattan, n_neighbors=9, weights=uniform;, score=0.490 total time=   0.0s
# [2025-05-27 15:45:48.537] [CUML] [info] Unused keyword parameter: n_jobs during cuML estimator initialization
# [CV 4/5] END metric=manhattan, n_neighbors=9, weights=uniform;, score=0.499 total time=   0.0s
# [2025-05-27 15:45:48.555] [CUML] [info] Unused keyword parameter: n_jobs during cuML estimator initialization
# [CV 5/5] END metric=manhattan, n_neighbors=9, weights=uniform;, score=0.501 total time=   0.0s
# [2025-05-27 15:45:48.574] [CUML] [info] Unused keyword parameter: n_jobs during cuML estimator initialization
# [CV 1/5] END metric=manhattan, n_neighbors=9, weights=distance;, score=0.496 total time=   0.0s
# [2025-05-27 15:45:48.590] [CUML] [info] Unused keyword parameter: n_jobs during cuML estimator initialization
# [CV 2/5] END metric=manhattan, n_neighbors=9, weights=distance;, score=0.498 total time=   0.0s
# [2025-05-27 15:45:48.607] [CUML] [info] Unused keyword parameter: n_jobs during cuML estimator initialization
# [CV 3/5] END metric=manhattan, n_neighbors=9, weights=distance;, score=0.490 total time=   0.0s
# [2025-05-27 15:45:48.630] [CUML] [info] Unused keyword parameter: n_jobs during cuML estimator initialization
# [CV 4/5] END metric=manhattan, n_neighbors=9, weights=distance;, score=0.499 total time=   0.0s
# [2025-05-27 15:45:48.647] [CUML] [info] Unused keyword parameter: n_jobs during cuML estimator initialization
# [CV 5/5] END metric=manhattan, n_neighbors=9, weights=distance;, score=0.501 total time=   0.0s
# [2025-05-27 15:45:48.662] [CUML] [info] Unused keyword parameter: n_jobs during cuML estimator initialization
# [CV 1/5] END metric=manhattan, n_neighbors=11, weights=uniform;, score=0.498 total time=   0.0s
# [2025-05-27 15:45:48.681] [CUML] [info] Unused keyword parameter: n_jobs during cuML estimator initialization
# [CV 2/5] END metric=manhattan, n_neighbors=11, weights=uniform;, score=0.494 total time=   0.0s
# [2025-05-27 15:45:48.697] [CUML] [info] Unused keyword parameter: n_jobs during cuML estimator initialization
# [CV 3/5] END metric=manhattan, n_neighbors=11, weights=uniform;, score=0.493 total time=   0.0s
# [2025-05-27 15:45:48.716] [CUML] [info] Unused keyword parameter: n_jobs during cuML estimator initialization
# [CV 4/5] END metric=manhattan, n_neighbors=11, weights=uniform;, score=0.498 total time=   0.0s
# [2025-05-27 15:45:48.739] [CUML] [info] Unused keyword parameter: n_jobs during cuML estimator initialization
# [CV 5/5] END metric=manhattan, n_neighbors=11, weights=uniform;, score=0.500 total time=   0.0s
# [2025-05-27 15:45:48.760] [CUML] [info] Unused keyword parameter: n_jobs during cuML estimator initialization
# [CV 1/5] END metric=manhattan, n_neighbors=11, weights=distance;, score=0.498 total time=   0.0s
# [2025-05-27 15:45:48.781] [CUML] [info] Unused keyword parameter: n_jobs during cuML estimator initialization
# [CV 2/5] END metric=manhattan, n_neighbors=11, weights=distance;, score=0.494 total time=   0.0s
# [2025-05-27 15:45:48.797] [CUML] [info] Unused keyword parameter: n_jobs during cuML estimator initialization
# [CV 3/5] END metric=manhattan, n_neighbors=11, weights=distance;, score=0.493 total time=   0.0s
# [2025-05-27 15:45:48.814] [CUML] [info] Unused keyword parameter: n_jobs during cuML estimator initialization
# [CV 4/5] END metric=manhattan, n_neighbors=11, weights=distance;, score=0.498 total time=   0.0s
# [2025-05-27 15:45:48.830] [CUML] [info] Unused keyword parameter: n_jobs during cuML estimator initialization
# [CV 5/5] END metric=manhattan, n_neighbors=11, weights=distance;, score=0.500 total time=   0.0s
# [2025-05-27 15:45:48.847] [CUML] [info] Unused keyword parameter: n_jobs during cuML estimator initialization
# cuml GridSearchCV training time (KNN) : 3.00 seconds
# cuml Best parameters (KNN): {'metric': 'euclidean', 'n_neighbors': 3, 'weights': 'uniform'}
# scikit-learn GridSearchCV training time (KNN) : 98.12 seconds
# scikit-learn Best parameters (KNN): {'metric': 'euclidean', 'n_neighbors': 3, 'weights': 'uniform'}

# %% [markdown]
# ## Random Forest

# %%
model_name = "RF"

# %%
from sklearn.ensemble import RandomForestClassifier as SklearnRandomForestClassifier
# Attempt to import cuML's RandomForestClassifier
try:
    from cuml.ensemble import RandomForestClassifier as cuMLRandomForestClassifier
    # has_cuml is already defined, assuming if previous cuML models are available, RF is too.
except ImportError:
    # Pass, relying on global has_cuml. Specific check for cuMLRandomForestClassifier will happen in the training block.
    pass

# %%
# Parameter grid for Random Forest
param_grid_rf = {
    'n_estimators': [100, 200], # Number of trees in the forest
    'max_depth': [None, 10, 20],    # Maximum depth of the tree
    'min_samples_split': [2, 5], # Minimum number of samples required to split an internal node
    'min_samples_leaf': [1, 2],   # Minimum number of samples required to be at a leaf node
    # 'max_features': ['auto', 'sqrt'] # Number of features to consider when looking for the best split (cuML might have different defaults/options)
    # For cuML compatibility, specific parameters like 'max_features' might need adjustment or careful selection.
    # cuML RandomForestClassifier has slightly different parameter names or accepted values for some arguments.
    # e.g. max_features in cuML can be int, float, or 'auto' (auto is sqrt(n_features)).
}

# 1) scikit-learn RandomForest with GridSearchCV
sk_models[model_name] = GridSearchCV(
    estimator=SklearnRandomForestClassifier(random_state=42),
    param_grid=param_grid_rf,
    cv=5, # Using 3-fold CV for RF due to potentially longer training times
    verbose=3,
    n_jobs=-1
)

time_start = time.time()
sk_models[model_name].fit(X_train, y_train)
time_end = time.time()
sk_times[model_name] = time_end - time_start


# 2) cuML RandomForest with GridSearchCV (adapted for cuML)
if has_cuml:
    try:
        # Ensure cuMLRandomForestClassifier was imported
        cuMLRandomForestClassifier

        # cuML specific parameter adjustments if necessary.
        # For example, cuML's RandomForestClassifier might not support all string options for max_features like sklearn.
        # It typically supports int (number of features) or float (fraction of features). 'auto' is often sqrt(n_features).
        # Let's use a simplified grid or ensure compatibility.
        # The provided param_grid_rf should generally work if 'max_features' is omitted or set to a compatible value.

        cu_models[model_name] = GridSearchCV(
            estimator=cuMLRandomForestClassifier(random_state=42), # cuML RandomForest
            param_grid=param_grid_rf, # Ensure parameters are compatible with cuML RF
            cv=5, # Using 3-fold CV
            verbose=3,
            n_jobs=1 # Safer for GPU resources with GridSearchCV
        )

        time_start = time.time()
        cu_models[model_name].fit(X_train, y_train) # X_train, y_train are pandas, cuML handles this
        time_end = time.time()
        cu_times[model_name] = time_end - time_start
        print(f"cuml GridSearchCV training time ({model_name}) : {cu_times[model_name]:.2f} seconds")
        print(f"cuml Best parameters ({model_name}): {cu_models[model_name].best_params_}")
    except NameError:
        print(f"cuML RandomForestClassifier not available. Skipping cuML {model_name} training.")
    except Exception as e:
        print(f"An error occurred during cuML {model_name} training: {e}")
        if model_name in cu_models: del cu_models[model_name]
        if model_name in cu_times: del cu_times[model_name]
else:
    print(f"cuML is not installed or GPU not available. Skipping cuML {model_name} benchmark.")

print(f"scikit-learn GridSearchCV training time ({model_name}) : {sk_times[model_name]:.2f} seconds")
print(f"scikit-learn Best parameters ({model_name}): {sk_models[model_name].best_params_}")
# Out:
# Fitting 5 folds for each of 24 candidates, totalling 120 fits
# /usr/local/lib/python3.11/dist-packages/cuml/internals/api_decorators.py:368: UserWarning: For reproducible results in Random Forest Classifier or for almost reproducible results in Random Forest Regressor, n_streams=1 is recommended. If n_streams is > 1, results may vary due to stream/thread timing differences, even when random_state is set
#   return init_func(self, *args, **kwargs)
# /usr/local/lib/python3.11/dist-packages/cuml/internals/api_decorators.py:368: UserWarning: For reproducible results in Random Forest Classifier or for almost reproducible results in Random Forest Regressor, n_streams=1 is recommended. If n_streams is > 1, results may vary due to stream/thread timing differences, even when random_state is set
#   return init_func(self, *args, **kwargs)
# /usr/local/lib/python3.11/dist-packages/cuml/internals/api_decorators.py:368: UserWarning: For reproducible results in Random Forest Classifier or for almost reproducible results in Random Forest Regressor, n_streams=1 is recommended. If n_streams is > 1, results may vary due to stream/thread timing differences, even when random_state is set
#   return init_func(self, *args, **kwargs)
# Fitting 5 folds for each of 24 candidates, totalling 120 fits
# [CV 1/5] END max_depth=None, min_samples_leaf=1, min_samples_split=2, n_estimators=100;, score=nan total time=   0.3s
# [CV 2/5] END max_depth=None, min_samples_leaf=1, min_samples_split=2, n_estimators=100;, score=nan total time=   0.0s
# [CV 3/5] END max_depth=None, min_samples_leaf=1, min_samples_split=2, n_estimators=100;, score=nan total time=   0.0s
# [CV 4/5] END max_depth=None, min_samples_leaf=1, min_samples_split=2, n_estimators=100;, score=nan total time=   0.0s
# [CV 5/5] END max_depth=None, min_samples_leaf=1, min_samples_split=2, n_estimators=100;, score=nan total time=   0.0s
# [CV 1/5] END max_depth=None, min_samples_leaf=1, min_samples_split=2, n_estimators=200;, score=nan total time=   0.0s
# [CV 2/5] END max_depth=None, min_samples_leaf=1, min_samples_split=2, n_estimators=200;, score=nan total time=   0.0s
# [CV 3/5] END max_depth=None, min_samples_leaf=1, min_samples_split=2, n_estimators=200;, score=nan total time=   0.0s
# [CV 4/5] END max_depth=None, min_samples_leaf=1, min_samples_split=2, n_estimators=200;, score=nan total time=   0.0s
# [CV 5/5] END max_depth=None, min_samples_leaf=1, min_samples_split=2, n_estimators=200;, score=nan total time=   0.0s
# [CV 1/5] END max_depth=None, min_samples_leaf=1, min_samples_split=5, n_estimators=100;, score=nan total time=   0.0s
# [CV 2/5] END max_depth=None, min_samples_leaf=1, min_samples_split=5, n_estimators=100;, score=nan total time=   0.0s
# [CV 3/5] END max_depth=None, min_samples_leaf=1, min_samples_split=5, n_estimators=100;, score=nan total time=   0.0s
# [CV 4/5] END max_depth=None, min_samples_leaf=1, min_samples_split=5, n_estimators=100;, score=nan total time=   0.0s
# [CV 5/5] END max_depth=None, min_samples_leaf=1, min_samples_split=5, n_estimators=100;, score=nan total time=   0.0s
# [CV 1/5] END max_depth=None, min_samples_leaf=1, min_samples_split=5, n_estimators=200;, score=nan total time=   0.0s
# [CV 2/5] END max_depth=None, min_samples_leaf=1, min_samples_split=5, n_estimators=200;, score=nan total time=   0.0s
# [CV 3/5] END max_depth=None, min_samples_leaf=1, min_samples_split=5, n_estimators=200;, score=nan total time=   0.0s
# [CV 4/5] END max_depth=None, min_samples_leaf=1, min_samples_split=5, n_estimators=200;, score=nan total time=   0.0s
# [CV 5/5] END max_depth=None, min_samples_leaf=1, min_samples_split=5, n_estimators=200;, score=nan total time=   0.0s
# [CV 1/5] END max_depth=None, min_samples_leaf=2, min_samples_split=2, n_estimators=100;, score=nan total time=   0.0s
# [CV 2/5] END max_depth=None, min_samples_leaf=2, min_samples_split=2, n_estimators=100;, score=nan total time=   0.0s
# [CV 3/5] END max_depth=None, min_samples_leaf=2, min_samples_split=2, n_estimators=100;, score=nan total time=   0.0s
# [CV 4/5] END max_depth=None, min_samples_leaf=2, min_samples_split=2, n_estimators=100;, score=nan total time=   0.0s
# [CV 5/5] END max_depth=None, min_samples_leaf=2, min_samples_split=2, n_estimators=100;, score=nan total time=   0.0s
# [CV 1/5] END max_depth=None, min_samples_leaf=2, min_samples_split=2, n_estimators=200;, score=nan total time=   0.0s
# [CV 2/5] END max_depth=None, min_samples_leaf=2, min_samples_split=2, n_estimators=200;, score=nan total time=   0.0s
# [CV 3/5] END max_depth=None, min_samples_leaf=2, min_samples_split=2, n_estimators=200;, score=nan total time=   0.0s
# [CV 4/5] END max_depth=None, min_samples_leaf=2, min_samples_split=2, n_estimators=200;, score=nan total time=   0.0s
# [CV 5/5] END max_depth=None, min_samples_leaf=2, min_samples_split=2, n_estimators=200;, score=nan total time=   0.0s
# [CV 1/5] END max_depth=None, min_samples_leaf=2, min_samples_split=5, n_estimators=100;, score=nan total time=   0.0s
# [CV 2/5] END max_depth=None, min_samples_leaf=2, min_samples_split=5, n_estimators=100;, score=nan total time=   0.0s
# [CV 3/5] END max_depth=None, min_samples_leaf=2, min_samples_split=5, n_estimators=100;, score=nan total time=   0.0s
# [CV 4/5] END max_depth=None, min_samples_leaf=2, min_samples_split=5, n_estimators=100;, score=nan total time=   0.0s
# [CV 5/5] END max_depth=None, min_samples_leaf=2, min_samples_split=5, n_estimators=100;, score=nan total time=   0.0s
# [CV 1/5] END max_depth=None, min_samples_leaf=2, min_samples_split=5, n_estimators=200;, score=nan total time=   0.0s
# [CV 2/5] END max_depth=None, min_samples_leaf=2, min_samples_split=5, n_estimators=200;, score=nan total time=   0.0s
# [CV 3/5] END max_depth=None, min_samples_leaf=2, min_samples_split=5, n_estimators=200;, score=nan total time=   0.0s
# [CV 4/5] END max_depth=None, min_samples_leaf=2, min_samples_split=5, n_estimators=200;, score=nan total time=   0.0s
# [CV 5/5] END max_depth=None, min_samples_leaf=2, min_samples_split=5, n_estimators=200;, score=nan total time=   0.0s
# [CV 1/5] END max_depth=10, min_samples_leaf=1, min_samples_split=2, n_estimators=100;, score=0.508 total time=   0.6s
# [CV 2/5] END max_depth=10, min_samples_leaf=1, min_samples_split=2, n_estimators=100;, score=0.501 total time=   0.4s
# [CV 3/5] END max_depth=10, min_samples_leaf=1, min_samples_split=2, n_estimators=100;, score=0.495 total time=   0.3s
# [CV 4/5] END max_depth=10, min_samples_leaf=1, min_samples_split=2, n_estimators=100;, score=0.497 total time=   0.4s
# [CV 5/5] END max_depth=10, min_samples_leaf=1, min_samples_split=2, n_estimators=100;, score=0.486 total time=   0.3s
# [CV 1/5] END max_depth=10, min_samples_leaf=1, min_samples_split=2, n_estimators=200;, score=0.507 total time=   0.6s
# [CV 2/5] END max_depth=10, min_samples_leaf=1, min_samples_split=2, n_estimators=200;, score=0.499 total time=   0.5s
# [CV 3/5] END max_depth=10, min_samples_leaf=1, min_samples_split=2, n_estimators=200;, score=0.497 total time=   0.4s
# [CV 4/5] END max_depth=10, min_samples_leaf=1, min_samples_split=2, n_estimators=200;, score=0.495 total time=   0.4s
# [CV 5/5] END max_depth=10, min_samples_leaf=1, min_samples_split=2, n_estimators=200;, score=0.490 total time=   0.4s
# [CV 1/5] END max_depth=10, min_samples_leaf=1, min_samples_split=5, n_estimators=100;, score=0.504 total time=   0.2s
# [CV 2/5] END max_depth=10, min_samples_leaf=1, min_samples_split=5, n_estimators=100;, score=0.502 total time=   0.2s
# [CV 3/5] END max_depth=10, min_samples_leaf=1, min_samples_split=5, n_estimators=100;, score=0.500 total time=   0.2s
# [CV 4/5] END max_depth=10, min_samples_leaf=1, min_samples_split=5, n_estimators=100;, score=0.494 total time=   0.2s
# [CV 5/5] END max_depth=10, min_samples_leaf=1, min_samples_split=5, n_estimators=100;, score=0.492 total time=   0.2s
# [CV 1/5] END max_depth=10, min_samples_leaf=1, min_samples_split=5, n_estimators=200;, score=0.512 total time=   0.5s
# [CV 2/5] END max_depth=10, min_samples_leaf=1, min_samples_split=5, n_estimators=200;, score=0.508 total time=   0.4s
# [CV 3/5] END max_depth=10, min_samples_leaf=1, min_samples_split=5, n_estimators=200;, score=0.498 total time=   0.4s
# [CV 4/5] END max_depth=10, min_samples_leaf=1, min_samples_split=5, n_estimators=200;, score=0.499 total time=   0.4s
# [CV 5/5] END max_depth=10, min_samples_leaf=1, min_samples_split=5, n_estimators=200;, score=0.492 total time=   0.4s
# [CV 1/5] END max_depth=10, min_samples_leaf=2, min_samples_split=2, n_estimators=100;, score=0.503 total time=   0.2s
# [CV 2/5] END max_depth=10, min_samples_leaf=2, min_samples_split=2, n_estimators=100;, score=0.499 total time=   0.2s
# [CV 3/5] END max_depth=10, min_samples_leaf=2, min_samples_split=2, n_estimators=100;, score=0.503 total time=   0.2s
# [CV 4/5] END max_depth=10, min_samples_leaf=2, min_samples_split=2, n_estimators=100;, score=0.488 total time=   0.2s
# [CV 5/5] END max_depth=10, min_samples_leaf=2, min_samples_split=2, n_estimators=100;, score=0.494 total time=   0.2s
# [CV 1/5] END max_depth=10, min_samples_leaf=2, min_samples_split=2, n_estimators=200;, score=0.504 total time=   0.4s
# [CV 2/5] END max_depth=10, min_samples_leaf=2, min_samples_split=2, n_estimators=200;, score=0.504 total time=   0.4s
# [CV 3/5] END max_depth=10, min_samples_leaf=2, min_samples_split=2, n_estimators=200;, score=0.504 total time=   0.4s
# [CV 4/5] END max_depth=10, min_samples_leaf=2, min_samples_split=2, n_estimators=200;, score=0.497 total time=   0.4s
# [CV 5/5] END max_depth=10, min_samples_leaf=2, min_samples_split=2, n_estimators=200;, score=0.490 total time=   0.5s
# [CV 1/5] END max_depth=10, min_samples_leaf=2, min_samples_split=5, n_estimators=100;, score=0.502 total time=   0.2s
# [CV 2/5] END max_depth=10, min_samples_leaf=2, min_samples_split=5, n_estimators=100;, score=0.493 total time=   0.2s
# [CV 3/5] END max_depth=10, min_samples_leaf=2, min_samples_split=5, n_estimators=100;, score=0.493 total time=   0.2s
# [CV 4/5] END max_depth=10, min_samples_leaf=2, min_samples_split=5, n_estimators=100;, score=0.496 total time=   0.2s
# [CV 5/5] END max_depth=10, min_samples_leaf=2, min_samples_split=5, n_estimators=100;, score=0.491 total time=   0.2s
# [CV 1/5] END max_depth=10, min_samples_leaf=2, min_samples_split=5, n_estimators=200;, score=0.508 total time=   0.4s
# [CV 2/5] END max_depth=10, min_samples_leaf=2, min_samples_split=5, n_estimators=200;, score=0.501 total time=   0.6s
# [CV 3/5] END max_depth=10, min_samples_leaf=2, min_samples_split=5, n_estimators=200;, score=0.498 total time=   0.6s
# [CV 4/5] END max_depth=10, min_samples_leaf=2, min_samples_split=5, n_estimators=200;, score=0.492 total time=   0.5s
# [CV 5/5] END max_depth=10, min_samples_leaf=2, min_samples_split=5, n_estimators=200;, score=0.484 total time=   0.5s
# [CV 1/5] END max_depth=20, min_samples_leaf=1, min_samples_split=2, n_estimators=100;, score=0.516 total time=   0.5s
# [CV 2/5] END max_depth=20, min_samples_leaf=1, min_samples_split=2, n_estimators=100;, score=0.502 total time=   0.6s
# [CV 3/5] END max_depth=20, min_samples_leaf=1, min_samples_split=2, n_estimators=100;, score=0.486 total time=   0.5s
# [CV 4/5] END max_depth=20, min_samples_leaf=1, min_samples_split=2, n_estimators=100;, score=0.491 total time=   0.4s
# [CV 5/5] END max_depth=20, min_samples_leaf=1, min_samples_split=2, n_estimators=100;, score=0.486 total time=   0.5s
# [CV 1/5] END max_depth=20, min_samples_leaf=1, min_samples_split=2, n_estimators=200;, score=0.513 total time=   0.9s
# [CV 2/5] END max_depth=20, min_samples_leaf=1, min_samples_split=2, n_estimators=200;, score=0.504 total time=   0.9s
# [CV 3/5] END max_depth=20, min_samples_leaf=1, min_samples_split=2, n_estimators=200;, score=0.489 total time=   0.9s
# [CV 4/5] END max_depth=20, min_samples_leaf=1, min_samples_split=2, n_estimators=200;, score=0.493 total time=   0.8s
# [CV 5/5] END max_depth=20, min_samples_leaf=1, min_samples_split=2, n_estimators=200;, score=0.492 total time=   0.9s
# [CV 1/5] END max_depth=20, min_samples_leaf=1, min_samples_split=5, n_estimators=100;, score=0.496 total time=   0.4s
# [CV 2/5] END max_depth=20, min_samples_leaf=1, min_samples_split=5, n_estimators=100;, score=0.501 total time=   0.4s
# [CV 3/5] END max_depth=20, min_samples_leaf=1, min_samples_split=5, n_estimators=100;, score=0.497 total time=   0.4s
# [CV 4/5] END max_depth=20, min_samples_leaf=1, min_samples_split=5, n_estimators=100;, score=0.490 total time=   0.4s
# [CV 5/5] END max_depth=20, min_samples_leaf=1, min_samples_split=5, n_estimators=100;, score=0.500 total time=   0.4s
# [CV 1/5] END max_depth=20, min_samples_leaf=1, min_samples_split=5, n_estimators=200;, score=0.504 total time=   0.8s
# [CV 2/5] END max_depth=20, min_samples_leaf=1, min_samples_split=5, n_estimators=200;, score=0.494 total time=   0.8s
# [CV 3/5] END max_depth=20, min_samples_leaf=1, min_samples_split=5, n_estimators=200;, score=0.499 total time=   0.9s
# [CV 4/5] END max_depth=20, min_samples_leaf=1, min_samples_split=5, n_estimators=200;, score=0.488 total time=   1.0s
# [CV 5/5] END max_depth=20, min_samples_leaf=1, min_samples_split=5, n_estimators=200;, score=0.496 total time=   1.1s
# [CV 1/5] END max_depth=20, min_samples_leaf=2, min_samples_split=2, n_estimators=100;, score=0.500 total time=   0.6s
# [CV 2/5] END max_depth=20, min_samples_leaf=2, min_samples_split=2, n_estimators=100;, score=0.504 total time=   0.5s
# [CV 3/5] END max_depth=20, min_samples_leaf=2, min_samples_split=2, n_estimators=100;, score=0.499 total time=   0.4s
# [CV 4/5] END max_depth=20, min_samples_leaf=2, min_samples_split=2, n_estimators=100;, score=0.496 total time=   0.4s
# [CV 5/5] END max_depth=20, min_samples_leaf=2, min_samples_split=2, n_estimators=100;, score=0.493 total time=   0.4s
# [CV 1/5] END max_depth=20, min_samples_leaf=2, min_samples_split=2, n_estimators=200;, score=0.502 total time=   0.9s
# [CV 2/5] END max_depth=20, min_samples_leaf=2, min_samples_split=2, n_estimators=200;, score=0.502 total time=   0.8s
# [CV 3/5] END max_depth=20, min_samples_leaf=2, min_samples_split=2, n_estimators=200;, score=0.500 total time=   0.9s
# [CV 4/5] END max_depth=20, min_samples_leaf=2, min_samples_split=2, n_estimators=200;, score=0.489 total time=   0.8s
# [CV 5/5] END max_depth=20, min_samples_leaf=2, min_samples_split=2, n_estimators=200;, score=0.495 total time=   0.8s
# [CV 1/5] END max_depth=20, min_samples_leaf=2, min_samples_split=5, n_estimators=100;, score=0.501 total time=   0.4s
# [CV 2/5] END max_depth=20, min_samples_leaf=2, min_samples_split=5, n_estimators=100;, score=0.491 total time=   0.4s
# [CV 3/5] END max_depth=20, min_samples_leaf=2, min_samples_split=5, n_estimators=100;, score=0.496 total time=   0.4s
# [CV 4/5] END max_depth=20, min_samples_leaf=2, min_samples_split=5, n_estimators=100;, score=0.490 total time=   0.4s
# [CV 5/5] END max_depth=20, min_samples_leaf=2, min_samples_split=5, n_estimators=100;, score=0.488 total time=   0.4s
# [CV 1/5] END max_depth=20, min_samples_leaf=2, min_samples_split=5, n_estimators=200;, score=0.507 total time=   0.8s
# [CV 2/5] END max_depth=20, min_samples_leaf=2, min_samples_split=5, n_estimators=200;, score=0.499 total time=   0.8s
# [CV 3/5] END max_depth=20, min_samples_leaf=2, min_samples_split=5, n_estimators=200;, score=0.500 total time=   0.8s
# [CV 4/5] END max_depth=20, min_samples_leaf=2, min_samples_split=5, n_estimators=200;, score=0.495 total time=   1.0s
# [CV 5/5] END max_depth=20, min_samples_leaf=2, min_samples_split=5, n_estimators=200;, score=0.496 total time=   1.0s
# /usr/local/lib/python3.11/dist-packages/sklearn/model_selection/_validation.py:528: FitFailedWarning:
# 40 fits failed out of a total of 120.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 40 fits failed with the following error:
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.11/dist-packages/sklearn/model_selection/_validation.py", line 866, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/usr/local/lib/python3.11/dist-packages/nvtx/nvtx.py", line 122, in inner
#     result = func(*args, **kwargs)
#              ^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/cuml/internals/api_decorators.py", line 193, in wrapper
#     ret = func(*args, **kwargs)
#           ^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/cuml/internals/api_decorators.py", line 416, in dispatch
#     return self.dispatch_func(func_name, gpu_func, *args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/cuml/internals/api_decorators.py", line 195, in wrapper
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "base.pyx", line 764, in cuml.internals.base.UniversalBase.dispatch_func
#   File "randomforestclassifier.pyx", line 493, in cuml.ensemble.randomforestclassifier.RandomForestClassifier.fit
# TypeError: an integer is required
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# /usr/local/lib/python3.11/dist-packages/sklearn/model_selection/_search.py:1108: UserWarning: One or more of the test scores are non-finite: [       nan        nan        nan        nan        nan        nan
#         nan        nan 0.49742187 0.49746094 0.49843751 0.50175782
#  0.49734375 0.50000001 0.49488281 0.49667969 0.49609374 0.49804688
#  0.49675782 0.49632813 0.49812499 0.49773438 0.49339845 0.499375  ]
#   warnings.warn(
# cuml GridSearchCV training time (RF) : 42.48 seconds
# cuml Best parameters (RF): {'max_depth': 10, 'min_samples_leaf': 1, 'min_samples_split': 5, 'n_estimators': 200}
# scikit-learn GridSearchCV training time (RF) : 1106.22 seconds
# scikit-learn Best parameters (RF): {'max_depth': 20, 'min_samples_leaf': 2, 'min_samples_split': 2, 'n_estimators': 200}

# %% [markdown]
# # Prediction & Model Evaluation

# %%
from sklearn.metrics import accuracy_score, confusion_matrix, ConfusionMatrixDisplay
import matplotlib.pyplot as plt

# --- Comparison and Evaluation ---
model_names = list(sk_models.keys()) # Assuming cu_models will have the same keys if cuML is available

for model_name in model_names:
    print(f"--- Evaluating: {model_name} ---")

    # --- scikit-learn model ---
    if model_name in sk_models:
        print("\n-- scikit-learn --")
        best_sk_model = sk_models[model_name].best_estimator_

        # Predictions
        y_pred_train_sk = best_sk_model.predict(X_train)
        y_pred_test_sk = best_sk_model.predict(X_test)
        start_time = time.time()
        sk_pred[model_name] = best_sk_model.predict(X)
        end_time = time.time()
        sk_pred_times[model_name] = end_time - start_time
        print(f"Prediction Duration: {sk_pred_times[model_name]:.2f} seconds")

        # Accuracy
        train_accuracy_sk = accuracy_score(y_train, y_pred_train_sk)
        test_accuracy_sk = accuracy_score(y_test, y_pred_test_sk)
        sk_train_accuracy[model_name] = train_accuracy_sk
        sk_test_accuracy[model_name] = test_accuracy_sk
        print(f"Train Accuracy: {train_accuracy_sk:.4f}")
        print(f"Test Accuracy: {test_accuracy_sk:.4f}")

        # Cross-validation score
        cv_score_sk = sk_models[model_name].best_score_
        sk_crossValidation_accuracy[model_name] = cv_score_sk
        print(f"Best Cross-Validation Score: {cv_score_sk:.4f}")

        # Duration
        print(f"Training Duration: {sk_times[model_name]:.2f} seconds")

        # Confusion Matrix
        print("Confusion Matrix (Test Set):")
        cm_sk = confusion_matrix(y_test, y_pred_test_sk)
        disp_sk = ConfusionMatrixDisplay(confusion_matrix=cm_sk, display_labels=best_sk_model.classes_)
        disp_sk.plot()
        plt.title(f"scikit-learn {model_name} - Confusion Matrix")
        plt.show()


    # --- cuML model ---
    print("\n-- cuML --")
    if has_cuml and model_name in cu_models:
        best_cu_model = cu_models[model_name].best_estimator_

        # Predictions

        # Note: cuML predict might require cuDF DataFrame or NumPy array
        # Ensuring X_train and X_test are in a compatible format (e.g., NumPy)
        # If they are pandas DataFrames, cuML usually handles them, but explicit conversion can be safer.
        y_pred_train_cu = best_cu_model.predict(X_train.to_numpy() if hasattr(X_train, 'to_numpy') else X_train)
        y_pred_test_cu = best_cu_model.predict(X_test.to_numpy() if hasattr(X_test, 'to_numpy') else X_test)
        start_time = time.time()
        cu_pred[model_name] = best_cu_model.predict(X.to_numpy() if hasattr(X, 'to_numpy') else X)
        end_time = time.time()
        cu_pred_times[model_name] = end_time - start_time
        print(f"Prediction Duration: {cu_pred_times[model_name]:.2f} seconds")

        # If predictions are cuPy arrays, convert them to NumPy for scikit-learn metrics
        if hasattr(y_pred_train_cu, 'get'): # Check if it's a cuPy array
            y_pred_train_cu = y_pred_train_cu.get()
        if hasattr(y_pred_test_cu, 'get'): # Check if it's a cuPy array
            y_pred_test_cu = y_pred_test_cu.get()


        # Accuracy
        train_accuracy_cu = accuracy_score(y_train, y_pred_train_cu) # y_train is pandas Series, compatible
        test_accuracy_cu = accuracy_score(y_test, y_pred_test_cu)   # y_test is pandas Series, compatible
        cu_train_accuracy[model_name] = train_accuracy_cu
        cu_test_accuracy[model_name] = test_accuracy_cu
        print(f"Train Accuracy: {train_accuracy_cu:.4f}")
        print(f"Test Accuracy: {test_accuracy_cu:.4f}")

        # Cross-validation score
        cv_score_cu = cu_models[model_name].best_score_
        cu_crossValidation_accuracy[f"cu_{model_name}"] = cv_score_cu
        print(f"Best Cross-Validation Score: {cv_score_cu:.4f}")

        # Duration
        # if model_name in cu_times: # Check if cu_times was populated
        print(f"Training Duration: {cu_times[model_name]:.2f} seconds")

        # Confusion Matrix
        print("Confusion Matrix (Test Set):")
        cm_cu = confusion_matrix(y_test, y_pred_test_cu)
        # Ensure classes are correctly obtained for cuML model if different from sklearn
        # For SVC, .classes_ should be available after fitting.
        disp_cu = ConfusionMatrixDisplay(confusion_matrix=cm_cu, display_labels=best_cu_model.classes_)
        disp_cu.plot()
        plt.title(f"cuML {model_name} - Confusion Matrix")
        plt.show()
    else:
        print(f"cuML {model_name} was not run as cuML model for it is not available.")

    print("\n" + "="*40 + "\n")

print("\nSummary of Accuracies and Times:")
print("scikit-learn Train Accuracies:", sk_train_accuracy)
print("CuML Train Accuracies:", cu_train_accuracy)
print("scikit-learn Test Accuracies:", sk_test_accuracy)
print("CuML Test Accuracies:", cu_test_accuracy)
print("scikit-learn Cross-Validation Accuracies:", sk_crossValidation_accuracy)
print("CuML Cross-Validation Accuracies:", cu_crossValidation_accuracy)
print("scikit-learn Training Times:", sk_times)
print("cuML Training Times:", cu_times)
print("scikit-learn Prediction Times:", sk_pred_times)
print("cuML Prediction Times:", cu_pred_times)
# Out:
# --- Evaluating: SVM ---
#
# -- scikit-learn --
# Prediction Duration: 39.54 seconds
# Train Accuracy: 0.5269
# Test Accuracy: 0.5058
# Best Cross-Validation Score: 0.5012
# Training Duration: 692.15 seconds
# Confusion Matrix (Test Set):
# -- cuML --
# Prediction Duration: 0.29 seconds
# Train Accuracy: 0.5268
# Test Accuracy: 0.5061
# Best Cross-Validation Score: 0.5012
# Training Duration: 67.48 seconds
# Confusion Matrix (Test Set):
# ========================================
#
# --- Evaluating: KNN ---
#
# -- scikit-learn --
# Prediction Duration: 3.82 seconds
# Train Accuracy: 0.7422
# Test Accuracy: 0.4830
# Best Cross-Validation Score: 0.4985
# Training Duration: 98.12 seconds
# Confusion Matrix (Test Set):
# -- cuML --
# Prediction Duration: 0.06 seconds
# Train Accuracy: 0.7422
# Test Accuracy: 0.4830
# Best Cross-Validation Score: 0.4985
# Training Duration: 3.00 seconds
# Confusion Matrix (Test Set):
# ========================================
#
# --- Evaluating: RF ---
#
# -- scikit-learn --
# Prediction Duration: 0.72 seconds
# Train Accuracy: 0.9936
# Test Accuracy: 0.5027
# Best Cross-Validation Score: 0.5035
# Training Duration: 1106.22 seconds
# Confusion Matrix (Test Set):
# -- cuML --
# Prediction Duration: 0.02 seconds
# Train Accuracy: 0.8300
# Test Accuracy: 0.4945
# Best Cross-Validation Score: 0.5018
# Training Duration: 42.48 seconds
# Confusion Matrix (Test Set):
# ========================================
#
#
# Summary of Accuracies and Times:
# scikit-learn Train Accuracies: {'SVM': 0.526875, 'KNN': 0.7422265625, 'RF': 0.9936328125}
# CuML Train Accuracies: {'SVM': 0.5268359375, 'KNN': 0.7422265625, 'RF': 0.8299609375}
# scikit-learn Test Accuracies: {'SVM': 0.50578125, 'KNN': 0.48296875, 'RF': 0.50265625}
# CuML Test Accuracies: {'SVM': 0.50609375, 'KNN': 0.48296875, 'RF': 0.49453125}
# scikit-learn Cross-Validation Accuracies: {'SVM': np.float64(0.501171875), 'KNN': np.float64(0.498515625), 'RF': np.float64(0.503515625)}
# CuML Cross-Validation Accuracies: {'cu_SVM': np.float64(0.5011718809604645), 'cu_KNN': np.float64(0.4985156297683716), 'cu_RF': np.float64(0.501757824420929)}
# scikit-learn Training Times: {'SVM': 692.1462740898132, 'KNN': 98.12269520759583, 'RF': 1106.2223761081696}
# cuML Training Times: {'SVM': 67.48255920410156, 'KNN': 2.9994659423828125, 'RF': 42.48158645629883}
# scikit-learn Prediction Times: {'SVM': 39.54344201087952, 'KNN': 3.824047565460205, 'RF': 0.7215895652770996}
# cuML Prediction Times: {'SVM': 0.2873575687408447, 'KNN': 0.0649406909942627, 'RF': 0.023798465728759766}

# %%
import matplotlib.pyplot as plt
import matplotlib.colors as mcolors
import pandas as pd

# Ensure all necessary variables are defined from previous cells:
# data, df, y, sk_pred, cu_pred, has_cuml (for cuML models)
# X (to get the index for aligning predictions if they are numpy arrays)

if 'DEPT' not in data.columns:
    print("Error: 'DEPT' column not found in data DataFrame. Cannot generate depth plots.")
else:
    depth_column = data['DEPT']
    feature_names = df.columns.tolist()

    # Prepare labels and predictions (same as before)
    true_labels = y
    all_predictions_to_plot = {}
    all_predictions_to_plot['True Labels'] = true_labels
    for model_name, preds in sk_pred.items():
        all_predictions_to_plot[f'SK: {model_name}'] = preds
    if has_cuml and cu_pred:
        for model_name, preds_cu in cu_pred.items():
            if hasattr(preds_cu, 'get'):
                preds_np = preds_cu.get()
            else:
                preds_np = preds_cu
            all_predictions_to_plot[f'CU: {model_name}'] = preds_np

    # Define colors for classes (same as before)
    if isinstance(true_labels, np.ndarray):
        unique_classes = np.sort(np.unique(true_labels))
    else:
        unique_classes = np.sort(true_labels.unique())

    if len(unique_classes) == 1:
        plot_colors = ['gold']
    elif len(unique_classes) == 2:
        plot_colors = ['gold', 'darkorange']
    else:
        cmap_tab10 = plt.cm.get_cmap('tab10', len(unique_classes))
        plot_colors = [mcolors.to_hex(cmap_tab10(i)) for i in range(len(unique_classes))]

    class_to_int = {cls: i for i, cls in enumerate(unique_classes)}
    cmap_listed = mcolors.ListedColormap(plot_colors[:len(unique_classes)])


    # --- Figure 1: feature Tracks ---
    num_feature_plots = len(feature_names)
    if num_feature_plots > 0:
        fig_features, axes_features = plt.subplots(1, num_feature_plots, figsize=(num_feature_plots * 2.5, 10), sharey=True)
        if num_feature_plots == 1: # Handle single feature case for axes indexing
            axes_features = [axes_features]
        fig_features.suptitle("Feature Tracks", fontsize=16, y=0.98)

        for i, feature_name in enumerate(feature_names):
            ax = axes_features[i]
            ax.plot(data[feature_name].loc[X.index], depth_column.loc[X.index])
            ax.set_title(feature_name, fontsize=10)
            ax.set_xlabel("Value", fontsize=8)
            if i == 0:
                ax.set_ylabel("DEPT (feet)", fontsize=10)
            ax.grid(True, linestyle='--', alpha=0.7)
            ax.tick_params(axis='x', labelsize=8)
            ax.tick_params(axis='y', labelsize=8)

        axes_features[0].invert_yaxis()
        plt.tight_layout(rect=[0, 0.03, 1, 0.95])
        plt.show()
    else:
        print("No features to plot for feature tracks.")

    # --- Figure 2: scaled feature Tracks ---
    num_feature_plots = len(feature_names)
    if num_feature_plots > 0:
        fig_features, axes_features = plt.subplots(1, num_feature_plots, figsize=(num_feature_plots * 2.5, 10), sharey=True)
        if num_feature_plots == 1: # Handle single feature case for axes indexing
            axes_features = [axes_features]
        fig_features.suptitle("Scaled Feature Tracks", fontsize=16, y=0.98)

        for i, feature_name in enumerate(feature_names):
            ax = axes_features[i]
            ax.plot(X[feature_name].loc[X.index], depth_column.loc[X.index])
            ax.set_title(feature_name, fontsize=10)
            ax.set_xlabel("Value", fontsize=8)
            if i == 0:
                ax.set_ylabel("DEPT (feet)", fontsize=10)
            ax.grid(True, linestyle='--', alpha=0.7)
            ax.tick_params(axis='x', labelsize=8)
            ax.tick_params(axis='y', labelsize=8)

        axes_features[0].invert_yaxis()
        plt.tight_layout(rect=[0, 0.03, 1, 0.95])
        plt.show()
    else:
        print("No features to plot for scaled feature tracks.")

    # --- Figure 3: Classification Tracks ---
    num_classification_plots = len(all_predictions_to_plot)
    if num_classification_plots > 0:
        # Adjust figsize: width per plot can be smaller for classification tracks
        fig_class, axes_class = plt.subplots(1, num_classification_plots, figsize=(num_classification_plots * 1.2, 10), sharey=True)
        if num_classification_plots == 1: # Handle single classification plot case
            axes_class = [axes_class]
        fig_class.suptitle("Classification Tracks", fontsize=16, y=0.98)

        plot_order = ['True Labels'] + [k for k in all_predictions_to_plot.keys() if k != 'True Labels']

        for i, title in enumerate(plot_order):
            predictions_data = all_predictions_to_plot[title]
            ax = axes_class[i]

            if isinstance(predictions_data, pd.Series):
                if not predictions_data.index.equals(X.index):
                    # This should ideally not happen with consistent data handling
                    # For safety, one might reindex or ensure alignment upstream
                    print(f"Warning: Index mismatch for {title}. Plotting may be incorrect.")
                mapped_preds = predictions_data.map(class_to_int).fillna(-1)
            elif isinstance(predictions_data, np.ndarray):
                temp_series = pd.Series(predictions_data, index=X.index)
                mapped_preds = temp_series.map(class_to_int).fillna(-1)
            else:
                print(f"Warning: Data for {title} is of unexpected type: {type(predictions_data)}")
                continue

            labels_int = mapped_preds.values.reshape(-1, 1)
            vmin = 0
            vmax = len(plot_colors) - 1

            ax.imshow(labels_int, aspect='auto', cmap=cmap_listed,
                      extent=[0, 1, depth_column.loc[X.index].max(), depth_column.loc[X.index].min()],
                      interpolation='none', vmin=vmin, vmax=vmax)

            if title == 'True Labels':
                ax.set_title("True Class", fontsize=10)
            else:
                ax.set_title(title, fontsize=10)

            ax.set_xticks([])
            ax.set_xlabel("")
            ax.tick_params(axis='y', labelsize=8)
            if i == 0: # Set Y-axis label only for the first plot in this figure
                ax.set_ylabel("DEPT (feet)", fontsize=10)


        axes_class[0].invert_yaxis()

        if unique_classes is not None and len(unique_classes) > 0:
            patches = [plt.Rectangle((0,0),1,1, color=plot_colors[class_to_int[cls]]) for cls in unique_classes]
            legend_labels = [str(cls) for cls in unique_classes]
            fig_class.legend(patches, legend_labels, loc='lower center', ncol=len(unique_classes), bbox_to_anchor=(0.5, -0.02), title="Classes")

        plt.tight_layout(rect=[0, 0.03, 1, 0.93])
        plt.show()
    else:
        print("No classification data to plot.")

# %% [markdown]
# # Shutdown colab runtime

# %%
# Execution time
end_notebook = time.time()
print(f"Total notebook execution time: {end_notebook - start_notebook:.2f} seconds")
# Out:
# Total notebook execution time: 2118.15 seconds

# %%
if is_running_on_colab:
    from google.colab import runtime
    runtime.unassign()
