# %% [markdown]
# # Retrieve data

# %%
try:
    from google.colab import drive
    is_running_on_colab = True
except ImportError:
    is_running_on_colab = False

if is_running_on_colab:
    # Mount Google Drive
    drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import time
start_notebook = time.time()

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
import numpy as np

# %%
# Option to generate mock data
generate_mock_data = True # Set to True to generate mock data
max_mock_depth_ft = 1000 # Define maximum depth for mock data

# %%
well_name = "LLB-10"
if not generate_mock_data:
  if is_running_on_colab:
    # Load data from Google Drive, if running on Google Colab
    colab_repo_dir = "/content/drive/MyDrive/riset-fttm-gdrive/cuml-tf-model-hydrocarbon-prediction"
    data = pd.read_csv(f"{colab_repo_dir}/data/interpreted/interpreted_{well_name}.csv", sep=',')
  else:
    # Load data from local directory
    data = pd.read_csv(f"./data/interpreted/interpreted_{well_name}.csv", sep=',')

# %%
if generate_mock_data:
    print(f"Generating mock data up to {max_mock_depth_ft} ft for well {well_name}...")
    mock_depth_step = 0.5
    mock_dept_values = np.arange(0, max_mock_depth_ft, mock_depth_step)
    num_mock_rows = len(mock_dept_values)

    mock_data_dict = {'DEPT': mock_dept_values}

    feature_cols_for_mock = ['CALI','DRHO','GR','MR','NPHI_corr','PEF','RHOB_CORR','ROP']

    for col in feature_cols_for_mock:
        mock_data_dict[col] = np.random.rand(num_mock_rows) * 100

    mock_data_dict['hydrocarbon_formation_class'] = np.random.randint(0, 2, num_mock_rows)

    data = pd.DataFrame(mock_data_dict)

    print(f"Mock data generated for well {well_name} with {num_mock_rows} rows and columns: {list(data.columns)}.")
    print("Mock data head:")
    print(data.head())
# Out:
# Generating mock data up to 1000 ft for well LLB-10...
# Mock data generated for well LLB-10 with 2000 rows and columns: ['DEPT', 'CALI', 'DRHO', 'GR', 'MR', 'NPHI_corr', 'PEF', 'RHOB_CORR', 'ROP', 'hydrocarbon_formation_class'].
# Mock data head:
#    DEPT       CALI       DRHO         GR         MR  NPHI_corr        PEF  \
# 0   0.0  13.929844  58.956658  94.430265  67.246590  39.212149  12.210139
# 1   0.5  66.437905  79.275124  37.509299  24.839250  25.963817  20.373975
# 2   1.0   4.659380  50.675624   1.636482  63.152331  92.038636  35.917487
# 3   1.5   5.431927  28.416795  77.211597   9.068387  57.114344  59.287452
# 4   2.0  61.133847  47.338714  32.001584  12.724887  23.466708   0.204354
#
#    RHOB_CORR        ROP  hydrocarbon_formation_class
# 0   9.090285  83.354582                            1
# 1  39.844827  20.869419                            1
# 2  46.127813  72.208693                            1
# 3  22.121539   0.558523                            0
# 4  29.752109  90.825776                            0

# %%
df=data[['CALI','DRHO','GR','MR','NPHI_corr','PEF','RHOB_CORR','ROP']]
df
# Out:
#            CALI       DRHO         GR         MR  NPHI_corr        PEF  \
# 0     13.929844  58.956658  94.430265  67.246590  39.212149  12.210139
# 1     66.437905  79.275124  37.509299  24.839250  25.963817  20.373975
# 2      4.659380  50.675624   1.636482  63.152331  92.038636  35.917487
# 3      5.431927  28.416795  77.211597   9.068387  57.114344  59.287452
# 4     61.133847  47.338714  32.001584  12.724887  23.466708   0.204354
# ...         ...        ...        ...        ...        ...        ...
# 1995   7.724894  37.437063  65.946767  53.214652  78.507411  21.873423
# 1996  66.983557   7.979541  69.205180  10.297985  28.668229   7.157934
# 1997  43.975467   0.590958  62.343518  95.854175  26.343091  47.785300
# 1998  74.840260  81.449673  32.859536  97.871247  95.233721  60.366188
# 1999  42.418289   2.534290  12.505234  76.759207  19.437367  77.278247
#
#       RHOB_CORR        ROP
# 0      9.090285  83.354582
# 1     39.844827  20.869419
# 2     46.127813  72.208693
# 3     22.121539   0.558523
# 4     29.752109  90.825776
# ...         ...        ...
# 1995  58.758639   4.151754
# 1996  24.836377  86.585239
# 1997  79.464363  17.253864
# 1998  95.694581  89.714273
# 1999  66.113654   6.571644
#
# [2000 rows x 8 columns]

# %% [markdown]
# # Data Preparation

# %% [markdown]
# ## Train/Test Splitting

# %%
# Misalkan 'data' adalah DataFrame Anda dan 'df' adalah fitur yang telah Anda ekstrak
X = df  # Fitur
y = data['hydrocarbon_formation_class']  # Label

# Split data menjadi training dan testing set
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, stratify=y, random_state=42)

# %%
X_train.describe()
# Out:
#               CALI         DRHO           GR           MR    NPHI_corr  \
# count  1600.000000  1600.000000  1600.000000  1600.000000  1600.000000
# mean     50.413186    51.049927    50.479213    51.013623    50.005811
# std      28.698990    28.577547    28.993585    28.871523    29.128937
# min       0.051574     0.300916     0.020064     0.195486     0.048359
# 25%      25.444952    25.870621    25.261992    25.881201    23.625738
# 50%      50.111314    51.583273    51.497955    51.091817    51.005161
# 75%      75.139117    75.467058    76.172844    76.561026    75.330138
# max      99.942879    99.906018    99.875737    99.788688    99.988659
#
#                PEF    RHOB_CORR          ROP
# count  1600.000000  1600.000000  1600.000000
# mean     50.231209    49.560694    49.395568
# std      28.725335    28.811350    29.694598
# min       0.027238     0.090558     0.016407
# 25%      25.453975    24.607189    24.088139
# 50%      50.185224    49.269531    48.932943
# 75%      74.452136    74.387742    74.867605
# max      99.991191    99.922640    99.985159

# %% [markdown]
# ## Apply Quantile Transformation

# %%
from sklearn.preprocessing import QuantileTransformer
def transform_quantile(X_train, X_test, X):
    qt_transformer = QuantileTransformer(output_distribution='normal')
    dfs = [X_train, X_test, X]
    qt_dfs = [None,None,None]
    for i, df in enumerate(dfs):
        if (i == 0): #only perform fit_transform on training data
            qt_dfs[i] = pd.DataFrame(qt_transformer.fit_transform(df))
        else:
            qt_dfs[i] = pd.DataFrame(qt_transformer.transform(df))
        qt_dfs[i].columns = df.columns.values
        qt_dfs[i].index = df.index.values
    return qt_dfs[0], qt_dfs[1], qt_dfs[2] #X_train, X_test, X

# %%
X_train, X_test, X = transform_quantile(X_train, X_test, X)

# %% [markdown]
# ## Feature Scaling
#
# karena menggunakan Quatile transformation dengan output gaussian, masing masing kolom secara otomatis ditransformasi ke distribusi normal baku, atau distribusi normal dengan rataan nol dan standar deviasi 1, oleh karena itu tidak diperlukan tambahan scaling.

# %%
X_train.describe()
# Out:
#               CALI         DRHO           GR           MR    NPHI_corr  \
# count  1600.000000  1600.000000  1600.000000  1600.000000  1600.000000
# mean      0.000035    -0.000220     0.000022    -0.000291     0.000077
# std       1.012289     1.013539     1.012354     1.013260     1.012474
# min      -5.199338    -5.199338    -5.199338    -5.199338    -5.199338
# 25%      -0.674448    -0.674766    -0.674658    -0.675116    -0.674513
# 50%      -0.000423    -0.000018    -0.001120    -0.000090     0.000012
# 75%       0.675032     0.673811     0.674267     0.674218     0.674532
# max       5.199338     5.199338     5.199338     5.199338     5.199338
#
#                PEF    RHOB_CORR          ROP
# count  1600.000000  1600.000000  1600.000000
# mean     -0.000407    -0.000173     0.000132
# std       1.013292     1.012886     1.012847
# min      -5.199338    -5.199338    -5.199338
# 25%      -0.674488    -0.674890    -0.674356
# 50%       0.000807     0.000023     0.000030
# 75%       0.674638     0.674400     0.674497
# max       5.199338     5.199338     5.199338

# %% [markdown]
# # Training setup

# %%
import time
import numpy as np
from sklearn.model_selection import GridSearchCV


sk_train_accuracy={}
sk_test_accuracy={}

cu_train_accuracy={}
cu_test_accuracy={}

sk_crossValidation_accuracy={}
cu_crossValidation_accuracy={}

sk_models = {} #sklearn models
cu_models = {} #cuml models

sk_times = {}
cu_times = {}

sk_pred = {}
cu_pred = {}

sk_pred_times = {}
cu_pred_times = {}

# %%
# test CuML availability & is working
try:
    import cuml
    kmeans = cuml.KMeans(n_clusters=2)
    # Create minimal dummy data
    dummy_data = np.array([[1, 2], [1.5, 1.8], [5, 8], [8, 8]])
    kmeans.fit(dummy_data)
    # Attempt to fit the model
    has_cuml = True
    print("cuML is found and working")
except ImportError:
    has_cuml = False
    print("cuML not found. Please ensure cuML is installed.")
except Exception as e:
    has_cuml = False
    print(f"cuML couldn't be initialized or used. Error: {e}")
# Out:
# cuML is found and working
# /usr/local/lib/python3.11/dist-packages/cuml/internals/api_decorators.py:195: FutureWarning: The default value of `n_init` will change from 1 to 'auto' in 25.04. Set the value of `n_init` explicitly to suppress this warning.
#   return func(*args, **kwargs)

# %% [markdown]
# # Models

# %% [markdown]
# ## SVM

# %%
model_name = "SVM"

# %%
from sklearn.svm import SVC as SklearnSVC
# Attempt to import cuML's SVC
try:
    from cuml.svm import SVC as cuMLSVC
except ImportError:
    print("cuML SVC not available. Please ensure cuML is installed and compatible with your environment.")

# %%
# Parameter grid for both models
param_grid = {
    'C': [0.1, 1, 10],
    'gamma': ['scale', 'auto']
}

# 1) scikit-learn SVM with GridSearchCV
sk_models[model_name] = GridSearchCV(
    estimator=SklearnSVC(kernel='rbf'),
    param_grid=param_grid,
    cv=5,
    verbose=3,
    n_jobs=-1
)

time_start = time.time()
sk_models[model_name].fit(X_train, y_train)
time_end = time.time()
sk_times[model_name] = time_end - time_start

# 2) cuML SVM with the same GridSearchCV
if has_cuml:
    cu_models[model_name] = GridSearchCV(
        estimator=cuMLSVC(kernel='rbf'),
        param_grid=param_grid,
        cv=5,
        verbose=3,
        # Note: cuML estimator runs on GPU; this grid search runs on CPU orchestrating GPU calls
        n_jobs=1  # avoid multiprocessing issues with GPU
    )

    time_start = time.time()
    cu_models[model_name].fit(X_train, y_train)
    time_end = time.time()
    cu_times[model_name] = time_end - time_start
    print(f"cuml GridSearchCV training time ({model_name}) : {cu_times[model_name]:.2f} seconds")
    print(f"cuml Best parameters ({model_name}): {cu_models[model_name].best_params_}")
else:
    print("cuML is not installed or GPU not available. Please install RAPIDS cuML to run this benchmark.")

print(f"scikit-learn GridSearchCV training time ({model_name}) : {sk_times[model_name]:.2f} seconds")
print(f"scikit-learn Best parameters ({model_name}): {sk_models[model_name].best_params_}")
# Out:
# Fitting 5 folds for each of 6 candidates, totalling 30 fits
# Fitting 5 folds for each of 6 candidates, totalling 30 fits
# [CV 1/5] END ................C=0.1, gamma=scale;, score=0.512 total time=   3.3s
# [CV 2/5] END ................C=0.1, gamma=scale;, score=0.516 total time=   0.1s
# [CV 3/5] END ................C=0.1, gamma=scale;, score=0.512 total time=   0.1s
# [CV 4/5] END ................C=0.1, gamma=scale;, score=0.506 total time=   0.1s
# [CV 5/5] END ................C=0.1, gamma=scale;, score=0.509 total time=   0.0s
# [CV 1/5] END .................C=0.1, gamma=auto;, score=0.512 total time=   0.0s
# [CV 2/5] END .................C=0.1, gamma=auto;, score=0.516 total time=   0.0s
# [CV 3/5] END .................C=0.1, gamma=auto;, score=0.512 total time=   0.0s
# [CV 4/5] END .................C=0.1, gamma=auto;, score=0.506 total time=   0.0s
# [CV 5/5] END .................C=0.1, gamma=auto;, score=0.509 total time=   0.0s
# [CV 1/5] END ..................C=1, gamma=scale;, score=0.475 total time=   0.0s
# [CV 2/5] END ..................C=1, gamma=scale;, score=0.481 total time=   0.0s
# [CV 3/5] END ..................C=1, gamma=scale;, score=0.522 total time=   0.0s
# [CV 4/5] END ..................C=1, gamma=scale;, score=0.494 total time=   0.0s
# [CV 5/5] END ..................C=1, gamma=scale;, score=0.453 total time=   0.0s
# [CV 1/5] END ...................C=1, gamma=auto;, score=0.472 total time=   0.0s
# [CV 2/5] END ...................C=1, gamma=auto;, score=0.481 total time=   0.0s
# [CV 3/5] END ...................C=1, gamma=auto;, score=0.525 total time=   0.0s
# [CV 4/5] END ...................C=1, gamma=auto;, score=0.506 total time=   0.0s
# [CV 5/5] END ...................C=1, gamma=auto;, score=0.453 total time=   0.0s
# [2025-05-27 14:59:23.542] [CUML] [warning] Warning: could not fill working set, found only 999 elements
# [2025-05-27 14:59:23.554] [CUML] [warning] Warning: could not fill working set, found only 955 elements
# [2025-05-27 14:59:23.591] [CUML] [warning] Warning: could not fill working set, found only 1000 elements
# [2025-05-27 14:59:23.632] [CUML] [warning] Warning: could not fill working set, found only 963 elements
# [2025-05-27 14:59:23.652] [CUML] [warning] Warning: could not fill working set, found only 1000 elements
# [CV 1/5] END .................C=10, gamma=scale;, score=0.478 total time=   0.2s
# [2025-05-27 14:59:23.727] [CUML] [warning] Warning: could not fill working set, found only 995 elements
# [2025-05-27 14:59:23.742] [CUML] [warning] Warning: could not fill working set, found only 965 elements
# [2025-05-27 14:59:23.779] [CUML] [warning] Warning: could not fill working set, found only 992 elements
# [2025-05-27 14:59:23.824] [CUML] [warning] Warning: could not fill working set, found only 966 elements
# [2025-05-27 14:59:23.839] [CUML] [warning] Warning: could not fill working set, found only 993 elements
# [CV 2/5] END .................C=10, gamma=scale;, score=0.500 total time=   0.2s
# [2025-05-27 14:59:23.916] [CUML] [warning] Warning: could not fill working set, found only 1017 elements
# [2025-05-27 14:59:23.938] [CUML] [warning] Warning: could not fill working set, found only 941 elements
# [2025-05-27 14:59:23.977] [CUML] [warning] Warning: could not fill working set, found only 1017 elements
# [2025-05-27 14:59:24.022] [CUML] [warning] Warning: could not fill working set, found only 938 elements
# [2025-05-27 14:59:24.028] [CUML] [warning] Warning: could not fill working set, found only 1017 elements
# [CV 3/5] END .................C=10, gamma=scale;, score=0.528 total time=   0.2s
# [2025-05-27 14:59:24.108] [CUML] [warning] Warning: could not fill working set, found only 1010 elements
# [2025-05-27 14:59:24.120] [CUML] [warning] Warning: could not fill working set, found only 955 elements
# [2025-05-27 14:59:24.154] [CUML] [warning] Warning: could not fill working set, found only 1007 elements
# [2025-05-27 14:59:24.199] [CUML] [warning] Warning: could not fill working set, found only 954 elements
# [2025-05-27 14:59:24.225] [CUML] [warning] Warning: could not fill working set, found only 1007 elements
# [CV 4/5] END .................C=10, gamma=scale;, score=0.541 total time=   0.2s
# [2025-05-27 14:59:24.301] [CUML] [warning] Warning: could not fill working set, found only 1022 elements
# [2025-05-27 14:59:24.315] [CUML] [warning] Warning: could not fill working set, found only 952 elements
# [2025-05-27 14:59:24.361] [CUML] [warning] Warning: could not fill working set, found only 995 elements
# [2025-05-27 14:59:24.413] [CUML] [warning] Warning: could not fill working set, found only 953 elements
# [2025-05-27 14:59:24.438] [CUML] [warning] Warning: could not fill working set, found only 996 elements
# [CV 5/5] END .................C=10, gamma=scale;, score=0.459 total time=   0.2s
# [2025-05-27 14:59:24.515] [CUML] [warning] Warning: could not fill working set, found only 1001 elements
# [2025-05-27 14:59:24.526] [CUML] [warning] Warning: could not fill working set, found only 954 elements
# [2025-05-27 14:59:24.561] [CUML] [warning] Warning: could not fill working set, found only 1000 elements
# [2025-05-27 14:59:24.608] [CUML] [warning] Warning: could not fill working set, found only 958 elements
# [2025-05-27 14:59:24.631] [CUML] [warning] Warning: could not fill working set, found only 1002 elements
# [CV 1/5] END ..................C=10, gamma=auto;, score=0.481 total time=   0.2s
# [2025-05-27 14:59:24.707] [CUML] [warning] Warning: could not fill working set, found only 1003 elements
# [2025-05-27 14:59:24.722] [CUML] [warning] Warning: could not fill working set, found only 961 elements
# [2025-05-27 14:59:24.759] [CUML] [warning] Warning: could not fill working set, found only 996 elements
# [2025-05-27 14:59:24.798] [CUML] [warning] Warning: could not fill working set, found only 962 elements
# [2025-05-27 14:59:24.807] [CUML] [warning] Warning: could not fill working set, found only 998 elements
# [CV 2/5] END ..................C=10, gamma=auto;, score=0.503 total time=   0.2s
# [2025-05-27 14:59:24.887] [CUML] [warning] Warning: could not fill working set, found only 1015 elements
# [2025-05-27 14:59:24.910] [CUML] [warning] Warning: could not fill working set, found only 945 elements
# [2025-05-27 14:59:24.946] [CUML] [warning] Warning: could not fill working set, found only 1014 elements
# [2025-05-27 14:59:24.993] [CUML] [warning] Warning: could not fill working set, found only 936 elements
# [2025-05-27 14:59:25.002] [CUML] [warning] Warning: could not fill working set, found only 1014 elements
# [CV 3/5] END ..................C=10, gamma=auto;, score=0.531 total time=   0.2s
# [2025-05-27 14:59:25.078] [CUML] [warning] Warning: could not fill working set, found only 1007 elements
# [2025-05-27 14:59:25.090] [CUML] [warning] Warning: could not fill working set, found only 949 elements
# [2025-05-27 14:59:25.127] [CUML] [warning] Warning: could not fill working set, found only 1008 elements
# [2025-05-27 14:59:25.169] [CUML] [warning] Warning: could not fill working set, found only 950 elements
# [2025-05-27 14:59:25.190] [CUML] [warning] Warning: could not fill working set, found only 1010 elements
# [CV 4/5] END ..................C=10, gamma=auto;, score=0.544 total time=   0.2s
# [2025-05-27 14:59:25.263] [CUML] [warning] Warning: could not fill working set, found only 1020 elements
# [2025-05-27 14:59:25.278] [CUML] [warning] Warning: could not fill working set, found only 950 elements
# [2025-05-27 14:59:25.326] [CUML] [warning] Warning: could not fill working set, found only 998 elements
# [2025-05-27 14:59:25.379] [CUML] [warning] Warning: could not fill working set, found only 937 elements
# [2025-05-27 14:59:25.405] [CUML] [warning] Warning: could not fill working set, found only 997 elements
# [CV 5/5] END ..................C=10, gamma=auto;, score=0.456 total time=   0.2s
# cuml GridSearchCV training time (SVM) : 6.07 seconds
# cuml Best parameters (SVM): {'C': 0.1, 'gamma': 'scale'}
# scikit-learn GridSearchCV training time (SVM) : 6.64 seconds
# scikit-learn Best parameters (SVM): {'C': 0.1, 'gamma': 'scale'}

# %% [markdown]
# ## K-Nearest Neighbors

# %%
model_name = "KNN"

# %%
from sklearn.neighbors import KNeighborsClassifier as SklearnKNeighborsClassifier
# Attempt to import cuML's KNeighborsClassifier
try:
    from cuml.neighbors import KNeighborsClassifier as cuMLKNeighborsClassifier
    # has_cuml is already defined from SVM section, assuming if SVM cuml is available, KNN cuml is too.
except ImportError:
    # If cuML was previously found but KNN specific part is missing, update has_cuml for KNN context if necessary
    # For simplicity, we rely on the initial has_cuml check. If specific components are missing,
    # the cuML KNN block will be skipped or error out, which is acceptable.
    # A more robust check could be:
    # try: from cuml.svm import SVC as cuMLSVC; has_cuml_svm = True except: has_cuml_svm = False
    # try: from cuml.neighbors import KNeighborsClassifier as cuMLKNeighborsClassifier; has_cuml_knn = True except: has_cuml_knn = False
    pass # Rely on global has_cuml

# %%
# Parameter grid for KNN
param_grid_knn = {
    'n_neighbors': [3, 5, 7, 9, 11],
    'weights': ['uniform', 'distance'],
    'metric': ['euclidean', 'manhattan']
}

# 1) scikit-learn KNN with GridSearchCV
sk_models[model_name] = GridSearchCV(
    estimator=SklearnKNeighborsClassifier(),
    param_grid=param_grid_knn,
    cv=5,
    verbose=3,
    n_jobs=-1
)

time_start = time.time()
sk_models[model_name].fit(X_train, y_train)
time_end = time.time()
sk_times[model_name] = time_end - time_start

# 2) cuML KNN with the same GridSearchCV (adapted for cuML)
if has_cuml:
    try:
        # Ensure cuMLKNeighborsClassifier was imported
        cuMLKNeighborsClassifier

        cu_models[model_name] = GridSearchCV(
            estimator=cuMLKNeighborsClassifier(), # cuML KNN
            param_grid=param_grid_knn, # Using the same grid, ensure params are compatible
            cv=5,
            verbose=3,
            n_jobs=1 # Potentially can be >1 if managed carefully, but 1 is safer for GPU resources with GridSearchCV
        )

        time_start = time.time()
        # cuML's KNN might prefer numpy arrays or cuDF dataframes
        # X_train and y_train are pandas, which cuml usually handles.
        # If issues arise, convert: X_train_cu = X_train.to_numpy(), y_train_cu = y_train.to_numpy()
        cu_models[model_name].fit(X_train, y_train)
        time_end = time.time()
        cu_times[model_name] = time_end - time_start
        print(f"cuml GridSearchCV training time ({model_name}) : {cu_times[model_name]:.2f} seconds")
        print(f"cuml Best parameters ({model_name}): {cu_models[model_name].best_params_}")
    except NameError: # handles if cuMLKNeighborsClassifier was not imported
        print(f"cuML KNeighborsClassifier not available. Skipping cuML {model_name} training.")
    except Exception as e:
        print(f"An error occurred during cuML {model_name} training: {e}")
        # Optionally, remove the model key if setup failed partway
        if model_name in cu_models: del cu_models[model_name]
        if model_name in cu_times: del cu_times[model_name]

else:
    print(f"cuML is not installed or GPU not available. Skipping cuML {model_name} benchmark.")

print(f"scikit-learn GridSearchCV training time ({model_name}) : {sk_times[model_name]:.2f} seconds")
print(f"scikit-learn Best parameters ({model_name}): {sk_models[model_name].best_params_}")
# Out:
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# [2025-05-27 14:59:27.233] [CUML] [info] Unused keyword parameter: n_jobs during cuML estimator initialization
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# [2025-05-27 14:59:27.235] [CUML] [info] Unused keyword parameter: n_jobs during cuML estimator initialization
# [CV 1/5] END metric=euclidean, n_neighbors=3, weights=uniform;, score=0.506 total time=   1.1s
# [2025-05-27 14:59:28.355] [CUML] [info] Unused keyword parameter: n_jobs during cuML estimator initialization
# [CV 2/5] END metric=euclidean, n_neighbors=3, weights=uniform;, score=0.525 total time=   0.0s
# [2025-05-27 14:59:28.365] [CUML] [info] Unused keyword parameter: n_jobs during cuML estimator initialization
# [CV 3/5] END metric=euclidean, n_neighbors=3, weights=uniform;, score=0.541 total time=   0.0s
# [2025-05-27 14:59:28.375] [CUML] [info] Unused keyword parameter: n_jobs during cuML estimator initialization
# [CV 4/5] END metric=euclidean, n_neighbors=3, weights=uniform;, score=0.516 total time=   0.0s
# [2025-05-27 14:59:28.389] [CUML] [info] Unused keyword parameter: n_jobs during cuML estimator initialization
# [CV 5/5] END metric=euclidean, n_neighbors=3, weights=uniform;, score=0.444 total time=   0.0s
# [2025-05-27 14:59:28.397] [CUML] [info] Unused keyword parameter: n_jobs during cuML estimator initialization
# [CV 1/5] END metric=euclidean, n_neighbors=3, weights=distance;, score=0.506 total time=   0.0s
# [2025-05-27 14:59:28.406] [CUML] [info] Unused keyword parameter: n_jobs during cuML estimator initialization
# [CV 2/5] END metric=euclidean, n_neighbors=3, weights=distance;, score=0.525 total time=   0.0s
# [2025-05-27 14:59:28.414] [CUML] [info] Unused keyword parameter: n_jobs during cuML estimator initialization
# [CV 3/5] END metric=euclidean, n_neighbors=3, weights=distance;, score=0.541 total time=   0.0s
# [2025-05-27 14:59:28.423] [CUML] [info] Unused keyword parameter: n_jobs during cuML estimator initialization
# [CV 4/5] END metric=euclidean, n_neighbors=3, weights=distance;, score=0.516 total time=   0.0s
# [2025-05-27 14:59:28.433] [CUML] [info] Unused keyword parameter: n_jobs during cuML estimator initialization
# [CV 5/5] END metric=euclidean, n_neighbors=3, weights=distance;, score=0.444 total time=   0.0s
# [2025-05-27 14:59:28.442] [CUML] [info] Unused keyword parameter: n_jobs during cuML estimator initialization
# [CV 1/5] END metric=euclidean, n_neighbors=5, weights=uniform;, score=0.466 total time=   0.0s
# [2025-05-27 14:59:28.450] [CUML] [info] Unused keyword parameter: n_jobs during cuML estimator initialization
# [CV 2/5] END metric=euclidean, n_neighbors=5, weights=uniform;, score=0.475 total time=   0.0s
# [2025-05-27 14:59:28.459] [CUML] [info] Unused keyword parameter: n_jobs during cuML estimator initialization
# [CV 3/5] END metric=euclidean, n_neighbors=5, weights=uniform;, score=0.550 total time=   0.0s
# [2025-05-27 14:59:28.468] [CUML] [info] Unused keyword parameter: n_jobs during cuML estimator initialization
# [CV 4/5] END metric=euclidean, n_neighbors=5, weights=uniform;, score=0.512 total time=   0.0s
# [2025-05-27 14:59:28.477] [CUML] [info] Unused keyword parameter: n_jobs during cuML estimator initialization
# [CV 5/5] END metric=euclidean, n_neighbors=5, weights=uniform;, score=0.469 total time=   0.0s
# [2025-05-27 14:59:28.486] [CUML] [info] Unused keyword parameter: n_jobs during cuML estimator initialization
# [CV 1/5] END metric=euclidean, n_neighbors=5, weights=distance;, score=0.466 total time=   0.0s
# [2025-05-27 14:59:28.494] [CUML] [info] Unused keyword parameter: n_jobs during cuML estimator initialization
# [CV 2/5] END metric=euclidean, n_neighbors=5, weights=distance;, score=0.475 total time=   0.0s
# [2025-05-27 14:59:28.502] [CUML] [info] Unused keyword parameter: n_jobs during cuML estimator initialization
# [CV 3/5] END metric=euclidean, n_neighbors=5, weights=distance;, score=0.550 total time=   0.0s
# [2025-05-27 14:59:28.510] [CUML] [info] Unused keyword parameter: n_jobs during cuML estimator initialization
# [CV 4/5] END metric=euclidean, n_neighbors=5, weights=distance;, score=0.512 total time=   0.0s
# [2025-05-27 14:59:28.519] [CUML] [info] Unused keyword parameter: n_jobs during cuML estimator initialization
# [CV 5/5] END metric=euclidean, n_neighbors=5, weights=distance;, score=0.469 total time=   0.0s
# [2025-05-27 14:59:28.528] [CUML] [info] Unused keyword parameter: n_jobs during cuML estimator initialization
# [CV 1/5] END metric=euclidean, n_neighbors=7, weights=uniform;, score=0.453 total time=   0.0s
# [2025-05-27 14:59:28.536] [CUML] [info] Unused keyword parameter: n_jobs during cuML estimator initialization
# [CV 2/5] END metric=euclidean, n_neighbors=7, weights=uniform;, score=0.509 total time=   0.0s
# [2025-05-27 14:59:28.544] [CUML] [info] Unused keyword parameter: n_jobs during cuML estimator initialization
# [CV 3/5] END metric=euclidean, n_neighbors=7, weights=uniform;, score=0.519 total time=   0.0s
# [2025-05-27 14:59:28.552] [CUML] [info] Unused keyword parameter: n_jobs during cuML estimator initialization
# [CV 4/5] END metric=euclidean, n_neighbors=7, weights=uniform;, score=0.519 total time=   0.0s
# [2025-05-27 14:59:28.563] [CUML] [info] Unused keyword parameter: n_jobs during cuML estimator initialization
# [CV 5/5] END metric=euclidean, n_neighbors=7, weights=uniform;, score=0.478 total time=   0.0s
# [2025-05-27 14:59:28.572] [CUML] [info] Unused keyword parameter: n_jobs during cuML estimator initialization
# [CV 1/5] END metric=euclidean, n_neighbors=7, weights=distance;, score=0.453 total time=   0.0s
# [2025-05-27 14:59:28.581] [CUML] [info] Unused keyword parameter: n_jobs during cuML estimator initialization
# [CV 2/5] END metric=euclidean, n_neighbors=7, weights=distance;, score=0.509 total time=   0.0s
# [2025-05-27 14:59:28.589] [CUML] [info] Unused keyword parameter: n_jobs during cuML estimator initialization
# [CV 3/5] END metric=euclidean, n_neighbors=7, weights=distance;, score=0.519 total time=   0.0s
# [2025-05-27 14:59:28.598] [CUML] [info] Unused keyword parameter: n_jobs during cuML estimator initialization
# [CV 4/5] END metric=euclidean, n_neighbors=7, weights=distance;, score=0.519 total time=   0.0s
# [2025-05-27 14:59:28.607] [CUML] [info] Unused keyword parameter: n_jobs during cuML estimator initialization
# [CV 5/5] END metric=euclidean, n_neighbors=7, weights=distance;, score=0.478 total time=   0.0s
# [2025-05-27 14:59:28.616] [CUML] [info] Unused keyword parameter: n_jobs during cuML estimator initialization
# [CV 1/5] END metric=euclidean, n_neighbors=9, weights=uniform;, score=0.434 total time=   0.0s
# [2025-05-27 14:59:28.624] [CUML] [info] Unused keyword parameter: n_jobs during cuML estimator initialization
# [CV 2/5] END metric=euclidean, n_neighbors=9, weights=uniform;, score=0.500 total time=   0.0s
# [2025-05-27 14:59:28.634] [CUML] [info] Unused keyword parameter: n_jobs during cuML estimator initialization
# [CV 3/5] END metric=euclidean, n_neighbors=9, weights=uniform;, score=0.525 total time=   0.0s
# [2025-05-27 14:59:28.646] [CUML] [info] Unused keyword parameter: n_jobs during cuML estimator initialization
# [CV 4/5] END metric=euclidean, n_neighbors=9, weights=uniform;, score=0.509 total time=   0.0s
# [2025-05-27 14:59:28.659] [CUML] [info] Unused keyword parameter: n_jobs during cuML estimator initialization
# [CV 5/5] END metric=euclidean, n_neighbors=9, weights=uniform;, score=0.484 total time=   0.0s
# [2025-05-27 14:59:28.669] [CUML] [info] Unused keyword parameter: n_jobs during cuML estimator initialization
# [CV 1/5] END metric=euclidean, n_neighbors=9, weights=distance;, score=0.434 total time=   0.0s
# [2025-05-27 14:59:28.678] [CUML] [info] Unused keyword parameter: n_jobs during cuML estimator initialization
# [CV 2/5] END metric=euclidean, n_neighbors=9, weights=distance;, score=0.500 total time=   0.0s
# [2025-05-27 14:59:28.687] [CUML] [info] Unused keyword parameter: n_jobs during cuML estimator initialization
# [CV 3/5] END metric=euclidean, n_neighbors=9, weights=distance;, score=0.525 total time=   0.0s
# [2025-05-27 14:59:28.697] [CUML] [info] Unused keyword parameter: n_jobs during cuML estimator initialization
# [CV 4/5] END metric=euclidean, n_neighbors=9, weights=distance;, score=0.509 total time=   0.0s
# [2025-05-27 14:59:28.708] [CUML] [info] Unused keyword parameter: n_jobs during cuML estimator initialization
# [CV 5/5] END metric=euclidean, n_neighbors=9, weights=distance;, score=0.484 total time=   0.0s
# [2025-05-27 14:59:28.717] [CUML] [info] Unused keyword parameter: n_jobs during cuML estimator initialization
# [CV 1/5] END metric=euclidean, n_neighbors=11, weights=uniform;, score=0.456 total time=   0.0s
# [2025-05-27 14:59:28.725] [CUML] [info] Unused keyword parameter: n_jobs during cuML estimator initialization
# [CV 2/5] END metric=euclidean, n_neighbors=11, weights=uniform;, score=0.522 total time=   0.0s
# [2025-05-27 14:59:28.735] [CUML] [info] Unused keyword parameter: n_jobs during cuML estimator initialization
# [CV 3/5] END metric=euclidean, n_neighbors=11, weights=uniform;, score=0.534 total time=   0.0s
# [2025-05-27 14:59:28.744] [CUML] [info] Unused keyword parameter: n_jobs during cuML estimator initialization
# [CV 4/5] END metric=euclidean, n_neighbors=11, weights=uniform;, score=0.525 total time=   0.0s
# [2025-05-27 14:59:28.753] [CUML] [info] Unused keyword parameter: n_jobs during cuML estimator initialization
# [CV 5/5] END metric=euclidean, n_neighbors=11, weights=uniform;, score=0.488 total time=   0.0s
# [2025-05-27 14:59:28.762] [CUML] [info] Unused keyword parameter: n_jobs during cuML estimator initialization
# [CV 1/5] END metric=euclidean, n_neighbors=11, weights=distance;, score=0.456 total time=   0.0s
# [2025-05-27 14:59:28.774] [CUML] [info] Unused keyword parameter: n_jobs during cuML estimator initialization
# [CV 2/5] END metric=euclidean, n_neighbors=11, weights=distance;, score=0.522 total time=   0.0s
# [2025-05-27 14:59:28.785] [CUML] [info] Unused keyword parameter: n_jobs during cuML estimator initialization
# [CV 3/5] END metric=euclidean, n_neighbors=11, weights=distance;, score=0.534 total time=   0.0s
# [2025-05-27 14:59:28.794] [CUML] [info] Unused keyword parameter: n_jobs during cuML estimator initialization
# [CV 4/5] END metric=euclidean, n_neighbors=11, weights=distance;, score=0.525 total time=   0.0s
# [2025-05-27 14:59:28.802] [CUML] [info] Unused keyword parameter: n_jobs during cuML estimator initialization
# [CV 5/5] END metric=euclidean, n_neighbors=11, weights=distance;, score=0.488 total time=   0.0s
# [2025-05-27 14:59:28.811] [CUML] [info] Unused keyword parameter: n_jobs during cuML estimator initialization
# [CV 1/5] END metric=manhattan, n_neighbors=3, weights=uniform;, score=0.494 total time=   0.1s
# [2025-05-27 14:59:28.915] [CUML] [info] Unused keyword parameter: n_jobs during cuML estimator initialization
# [CV 2/5] END metric=manhattan, n_neighbors=3, weights=uniform;, score=0.475 total time=   0.0s
# [2025-05-27 14:59:28.927] [CUML] [info] Unused keyword parameter: n_jobs during cuML estimator initialization
# [CV 3/5] END metric=manhattan, n_neighbors=3, weights=uniform;, score=0.541 total time=   0.0s
# [2025-05-27 14:59:28.936] [CUML] [info] Unused keyword parameter: n_jobs during cuML estimator initialization
# [CV 4/5] END metric=manhattan, n_neighbors=3, weights=uniform;, score=0.519 total time=   0.0s
# [2025-05-27 14:59:28.945] [CUML] [info] Unused keyword parameter: n_jobs during cuML estimator initialization
# [CV 5/5] END metric=manhattan, n_neighbors=3, weights=uniform;, score=0.475 total time=   0.0s
# [2025-05-27 14:59:28.953] [CUML] [info] Unused keyword parameter: n_jobs during cuML estimator initialization
# [CV 1/5] END metric=manhattan, n_neighbors=3, weights=distance;, score=0.494 total time=   0.0s
# [2025-05-27 14:59:28.962] [CUML] [info] Unused keyword parameter: n_jobs during cuML estimator initialization
# [CV 2/5] END metric=manhattan, n_neighbors=3, weights=distance;, score=0.475 total time=   0.0s
# [2025-05-27 14:59:28.972] [CUML] [info] Unused keyword parameter: n_jobs during cuML estimator initialization
# [CV 3/5] END metric=manhattan, n_neighbors=3, weights=distance;, score=0.541 total time=   0.0s
# [2025-05-27 14:59:28.983] [CUML] [info] Unused keyword parameter: n_jobs during cuML estimator initialization
# [CV 4/5] END metric=manhattan, n_neighbors=3, weights=distance;, score=0.519 total time=   0.0s
# [2025-05-27 14:59:28.995] [CUML] [info] Unused keyword parameter: n_jobs during cuML estimator initialization
# [CV 5/5] END metric=manhattan, n_neighbors=3, weights=distance;, score=0.475 total time=   0.0s
# [2025-05-27 14:59:29.009] [CUML] [info] Unused keyword parameter: n_jobs during cuML estimator initialization
# [CV 1/5] END metric=manhattan, n_neighbors=5, weights=uniform;, score=0.469 total time=   0.0s
# [2025-05-27 14:59:29.024] [CUML] [info] Unused keyword parameter: n_jobs during cuML estimator initialization
# [CV 2/5] END metric=manhattan, n_neighbors=5, weights=uniform;, score=0.472 total time=   0.0s
# [2025-05-27 14:59:29.038] [CUML] [info] Unused keyword parameter: n_jobs during cuML estimator initialization
# [CV 3/5] END metric=manhattan, n_neighbors=5, weights=uniform;, score=0.497 total time=   0.0s
# [2025-05-27 14:59:29.051] [CUML] [info] Unused keyword parameter: n_jobs during cuML estimator initialization
# [CV 4/5] END metric=manhattan, n_neighbors=5, weights=uniform;, score=0.575 total time=   0.0s
# [2025-05-27 14:59:29.065] [CUML] [info] Unused keyword parameter: n_jobs during cuML estimator initialization
# [CV 5/5] END metric=manhattan, n_neighbors=5, weights=uniform;, score=0.475 total time=   0.0s
# [2025-05-27 14:59:29.076] [CUML] [info] Unused keyword parameter: n_jobs during cuML estimator initialization
# [CV 1/5] END metric=manhattan, n_neighbors=5, weights=distance;, score=0.469 total time=   0.0s
# [2025-05-27 14:59:29.089] [CUML] [info] Unused keyword parameter: n_jobs during cuML estimator initialization
# [CV 2/5] END metric=manhattan, n_neighbors=5, weights=distance;, score=0.472 total time=   0.0s
# [2025-05-27 14:59:29.102] [CUML] [info] Unused keyword parameter: n_jobs during cuML estimator initialization
# [CV 3/5] END metric=manhattan, n_neighbors=5, weights=distance;, score=0.497 total time=   0.0s
# [2025-05-27 14:59:29.114] [CUML] [info] Unused keyword parameter: n_jobs during cuML estimator initialization
# [CV 4/5] END metric=manhattan, n_neighbors=5, weights=distance;, score=0.575 total time=   0.0s
# [2025-05-27 14:59:29.127] [CUML] [info] Unused keyword parameter: n_jobs during cuML estimator initialization
# [CV 5/5] END metric=manhattan, n_neighbors=5, weights=distance;, score=0.475 total time=   0.0s
# [2025-05-27 14:59:29.139] [CUML] [info] Unused keyword parameter: n_jobs during cuML estimator initialization
# [CV 1/5] END metric=manhattan, n_neighbors=7, weights=uniform;, score=0.447 total time=   0.0s
# [2025-05-27 14:59:29.152] [CUML] [info] Unused keyword parameter: n_jobs during cuML estimator initialization
# [CV 2/5] END metric=manhattan, n_neighbors=7, weights=uniform;, score=0.478 total time=   0.0s
# [2025-05-27 14:59:29.166] [CUML] [info] Unused keyword parameter: n_jobs during cuML estimator initialization
# [CV 3/5] END metric=manhattan, n_neighbors=7, weights=uniform;, score=0.525 total time=   0.0s
# [2025-05-27 14:59:29.177] [CUML] [info] Unused keyword parameter: n_jobs during cuML estimator initialization
# [CV 4/5] END metric=manhattan, n_neighbors=7, weights=uniform;, score=0.547 total time=   0.0s
# [2025-05-27 14:59:29.189] [CUML] [info] Unused keyword parameter: n_jobs during cuML estimator initialization
# [CV 5/5] END metric=manhattan, n_neighbors=7, weights=uniform;, score=0.459 total time=   0.0s
# [2025-05-27 14:59:29.203] [CUML] [info] Unused keyword parameter: n_jobs during cuML estimator initialization
# [CV 1/5] END metric=manhattan, n_neighbors=7, weights=distance;, score=0.447 total time=   0.0s
# [2025-05-27 14:59:29.214] [CUML] [info] Unused keyword parameter: n_jobs during cuML estimator initialization
# [CV 2/5] END metric=manhattan, n_neighbors=7, weights=distance;, score=0.478 total time=   0.0s
# [2025-05-27 14:59:29.225] [CUML] [info] Unused keyword parameter: n_jobs during cuML estimator initialization
# [CV 3/5] END metric=manhattan, n_neighbors=7, weights=distance;, score=0.525 total time=   0.0s
# [2025-05-27 14:59:29.237] [CUML] [info] Unused keyword parameter: n_jobs during cuML estimator initialization
# [CV 4/5] END metric=manhattan, n_neighbors=7, weights=distance;, score=0.547 total time=   0.0s
# [2025-05-27 14:59:29.247] [CUML] [info] Unused keyword parameter: n_jobs during cuML estimator initialization
# [CV 5/5] END metric=manhattan, n_neighbors=7, weights=distance;, score=0.459 total time=   0.0s
# [2025-05-27 14:59:29.260] [CUML] [info] Unused keyword parameter: n_jobs during cuML estimator initialization
# [CV 1/5] END metric=manhattan, n_neighbors=9, weights=uniform;, score=0.456 total time=   0.0s
# [2025-05-27 14:59:29.276] [CUML] [info] Unused keyword parameter: n_jobs during cuML estimator initialization
# [CV 2/5] END metric=manhattan, n_neighbors=9, weights=uniform;, score=0.531 total time=   0.0s
# [2025-05-27 14:59:29.289] [CUML] [info] Unused keyword parameter: n_jobs during cuML estimator initialization
# [CV 3/5] END metric=manhattan, n_neighbors=9, weights=uniform;, score=0.497 total time=   0.0s
# [2025-05-27 14:59:29.302] [CUML] [info] Unused keyword parameter: n_jobs during cuML estimator initialization
# [CV 4/5] END metric=manhattan, n_neighbors=9, weights=uniform;, score=0.519 total time=   0.0s
# [2025-05-27 14:59:29.314] [CUML] [info] Unused keyword parameter: n_jobs during cuML estimator initialization
# [CV 5/5] END metric=manhattan, n_neighbors=9, weights=uniform;, score=0.466 total time=   0.0s
# [2025-05-27 14:59:29.326] [CUML] [info] Unused keyword parameter: n_jobs during cuML estimator initialization
# [CV 1/5] END metric=manhattan, n_neighbors=9, weights=distance;, score=0.456 total time=   0.0s
# [2025-05-27 14:59:29.336] [CUML] [info] Unused keyword parameter: n_jobs during cuML estimator initialization
# [CV 2/5] END metric=manhattan, n_neighbors=9, weights=distance;, score=0.531 total time=   0.0s
# [2025-05-27 14:59:29.348] [CUML] [info] Unused keyword parameter: n_jobs during cuML estimator initialization
# [CV 3/5] END metric=manhattan, n_neighbors=9, weights=distance;, score=0.497 total time=   0.0s
# [2025-05-27 14:59:29.359] [CUML] [info] Unused keyword parameter: n_jobs during cuML estimator initialization
# [CV 4/5] END metric=manhattan, n_neighbors=9, weights=distance;, score=0.519 total time=   0.0s
# [2025-05-27 14:59:29.372] [CUML] [info] Unused keyword parameter: n_jobs during cuML estimator initialization
# [CV 5/5] END metric=manhattan, n_neighbors=9, weights=distance;, score=0.466 total time=   0.0s
# [2025-05-27 14:59:29.382] [CUML] [info] Unused keyword parameter: n_jobs during cuML estimator initialization
# [CV 1/5] END metric=manhattan, n_neighbors=11, weights=uniform;, score=0.463 total time=   0.0s
# [2025-05-27 14:59:29.398] [CUML] [info] Unused keyword parameter: n_jobs during cuML estimator initialization
# [CV 2/5] END metric=manhattan, n_neighbors=11, weights=uniform;, score=0.494 total time=   0.0s
# [2025-05-27 14:59:29.411] [CUML] [info] Unused keyword parameter: n_jobs during cuML estimator initialization
# [CV 3/5] END metric=manhattan, n_neighbors=11, weights=uniform;, score=0.534 total time=   0.0s
# [2025-05-27 14:59:29.422] [CUML] [info] Unused keyword parameter: n_jobs during cuML estimator initialization
# [CV 4/5] END metric=manhattan, n_neighbors=11, weights=uniform;, score=0.512 total time=   0.0s
# [2025-05-27 14:59:29.434] [CUML] [info] Unused keyword parameter: n_jobs during cuML estimator initialization
# [CV 5/5] END metric=manhattan, n_neighbors=11, weights=uniform;, score=0.466 total time=   0.0s
# [2025-05-27 14:59:29.444] [CUML] [info] Unused keyword parameter: n_jobs during cuML estimator initialization
# [CV 1/5] END metric=manhattan, n_neighbors=11, weights=distance;, score=0.463 total time=   0.0s
# [2025-05-27 14:59:29.455] [CUML] [info] Unused keyword parameter: n_jobs during cuML estimator initialization
# [CV 2/5] END metric=manhattan, n_neighbors=11, weights=distance;, score=0.494 total time=   0.0s
# [2025-05-27 14:59:29.468] [CUML] [info] Unused keyword parameter: n_jobs during cuML estimator initialization
# [CV 3/5] END metric=manhattan, n_neighbors=11, weights=distance;, score=0.534 total time=   0.0s
# [2025-05-27 14:59:29.479] [CUML] [info] Unused keyword parameter: n_jobs during cuML estimator initialization
# [CV 4/5] END metric=manhattan, n_neighbors=11, weights=distance;, score=0.512 total time=   0.0s
# [2025-05-27 14:59:29.490] [CUML] [info] Unused keyword parameter: n_jobs during cuML estimator initialization
# [CV 5/5] END metric=manhattan, n_neighbors=11, weights=distance;, score=0.466 total time=   0.0s
# [2025-05-27 14:59:29.502] [CUML] [info] Unused keyword parameter: n_jobs during cuML estimator initialization
# cuml GridSearchCV training time (KNN) : 2.27 seconds
# cuml Best parameters (KNN): {'metric': 'euclidean', 'n_neighbors': 3, 'weights': 'uniform'}
# scikit-learn GridSearchCV training time (KNN) : 1.76 seconds
# scikit-learn Best parameters (KNN): {'metric': 'euclidean', 'n_neighbors': 3, 'weights': 'distance'}

# %% [markdown]
# ## Random Forest

# %%
model_name = "RF"

# %%
from sklearn.ensemble import RandomForestClassifier as SklearnRandomForestClassifier
# Attempt to import cuML's RandomForestClassifier
try:
    from cuml.ensemble import RandomForestClassifier as cuMLRandomForestClassifier
    # has_cuml is already defined, assuming if previous cuML models are available, RF is too.
except ImportError:
    # Pass, relying on global has_cuml. Specific check for cuMLRandomForestClassifier will happen in the training block.
    pass

# %%
# Parameter grid for Random Forest
param_grid_rf = {
    'n_estimators': [100, 200], # Number of trees in the forest
    'max_depth': [None, 10, 20],    # Maximum depth of the tree
    'min_samples_split': [2, 5], # Minimum number of samples required to split an internal node
    'min_samples_leaf': [1, 2],   # Minimum number of samples required to be at a leaf node
    # 'max_features': ['auto', 'sqrt'] # Number of features to consider when looking for the best split (cuML might have different defaults/options)
    # For cuML compatibility, specific parameters like 'max_features' might need adjustment or careful selection.
    # cuML RandomForestClassifier has slightly different parameter names or accepted values for some arguments.
    # e.g. max_features in cuML can be int, float, or 'auto' (auto is sqrt(n_features)).
}

# 1) scikit-learn RandomForest with GridSearchCV
sk_models[model_name] = GridSearchCV(
    estimator=SklearnRandomForestClassifier(random_state=42),
    param_grid=param_grid_rf,
    cv=5, # Using 3-fold CV for RF due to potentially longer training times
    verbose=3,
    n_jobs=-1
)

time_start = time.time()
sk_models[model_name].fit(X_train, y_train)
time_end = time.time()
sk_times[model_name] = time_end - time_start


# 2) cuML RandomForest with GridSearchCV (adapted for cuML)
if has_cuml:
    try:
        # Ensure cuMLRandomForestClassifier was imported
        cuMLRandomForestClassifier

        # cuML specific parameter adjustments if necessary.
        # For example, cuML's RandomForestClassifier might not support all string options for max_features like sklearn.
        # It typically supports int (number of features) or float (fraction of features). 'auto' is often sqrt(n_features).
        # Let's use a simplified grid or ensure compatibility.
        # The provided param_grid_rf should generally work if 'max_features' is omitted or set to a compatible value.

        cu_models[model_name] = GridSearchCV(
            estimator=cuMLRandomForestClassifier(random_state=42), # cuML RandomForest
            param_grid=param_grid_rf, # Ensure parameters are compatible with cuML RF
            cv=5, # Using 3-fold CV
            verbose=3,
            n_jobs=1 # Safer for GPU resources with GridSearchCV
        )

        time_start = time.time()
        cu_models[model_name].fit(X_train, y_train) # X_train, y_train are pandas, cuML handles this
        time_end = time.time()
        cu_times[model_name] = time_end - time_start
        print(f"cuml GridSearchCV training time ({model_name}) : {cu_times[model_name]:.2f} seconds")
        print(f"cuml Best parameters ({model_name}): {cu_models[model_name].best_params_}")
    except NameError:
        print(f"cuML RandomForestClassifier not available. Skipping cuML {model_name} training.")
    except Exception as e:
        print(f"An error occurred during cuML {model_name} training: {e}")
        if model_name in cu_models: del cu_models[model_name]
        if model_name in cu_times: del cu_times[model_name]
else:
    print(f"cuML is not installed or GPU not available. Skipping cuML {model_name} benchmark.")

print(f"scikit-learn GridSearchCV training time ({model_name}) : {sk_times[model_name]:.2f} seconds")
print(f"scikit-learn Best parameters ({model_name}): {sk_models[model_name].best_params_}")
# Out:
# Fitting 5 folds for each of 24 candidates, totalling 120 fits
# /usr/local/lib/python3.11/dist-packages/cuml/internals/api_decorators.py:368: UserWarning: For reproducible results in Random Forest Classifier or for almost reproducible results in Random Forest Regressor, n_streams=1 is recommended. If n_streams is > 1, results may vary due to stream/thread timing differences, even when random_state is set
#   return init_func(self, *args, **kwargs)
# /usr/local/lib/python3.11/dist-packages/cuml/internals/api_decorators.py:368: UserWarning: For reproducible results in Random Forest Classifier or for almost reproducible results in Random Forest Regressor, n_streams=1 is recommended. If n_streams is > 1, results may vary due to stream/thread timing differences, even when random_state is set
#   return init_func(self, *args, **kwargs)
# /usr/local/lib/python3.11/dist-packages/cuml/internals/api_decorators.py:368: UserWarning: For reproducible results in Random Forest Classifier or for almost reproducible results in Random Forest Regressor, n_streams=1 is recommended. If n_streams is > 1, results may vary due to stream/thread timing differences, even when random_state is set
#   return init_func(self, *args, **kwargs)
# Fitting 5 folds for each of 24 candidates, totalling 120 fits
# [CV 1/5] END max_depth=None, min_samples_leaf=1, min_samples_split=2, n_estimators=100;, score=nan total time=   0.2s
# [CV 2/5] END max_depth=None, min_samples_leaf=1, min_samples_split=2, n_estimators=100;, score=nan total time=   0.0s
# [CV 3/5] END max_depth=None, min_samples_leaf=1, min_samples_split=2, n_estimators=100;, score=nan total time=   0.0s
# [CV 4/5] END max_depth=None, min_samples_leaf=1, min_samples_split=2, n_estimators=100;, score=nan total time=   0.0s
# [CV 5/5] END max_depth=None, min_samples_leaf=1, min_samples_split=2, n_estimators=100;, score=nan total time=   0.0s
# [CV 1/5] END max_depth=None, min_samples_leaf=1, min_samples_split=2, n_estimators=200;, score=nan total time=   0.0s
# [CV 2/5] END max_depth=None, min_samples_leaf=1, min_samples_split=2, n_estimators=200;, score=nan total time=   0.0s
# [CV 3/5] END max_depth=None, min_samples_leaf=1, min_samples_split=2, n_estimators=200;, score=nan total time=   0.0s
# [CV 4/5] END max_depth=None, min_samples_leaf=1, min_samples_split=2, n_estimators=200;, score=nan total time=   0.0s
# [CV 5/5] END max_depth=None, min_samples_leaf=1, min_samples_split=2, n_estimators=200;, score=nan total time=   0.0s
# [CV 1/5] END max_depth=None, min_samples_leaf=1, min_samples_split=5, n_estimators=100;, score=nan total time=   0.0s
# [CV 2/5] END max_depth=None, min_samples_leaf=1, min_samples_split=5, n_estimators=100;, score=nan total time=   0.0s
# [CV 3/5] END max_depth=None, min_samples_leaf=1, min_samples_split=5, n_estimators=100;, score=nan total time=   0.0s
# [CV 4/5] END max_depth=None, min_samples_leaf=1, min_samples_split=5, n_estimators=100;, score=nan total time=   0.0s
# [CV 5/5] END max_depth=None, min_samples_leaf=1, min_samples_split=5, n_estimators=100;, score=nan total time=   0.0s
# [CV 1/5] END max_depth=None, min_samples_leaf=1, min_samples_split=5, n_estimators=200;, score=nan total time=   0.0s
# [CV 2/5] END max_depth=None, min_samples_leaf=1, min_samples_split=5, n_estimators=200;, score=nan total time=   0.0s
# [CV 3/5] END max_depth=None, min_samples_leaf=1, min_samples_split=5, n_estimators=200;, score=nan total time=   0.0s
# [CV 4/5] END max_depth=None, min_samples_leaf=1, min_samples_split=5, n_estimators=200;, score=nan total time=   0.0s
# [CV 5/5] END max_depth=None, min_samples_leaf=1, min_samples_split=5, n_estimators=200;, score=nan total time=   0.0s
# [CV 1/5] END max_depth=None, min_samples_leaf=2, min_samples_split=2, n_estimators=100;, score=nan total time=   0.0s
# [CV 2/5] END max_depth=None, min_samples_leaf=2, min_samples_split=2, n_estimators=100;, score=nan total time=   0.0s
# [CV 3/5] END max_depth=None, min_samples_leaf=2, min_samples_split=2, n_estimators=100;, score=nan total time=   0.0s
# [CV 4/5] END max_depth=None, min_samples_leaf=2, min_samples_split=2, n_estimators=100;, score=nan total time=   0.0s
# [CV 5/5] END max_depth=None, min_samples_leaf=2, min_samples_split=2, n_estimators=100;, score=nan total time=   0.0s
# [CV 1/5] END max_depth=None, min_samples_leaf=2, min_samples_split=2, n_estimators=200;, score=nan total time=   0.0s
# [CV 2/5] END max_depth=None, min_samples_leaf=2, min_samples_split=2, n_estimators=200;, score=nan total time=   0.0s
# [CV 3/5] END max_depth=None, min_samples_leaf=2, min_samples_split=2, n_estimators=200;, score=nan total time=   0.0s
# [CV 4/5] END max_depth=None, min_samples_leaf=2, min_samples_split=2, n_estimators=200;, score=nan total time=   0.0s
# [CV 5/5] END max_depth=None, min_samples_leaf=2, min_samples_split=2, n_estimators=200;, score=nan total time=   0.0s
# [CV 1/5] END max_depth=None, min_samples_leaf=2, min_samples_split=5, n_estimators=100;, score=nan total time=   0.0s
# [CV 2/5] END max_depth=None, min_samples_leaf=2, min_samples_split=5, n_estimators=100;, score=nan total time=   0.0s
# [CV 3/5] END max_depth=None, min_samples_leaf=2, min_samples_split=5, n_estimators=100;, score=nan total time=   0.0s
# [CV 4/5] END max_depth=None, min_samples_leaf=2, min_samples_split=5, n_estimators=100;, score=nan total time=   0.0s
# [CV 5/5] END max_depth=None, min_samples_leaf=2, min_samples_split=5, n_estimators=100;, score=nan total time=   0.0s
# [CV 1/5] END max_depth=None, min_samples_leaf=2, min_samples_split=5, n_estimators=200;, score=nan total time=   0.0s
# [CV 2/5] END max_depth=None, min_samples_leaf=2, min_samples_split=5, n_estimators=200;, score=nan total time=   0.0s
# [CV 3/5] END max_depth=None, min_samples_leaf=2, min_samples_split=5, n_estimators=200;, score=nan total time=   0.0s
# [CV 4/5] END max_depth=None, min_samples_leaf=2, min_samples_split=5, n_estimators=200;, score=nan total time=   0.0s
# [CV 5/5] END max_depth=None, min_samples_leaf=2, min_samples_split=5, n_estimators=200;, score=nan total time=   0.0s
# [CV 1/5] END max_depth=10, min_samples_leaf=1, min_samples_split=2, n_estimators=100;, score=0.503 total time=   0.4s
# [CV 2/5] END max_depth=10, min_samples_leaf=1, min_samples_split=2, n_estimators=100;, score=0.463 total time=   0.2s
# [CV 3/5] END max_depth=10, min_samples_leaf=1, min_samples_split=2, n_estimators=100;, score=0.500 total time=   0.2s
# [CV 4/5] END max_depth=10, min_samples_leaf=1, min_samples_split=2, n_estimators=100;, score=0.491 total time=   0.2s
# [CV 5/5] END max_depth=10, min_samples_leaf=1, min_samples_split=2, n_estimators=100;, score=0.475 total time=   0.2s
# [CV 1/5] END max_depth=10, min_samples_leaf=1, min_samples_split=2, n_estimators=200;, score=0.506 total time=   0.3s
# [CV 2/5] END max_depth=10, min_samples_leaf=1, min_samples_split=2, n_estimators=200;, score=0.472 total time=   0.3s
# [CV 3/5] END max_depth=10, min_samples_leaf=1, min_samples_split=2, n_estimators=200;, score=0.500 total time=   0.3s
# [CV 4/5] END max_depth=10, min_samples_leaf=1, min_samples_split=2, n_estimators=200;, score=0.478 total time=   0.4s
# [CV 5/5] END max_depth=10, min_samples_leaf=1, min_samples_split=2, n_estimators=200;, score=0.484 total time=   0.3s
# [CV 1/5] END max_depth=10, min_samples_leaf=1, min_samples_split=5, n_estimators=100;, score=0.497 total time=   0.2s
# [CV 2/5] END max_depth=10, min_samples_leaf=1, min_samples_split=5, n_estimators=100;, score=0.466 total time=   0.2s
# [CV 3/5] END max_depth=10, min_samples_leaf=1, min_samples_split=5, n_estimators=100;, score=0.484 total time=   0.3s
# [CV 4/5] END max_depth=10, min_samples_leaf=1, min_samples_split=5, n_estimators=100;, score=0.463 total time=   0.3s
# [CV 5/5] END max_depth=10, min_samples_leaf=1, min_samples_split=5, n_estimators=100;, score=0.450 total time=   0.3s
# [CV 1/5] END max_depth=10, min_samples_leaf=1, min_samples_split=5, n_estimators=200;, score=0.500 total time=   0.4s
# [CV 2/5] END max_depth=10, min_samples_leaf=1, min_samples_split=5, n_estimators=200;, score=0.472 total time=   0.5s
# [CV 3/5] END max_depth=10, min_samples_leaf=1, min_samples_split=5, n_estimators=200;, score=0.494 total time=   0.4s
# [CV 4/5] END max_depth=10, min_samples_leaf=1, min_samples_split=5, n_estimators=200;, score=0.481 total time=   0.4s
# [CV 5/5] END max_depth=10, min_samples_leaf=1, min_samples_split=5, n_estimators=200;, score=0.466 total time=   0.4s
# [CV 1/5] END max_depth=10, min_samples_leaf=2, min_samples_split=2, n_estimators=100;, score=0.491 total time=   0.2s
# [CV 2/5] END max_depth=10, min_samples_leaf=2, min_samples_split=2, n_estimators=100;, score=0.456 total time=   0.2s
# [CV 3/5] END max_depth=10, min_samples_leaf=2, min_samples_split=2, n_estimators=100;, score=0.522 total time=   0.2s
# [CV 4/5] END max_depth=10, min_samples_leaf=2, min_samples_split=2, n_estimators=100;, score=0.481 total time=   0.2s
# [CV 5/5] END max_depth=10, min_samples_leaf=2, min_samples_split=2, n_estimators=100;, score=0.491 total time=   0.2s
# [CV 1/5] END max_depth=10, min_samples_leaf=2, min_samples_split=2, n_estimators=200;, score=0.506 total time=   0.3s
# [CV 2/5] END max_depth=10, min_samples_leaf=2, min_samples_split=2, n_estimators=200;, score=0.453 total time=   0.4s
# [CV 3/5] END max_depth=10, min_samples_leaf=2, min_samples_split=2, n_estimators=200;, score=0.519 total time=   0.3s
# [CV 4/5] END max_depth=10, min_samples_leaf=2, min_samples_split=2, n_estimators=200;, score=0.488 total time=   0.4s
# [CV 5/5] END max_depth=10, min_samples_leaf=2, min_samples_split=2, n_estimators=200;, score=0.466 total time=   0.4s
# [CV 1/5] END max_depth=10, min_samples_leaf=2, min_samples_split=5, n_estimators=100;, score=0.506 total time=   0.2s
# [CV 2/5] END max_depth=10, min_samples_leaf=2, min_samples_split=5, n_estimators=100;, score=0.441 total time=   0.2s
# [CV 3/5] END max_depth=10, min_samples_leaf=2, min_samples_split=5, n_estimators=100;, score=0.516 total time=   0.2s
# [CV 4/5] END max_depth=10, min_samples_leaf=2, min_samples_split=5, n_estimators=100;, score=0.497 total time=   0.2s
# [CV 5/5] END max_depth=10, min_samples_leaf=2, min_samples_split=5, n_estimators=100;, score=0.434 total time=   0.2s
# [CV 1/5] END max_depth=10, min_samples_leaf=2, min_samples_split=5, n_estimators=200;, score=0.531 total time=   0.3s
# [CV 2/5] END max_depth=10, min_samples_leaf=2, min_samples_split=5, n_estimators=200;, score=0.441 total time=   0.3s
# [CV 3/5] END max_depth=10, min_samples_leaf=2, min_samples_split=5, n_estimators=200;, score=0.512 total time=   0.3s
# [CV 4/5] END max_depth=10, min_samples_leaf=2, min_samples_split=5, n_estimators=200;, score=0.500 total time=   0.3s
# [CV 5/5] END max_depth=10, min_samples_leaf=2, min_samples_split=5, n_estimators=200;, score=0.469 total time=   0.3s
# [CV 1/5] END max_depth=20, min_samples_leaf=1, min_samples_split=2, n_estimators=100;, score=0.519 total time=   0.2s
# [CV 2/5] END max_depth=20, min_samples_leaf=1, min_samples_split=2, n_estimators=100;, score=0.434 total time=   0.2s
# [CV 3/5] END max_depth=20, min_samples_leaf=1, min_samples_split=2, n_estimators=100;, score=0.525 total time=   0.2s
# [CV 4/5] END max_depth=20, min_samples_leaf=1, min_samples_split=2, n_estimators=100;, score=0.519 total time=   0.2s
# [CV 5/5] END max_depth=20, min_samples_leaf=1, min_samples_split=2, n_estimators=100;, score=0.472 total time=   0.2s
# [CV 1/5] END max_depth=20, min_samples_leaf=1, min_samples_split=2, n_estimators=200;, score=0.509 total time=   0.4s
# [CV 2/5] END max_depth=20, min_samples_leaf=1, min_samples_split=2, n_estimators=200;, score=0.444 total time=   0.4s
# [CV 3/5] END max_depth=20, min_samples_leaf=1, min_samples_split=2, n_estimators=200;, score=0.509 total time=   0.4s
# [CV 4/5] END max_depth=20, min_samples_leaf=1, min_samples_split=2, n_estimators=200;, score=0.494 total time=   0.4s
# [CV 5/5] END max_depth=20, min_samples_leaf=1, min_samples_split=2, n_estimators=200;, score=0.472 total time=   0.4s
# [CV 1/5] END max_depth=20, min_samples_leaf=1, min_samples_split=5, n_estimators=100;, score=0.500 total time=   0.2s
# [CV 2/5] END max_depth=20, min_samples_leaf=1, min_samples_split=5, n_estimators=100;, score=0.444 total time=   0.2s
# [CV 3/5] END max_depth=20, min_samples_leaf=1, min_samples_split=5, n_estimators=100;, score=0.491 total time=   0.2s
# [CV 4/5] END max_depth=20, min_samples_leaf=1, min_samples_split=5, n_estimators=100;, score=0.491 total time=   0.2s
# [CV 5/5] END max_depth=20, min_samples_leaf=1, min_samples_split=5, n_estimators=100;, score=0.469 total time=   0.2s
# [CV 1/5] END max_depth=20, min_samples_leaf=1, min_samples_split=5, n_estimators=200;, score=0.484 total time=   0.4s
# [CV 2/5] END max_depth=20, min_samples_leaf=1, min_samples_split=5, n_estimators=200;, score=0.463 total time=   0.4s
# [CV 3/5] END max_depth=20, min_samples_leaf=1, min_samples_split=5, n_estimators=200;, score=0.506 total time=   0.5s
# [CV 4/5] END max_depth=20, min_samples_leaf=1, min_samples_split=5, n_estimators=200;, score=0.516 total time=   0.5s
# [CV 5/5] END max_depth=20, min_samples_leaf=1, min_samples_split=5, n_estimators=200;, score=0.478 total time=   0.5s
# [CV 1/5] END max_depth=20, min_samples_leaf=2, min_samples_split=2, n_estimators=100;, score=0.466 total time=   0.3s
# [CV 2/5] END max_depth=20, min_samples_leaf=2, min_samples_split=2, n_estimators=100;, score=0.453 total time=   0.3s
# [CV 3/5] END max_depth=20, min_samples_leaf=2, min_samples_split=2, n_estimators=100;, score=0.556 total time=   0.3s
# [CV 4/5] END max_depth=20, min_samples_leaf=2, min_samples_split=2, n_estimators=100;, score=0.497 total time=   0.3s
# [CV 5/5] END max_depth=20, min_samples_leaf=2, min_samples_split=2, n_estimators=100;, score=0.475 total time=   0.3s
# [CV 1/5] END max_depth=20, min_samples_leaf=2, min_samples_split=2, n_estimators=200;, score=0.481 total time=   0.4s
# [CV 2/5] END max_depth=20, min_samples_leaf=2, min_samples_split=2, n_estimators=200;, score=0.434 total time=   0.4s
# [CV 3/5] END max_depth=20, min_samples_leaf=2, min_samples_split=2, n_estimators=200;, score=0.512 total time=   0.4s
# [CV 4/5] END max_depth=20, min_samples_leaf=2, min_samples_split=2, n_estimators=200;, score=0.506 total time=   0.4s
# [CV 5/5] END max_depth=20, min_samples_leaf=2, min_samples_split=2, n_estimators=200;, score=0.472 total time=   0.4s
# [CV 1/5] END max_depth=20, min_samples_leaf=2, min_samples_split=5, n_estimators=100;, score=0.519 total time=   0.2s
# [CV 2/5] END max_depth=20, min_samples_leaf=2, min_samples_split=5, n_estimators=100;, score=0.441 total time=   0.2s
# [CV 3/5] END max_depth=20, min_samples_leaf=2, min_samples_split=5, n_estimators=100;, score=0.503 total time=   0.2s
# [CV 4/5] END max_depth=20, min_samples_leaf=2, min_samples_split=5, n_estimators=100;, score=0.506 total time=   0.2s
# [CV 5/5] END max_depth=20, min_samples_leaf=2, min_samples_split=5, n_estimators=100;, score=0.469 total time=   0.2s
# [CV 1/5] END max_depth=20, min_samples_leaf=2, min_samples_split=5, n_estimators=200;, score=0.531 total time=   0.4s
# [CV 2/5] END max_depth=20, min_samples_leaf=2, min_samples_split=5, n_estimators=200;, score=0.444 total time=   0.4s
# [CV 3/5] END max_depth=20, min_samples_leaf=2, min_samples_split=5, n_estimators=200;, score=0.503 total time=   0.4s
# [CV 4/5] END max_depth=20, min_samples_leaf=2, min_samples_split=5, n_estimators=200;, score=0.503 total time=   0.4s
# [CV 5/5] END max_depth=20, min_samples_leaf=2, min_samples_split=5, n_estimators=200;, score=0.466 total time=   0.4s
# cuml GridSearchCV training time (RF) : 24.89 seconds
# cuml Best parameters (RF): {'max_depth': 20, 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 100}
# scikit-learn GridSearchCV training time (RF) : 68.62 seconds
# scikit-learn Best parameters (RF): {'max_depth': 10, 'min_samples_leaf': 2, 'min_samples_split': 5, 'n_estimators': 200}
# /usr/local/lib/python3.11/dist-packages/sklearn/model_selection/_validation.py:528: FitFailedWarning:
# 40 fits failed out of a total of 120.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 40 fits failed with the following error:
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.11/dist-packages/sklearn/model_selection/_validation.py", line 866, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/usr/local/lib/python3.11/dist-packages/nvtx/nvtx.py", line 122, in inner
#     result = func(*args, **kwargs)
#              ^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/cuml/internals/api_decorators.py", line 193, in wrapper
#     ret = func(*args, **kwargs)
#           ^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/cuml/internals/api_decorators.py", line 416, in dispatch
#     return self.dispatch_func(func_name, gpu_func, *args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/cuml/internals/api_decorators.py", line 195, in wrapper
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "base.pyx", line 764, in cuml.internals.base.UniversalBase.dispatch_func
#   File "randomforestclassifier.pyx", line 493, in cuml.ensemble.randomforestclassifier.RandomForestClassifier.fit
# TypeError: an integer is required
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# /usr/local/lib/python3.11/dist-packages/sklearn/model_selection/_search.py:1108: UserWarning: One or more of the test scores are non-finite: [       nan        nan        nan        nan        nan        nan
#         nan        nan 0.48625    0.48812501 0.47187499 0.4825
#  0.488125   0.48625001 0.47875    0.490625   0.49375    0.48562499
#  0.47875    0.48937501 0.48937499 0.48125    0.48750001 0.489375  ]
#   warnings.warn(

# %% [markdown]
# # Prediction & Model Evaluation

# %%
from sklearn.metrics import accuracy_score, confusion_matrix, ConfusionMatrixDisplay
import matplotlib.pyplot as plt

# --- Comparison and Evaluation ---
model_names = list(sk_models.keys()) # Assuming cu_models will have the same keys if cuML is available

for model_name in model_names:
    print(f"--- Evaluating: {model_name} ---")

    # --- scikit-learn model ---
    if model_name in sk_models:
        print("\n-- scikit-learn --")
        best_sk_model = sk_models[model_name].best_estimator_

        # Predictions
        y_pred_train_sk = best_sk_model.predict(X_train)
        y_pred_test_sk = best_sk_model.predict(X_test)
        start_time = time.time()
        sk_pred[model_name] = best_sk_model.predict(X)
        end_time = time.time()
        sk_pred_times[model_name] = end_time - start_time
        print(f"Prediction Duration: {sk_pred_times[model_name]:.2f} seconds")

        # Accuracy
        train_accuracy_sk = accuracy_score(y_train, y_pred_train_sk)
        test_accuracy_sk = accuracy_score(y_test, y_pred_test_sk)
        sk_train_accuracy[model_name] = train_accuracy_sk
        sk_test_accuracy[model_name] = test_accuracy_sk
        print(f"Train Accuracy: {train_accuracy_sk:.4f}")
        print(f"Test Accuracy: {test_accuracy_sk:.4f}")

        # Cross-validation score
        cv_score_sk = sk_models[model_name].best_score_
        sk_crossValidation_accuracy[model_name] = cv_score_sk
        print(f"Best Cross-Validation Score: {cv_score_sk:.4f}")

        # Duration
        print(f"Training Duration: {sk_times[model_name]:.2f} seconds")

        # Confusion Matrix
        print("Confusion Matrix (Test Set):")
        cm_sk = confusion_matrix(y_test, y_pred_test_sk)
        disp_sk = ConfusionMatrixDisplay(confusion_matrix=cm_sk, display_labels=best_sk_model.classes_)
        disp_sk.plot()
        plt.title(f"scikit-learn {model_name} - Confusion Matrix")
        plt.show()


    # --- cuML model ---
    print("\n-- cuML --")
    if has_cuml and model_name in cu_models:
        best_cu_model = cu_models[model_name].best_estimator_

        # Predictions

        # Note: cuML predict might require cuDF DataFrame or NumPy array
        # Ensuring X_train and X_test are in a compatible format (e.g., NumPy)
        # If they are pandas DataFrames, cuML usually handles them, but explicit conversion can be safer.
        y_pred_train_cu = best_cu_model.predict(X_train.to_numpy() if hasattr(X_train, 'to_numpy') else X_train)
        y_pred_test_cu = best_cu_model.predict(X_test.to_numpy() if hasattr(X_test, 'to_numpy') else X_test)
        start_time = time.time()
        cu_pred[model_name] = best_cu_model.predict(X.to_numpy() if hasattr(X, 'to_numpy') else X)
        end_time = time.time()
        cu_pred_times[model_name] = end_time - start_time
        print(f"Prediction Duration: {cu_pred_times[model_name]:.2f} seconds")

        # If predictions are cuPy arrays, convert them to NumPy for scikit-learn metrics
        if hasattr(y_pred_train_cu, 'get'): # Check if it's a cuPy array
            y_pred_train_cu = y_pred_train_cu.get()
        if hasattr(y_pred_test_cu, 'get'): # Check if it's a cuPy array
            y_pred_test_cu = y_pred_test_cu.get()


        # Accuracy
        train_accuracy_cu = accuracy_score(y_train, y_pred_train_cu) # y_train is pandas Series, compatible
        test_accuracy_cu = accuracy_score(y_test, y_pred_test_cu)   # y_test is pandas Series, compatible
        cu_train_accuracy[model_name] = train_accuracy_cu
        cu_test_accuracy[model_name] = test_accuracy_cu
        print(f"Train Accuracy: {train_accuracy_cu:.4f}")
        print(f"Test Accuracy: {test_accuracy_cu:.4f}")

        # Cross-validation score
        cv_score_cu = cu_models[model_name].best_score_
        cu_crossValidation_accuracy[f"cu_{model_name}"] = cv_score_cu
        print(f"Best Cross-Validation Score: {cv_score_cu:.4f}")

        # Duration
        # if model_name in cu_times: # Check if cu_times was populated
        print(f"Training Duration: {cu_times[model_name]:.2f} seconds")

        # Confusion Matrix
        print("Confusion Matrix (Test Set):")
        cm_cu = confusion_matrix(y_test, y_pred_test_cu)
        # Ensure classes are correctly obtained for cuML model if different from sklearn
        # For SVC, .classes_ should be available after fitting.
        disp_cu = ConfusionMatrixDisplay(confusion_matrix=cm_cu, display_labels=best_cu_model.classes_)
        disp_cu.plot()
        plt.title(f"cuML {model_name} - Confusion Matrix")
        plt.show()
    else:
        print(f"cuML {model_name} was not run as cuML model for it is not available.")

    print("\n" + "="*40 + "\n")

print("\nSummary of Accuracies and Times:")
print("scikit-learn Train Accuracies:", sk_train_accuracy)
print("CuML Train Accuracies:", cu_train_accuracy)
print("scikit-learn Test Accuracies:", sk_test_accuracy)
print("CuML Test Accuracies:", cu_test_accuracy)
print("scikit-learn Cross-Validation Accuracies:", sk_crossValidation_accuracy)
print("CuML Cross-Validation Accuracies:", cu_crossValidation_accuracy)
print("scikit-learn Training Times:", sk_times)
print("cuML Training Times:", cu_times)
print("scikit-learn Prediction Times:", sk_pred_times)
print("cuML Prediction Times:", cu_pred_times)
# Out:
# --- Evaluating: SVM ---
#
# -- scikit-learn --
# Prediction Duration: 0.13 seconds
# Train Accuracy: 0.5150
# Test Accuracy: 0.5125
# Best Cross-Validation Score: 0.5112
# Training Duration: 6.64 seconds
# Confusion Matrix (Test Set):
# -- cuML --
# Prediction Duration: 0.00 seconds
# Train Accuracy: 0.5150
# Test Accuracy: 0.5125
# Best Cross-Validation Score: 0.5112
# Training Duration: 6.07 seconds
# Confusion Matrix (Test Set):
# ========================================
#
# --- Evaluating: KNN ---
#
# -- scikit-learn --
# Prediction Duration: 0.04 seconds
# Train Accuracy: 1.0000
# Test Accuracy: 0.5125
# Best Cross-Validation Score: 0.5081
# Training Duration: 1.76 seconds
# Confusion Matrix (Test Set):
# -- cuML --
# Prediction Duration: 0.00 seconds
# Train Accuracy: 0.7625
# Test Accuracy: 0.5150
# Best Cross-Validation Score: 0.5062
# Training Duration: 2.27 seconds
# Confusion Matrix (Test Set):
# ========================================
#
# --- Evaluating: RF ---
#
# -- scikit-learn --
# Prediction Duration: 0.04 seconds
# Train Accuracy: 0.9806
# Test Accuracy: 0.4950
# Best Cross-Validation Score: 0.5044
# Training Duration: 68.62 seconds
# Confusion Matrix (Test Set):
# -- cuML --
# Prediction Duration: 0.01 seconds
# Train Accuracy: 1.0000
# Test Accuracy: 0.4975
# Best Cross-Validation Score: 0.4938
# Training Duration: 24.89 seconds
# Confusion Matrix (Test Set):
# ========================================
#
#
# Summary of Accuracies and Times:
# scikit-learn Train Accuracies: {'SVM': 0.515, 'KNN': 1.0, 'RF': 0.980625}
# CuML Train Accuracies: {'SVM': 0.515, 'KNN': 0.7625, 'RF': 1.0}
# scikit-learn Test Accuracies: {'SVM': 0.5125, 'KNN': 0.5125, 'RF': 0.495}
# CuML Test Accuracies: {'SVM': 0.5125, 'KNN': 0.515, 'RF': 0.4975}
# scikit-learn Cross-Validation Accuracies: {'SVM': np.float64(0.51125), 'KNN': np.float64(0.5081249999999999), 'RF': np.float64(0.504375)}
# CuML Cross-Validation Accuracies: {'cu_SVM': np.float64(0.5112499952316284), 'cu_KNN': np.float64(0.5062499940395355), 'cu_RF': np.float64(0.49375)}
# scikit-learn Training Times: {'SVM': 6.639094591140747, 'KNN': 1.764807939529419, 'RF': 68.62082004547119}
# cuML Training Times: {'SVM': 6.072004318237305, 'KNN': 2.2729384899139404, 'RF': 24.889572381973267}
# scikit-learn Prediction Times: {'SVM': 0.12967967987060547, 'KNN': 0.035556793212890625, 'RF': 0.04062080383300781}
# cuML Prediction Times: {'SVM': 0.002256155014038086, 'KNN': 0.0030372142791748047, 'RF': 0.005882740020751953}

# %%
import matplotlib.pyplot as plt
import matplotlib.colors as mcolors
import pandas as pd

# Ensure all necessary variables are defined from previous cells:
# data, df, y, sk_pred, cu_pred, has_cuml (for cuML models)
# X (to get the index for aligning predictions if they are numpy arrays)

if 'DEPT' not in data.columns:
    print("Error: 'DEPT' column not found in data DataFrame. Cannot generate depth plots.")
else:
    depth_column = data['DEPT']
    feature_names = df.columns.tolist()

    # Prepare labels and predictions (same as before)
    true_labels = y
    all_predictions_to_plot = {}
    all_predictions_to_plot['True Labels'] = true_labels
    for model_name, preds in sk_pred.items():
        all_predictions_to_plot[f'SK: {model_name}'] = preds
    if has_cuml and cu_pred:
        for model_name, preds_cu in cu_pred.items():
            if hasattr(preds_cu, 'get'):
                preds_np = preds_cu.get()
            else:
                preds_np = preds_cu
            all_predictions_to_plot[f'CU: {model_name}'] = preds_np

    # Define colors for classes (same as before)
    if isinstance(true_labels, np.ndarray):
        unique_classes = np.sort(np.unique(true_labels))
    else:
        unique_classes = np.sort(true_labels.unique())

    if len(unique_classes) == 1:
        plot_colors = ['gold']
    elif len(unique_classes) == 2:
        plot_colors = ['gold', 'darkorange']
    else:
        cmap_tab10 = plt.cm.get_cmap('tab10', len(unique_classes))
        plot_colors = [mcolors.to_hex(cmap_tab10(i)) for i in range(len(unique_classes))]

    class_to_int = {cls: i for i, cls in enumerate(unique_classes)}
    cmap_listed = mcolors.ListedColormap(plot_colors[:len(unique_classes)])


    # --- Figure 1: feature Tracks ---
    num_feature_plots = len(feature_names)
    if num_feature_plots > 0:
        fig_features, axes_features = plt.subplots(1, num_feature_plots, figsize=(num_feature_plots * 2.5, 10), sharey=True)
        if num_feature_plots == 1: # Handle single feature case for axes indexing
            axes_features = [axes_features]
        fig_features.suptitle("Feature Tracks", fontsize=16, y=0.98)

        for i, feature_name in enumerate(feature_names):
            ax = axes_features[i]
            ax.plot(data[feature_name].loc[X.index], depth_column.loc[X.index])
            ax.set_title(feature_name, fontsize=10)
            ax.set_xlabel("Value", fontsize=8)
            if i == 0:
                ax.set_ylabel("DEPT (feet)", fontsize=10)
            ax.grid(True, linestyle='--', alpha=0.7)
            ax.tick_params(axis='x', labelsize=8)
            ax.tick_params(axis='y', labelsize=8)

        axes_features[0].invert_yaxis()
        plt.tight_layout(rect=[0, 0.03, 1, 0.95])
        plt.show()
    else:
        print("No features to plot for feature tracks.")

    # --- Figure 2: scaled feature Tracks ---
    num_feature_plots = len(feature_names)
    if num_feature_plots > 0:
        fig_features, axes_features = plt.subplots(1, num_feature_plots, figsize=(num_feature_plots * 2.5, 10), sharey=True)
        if num_feature_plots == 1: # Handle single feature case for axes indexing
            axes_features = [axes_features]
        fig_features.suptitle("Scaled Feature Tracks", fontsize=16, y=0.98)

        for i, feature_name in enumerate(feature_names):
            ax = axes_features[i]
            ax.plot(X[feature_name].loc[X.index], depth_column.loc[X.index])
            ax.set_title(feature_name, fontsize=10)
            ax.set_xlabel("Value", fontsize=8)
            if i == 0:
                ax.set_ylabel("DEPT (feet)", fontsize=10)
            ax.grid(True, linestyle='--', alpha=0.7)
            ax.tick_params(axis='x', labelsize=8)
            ax.tick_params(axis='y', labelsize=8)

        axes_features[0].invert_yaxis()
        plt.tight_layout(rect=[0, 0.03, 1, 0.95])
        plt.show()
    else:
        print("No features to plot for scaled feature tracks.")

    # --- Figure 3: Classification Tracks ---
    num_classification_plots = len(all_predictions_to_plot)
    if num_classification_plots > 0:
        # Adjust figsize: width per plot can be smaller for classification tracks
        fig_class, axes_class = plt.subplots(1, num_classification_plots, figsize=(num_classification_plots * 1.2, 10), sharey=True)
        if num_classification_plots == 1: # Handle single classification plot case
            axes_class = [axes_class]
        fig_class.suptitle("Classification Tracks", fontsize=16, y=0.98)

        plot_order = ['True Labels'] + [k for k in all_predictions_to_plot.keys() if k != 'True Labels']

        for i, title in enumerate(plot_order):
            predictions_data = all_predictions_to_plot[title]
            ax = axes_class[i]

            if isinstance(predictions_data, pd.Series):
                if not predictions_data.index.equals(X.index):
                    # This should ideally not happen with consistent data handling
                    # For safety, one might reindex or ensure alignment upstream
                    print(f"Warning: Index mismatch for {title}. Plotting may be incorrect.")
                mapped_preds = predictions_data.map(class_to_int).fillna(-1)
            elif isinstance(predictions_data, np.ndarray):
                temp_series = pd.Series(predictions_data, index=X.index)
                mapped_preds = temp_series.map(class_to_int).fillna(-1)
            else:
                print(f"Warning: Data for {title} is of unexpected type: {type(predictions_data)}")
                continue

            labels_int = mapped_preds.values.reshape(-1, 1)
            vmin = 0
            vmax = len(plot_colors) - 1

            ax.imshow(labels_int, aspect='auto', cmap=cmap_listed,
                      extent=[0, 1, depth_column.loc[X.index].max(), depth_column.loc[X.index].min()],
                      interpolation='none', vmin=vmin, vmax=vmax)

            if title == 'True Labels':
                ax.set_title("True Class", fontsize=10)
            else:
                ax.set_title(title, fontsize=10)

            ax.set_xticks([])
            ax.set_xlabel("")
            ax.tick_params(axis='y', labelsize=8)
            if i == 0: # Set Y-axis label only for the first plot in this figure
                ax.set_ylabel("DEPT (feet)", fontsize=10)


        axes_class[0].invert_yaxis()

        if unique_classes is not None and len(unique_classes) > 0:
            patches = [plt.Rectangle((0,0),1,1, color=plot_colors[class_to_int[cls]]) for cls in unique_classes]
            legend_labels = [str(cls) for cls in unique_classes]
            fig_class.legend(patches, legend_labels, loc='lower center', ncol=len(unique_classes), bbox_to_anchor=(0.5, -0.02), title="Classes")

        plt.tight_layout(rect=[0, 0.03, 1, 0.93])
        plt.show()
    else:
        print("No classification data to plot.")

# %% [markdown]
# # Shutdown colab runtime

# %%
# Execution time
end_notebook = time.time()
print(f"Total notebook execution time: {end_notebook - start_notebook:.2f} seconds")
# Out:
# Total notebook execution time: 127.73 seconds

# %%
if is_running_on_colab:
    from google.colab import runtime
    runtime.unassign()
