# %% [markdown]
# # Retrieve data

# %%
try:
    from google.colab import drive
    is_running_on_colab = True
except ImportError:
    is_running_on_colab = False

if is_running_on_colab:
    # Mount Google Drive
    drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import time
start_notebook = time.time()

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
import numpy as np

# %%
# Option to generate mock data
generate_mock_data = True # Set to True to generate mock data
max_mock_depth_ft = 8000 # Define maximum depth for mock data

# %%
well_name = "LLB-10"
if not generate_mock_data:
  if is_running_on_colab:
    # Load data from Google Drive, if running on Google Colab
    colab_repo_dir = "/content/drive/MyDrive/riset-fttm-gdrive/cuml-tf-model-hydrocarbon-prediction"
    data = pd.read_csv(f"{colab_repo_dir}/data/interpreted/interpreted_{well_name}.csv", sep=',')
  else:
    # Load data from local directory
    data = pd.read_csv(f"./data/interpreted/interpreted_{well_name}.csv", sep=',')

# %%
if generate_mock_data:
    print(f"Generating mock data up to {max_mock_depth_ft} ft for well {well_name}...")
    mock_depth_step = 0.5
    mock_dept_values = np.arange(0, max_mock_depth_ft, mock_depth_step)
    num_mock_rows = len(mock_dept_values)

    mock_data_dict = {'DEPT': mock_dept_values}

    feature_cols_for_mock = ['CALI','DRHO','GR','MR','NPHI_corr','PEF','RHOB_CORR','ROP']

    for col in feature_cols_for_mock:
        mock_data_dict[col] = np.random.rand(num_mock_rows) * 100

    mock_data_dict['hydrocarbon_formation_class'] = np.random.randint(0, 2, num_mock_rows)

    data = pd.DataFrame(mock_data_dict)

    print(f"Mock data generated for well {well_name} with {num_mock_rows} rows and columns: {list(data.columns)}.")
    print("Mock data head:")
    print(data.head())
# Out:
# Generating mock data up to 8000 ft for well LLB-10...
# Mock data generated for well LLB-10 with 16000 rows and columns: ['DEPT', 'CALI', 'DRHO', 'GR', 'MR', 'NPHI_corr', 'PEF', 'RHOB_CORR', 'ROP', 'hydrocarbon_formation_class'].
# Mock data head:
#    DEPT       CALI       DRHO         GR         MR  NPHI_corr        PEF  \
# 0   0.0  46.509025  43.769836  51.485190  62.681816  58.858139  58.349643
# 1   0.5  26.503492  60.684425  69.020466  78.233379  41.573107  36.866852
# 2   1.0  42.199037  29.830657  36.441246  16.003439  77.706311  25.615872
# 3   1.5  65.040409  16.621223  25.579788  11.676929  55.061491  35.249926
# 4   2.0  45.874548  94.621433  10.429676  64.935655  49.095465  38.980874
#
#    RHOB_CORR        ROP  hydrocarbon_formation_class
# 0  10.744433  47.076152                            1
# 1  55.564377  86.454499                            0
# 2  97.832668  68.948286                            1
# 3  16.430298   8.183535                            0
# 4  38.582799   3.895162                            1

# %%
df=data[['CALI','DRHO','GR','MR','NPHI_corr','PEF','RHOB_CORR','ROP']]
df
# Out:
#             CALI       DRHO         GR         MR  NPHI_corr        PEF  \
# 0      46.509025  43.769836  51.485190  62.681816  58.858139  58.349643
# 1      26.503492  60.684425  69.020466  78.233379  41.573107  36.866852
# 2      42.199037  29.830657  36.441246  16.003439  77.706311  25.615872
# 3      65.040409  16.621223  25.579788  11.676929  55.061491  35.249926
# 4      45.874548  94.621433  10.429676  64.935655  49.095465  38.980874
# ...          ...        ...        ...        ...        ...        ...
# 15995  67.928916  31.531693  15.856804  11.573028  61.252056  44.621733
# 15996  16.213096  28.486363  57.982278  29.060387  13.308149  62.953647
# 15997   3.207745  65.994516   1.334101  16.021977  81.745934   4.850567
# 15998  53.129764  33.904919  89.380021  35.942610  85.941107  88.195287
# 15999  52.506586  19.299727  84.650097  65.241026  29.276833  83.597991
#
#        RHOB_CORR        ROP
# 0      10.744433  47.076152
# 1      55.564377  86.454499
# 2      97.832668  68.948286
# 3      16.430298   8.183535
# 4      38.582799   3.895162
# ...          ...        ...
# 15995  82.880315  43.913406
# 15996  47.442486  60.201907
# 15997  79.191700  51.592444
# 15998  42.231597  20.343144
# 15999   2.947020  79.063430
#
# [16000 rows x 8 columns]

# %% [markdown]
# # Data Preparation

# %% [markdown]
# ## Train/Test Splitting

# %%
# Misalkan 'data' adalah DataFrame Anda dan 'df' adalah fitur yang telah Anda ekstrak
X = df  # Fitur
y = data['hydrocarbon_formation_class']  # Label

# Split data menjadi training dan testing set
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, stratify=y, random_state=42)

# %%
X_train.describe()
# Out:
#                CALI          DRHO            GR            MR     NPHI_corr  \
# count  12800.000000  12800.000000  12800.000000  12800.000000  12800.000000
# mean      50.412502     50.300848     49.668517     50.109180     50.093244
# std       28.921185     29.027969     28.898750     28.715733     28.746357
# min        0.005862      0.001095      0.000398      0.017601      0.000101
# 25%       25.619839     25.348554     24.368094     25.643694     25.188347
# 50%       50.934243     50.173729     49.799092     50.083389     49.995603
# 75%       75.418191     75.910489     74.638797     74.901027     74.926807
# max       99.994386     99.983297     99.994999     99.996418     99.989588
#
#                 PEF     RHOB_CORR           ROP
# count  12800.000000  12800.000000  12800.000000
# mean      50.178973     49.899106     49.622323
# std       28.908995     28.922909     28.809662
# min        0.011537      0.006699      0.003492
# 25%       25.251182     24.888350     24.639960
# 50%       49.930914     49.900102     49.229977
# 75%       75.351811     74.679361     74.550984
# max       99.999524     99.998968     99.999271

# %% [markdown]
# ## Apply Quantile Transformation

# %%
from sklearn.preprocessing import QuantileTransformer
def transform_quantile(X_train, X_test, X):
    qt_transformer = QuantileTransformer(output_distribution='normal')
    dfs = [X_train, X_test, X]
    qt_dfs = [None,None,None]
    for i, df in enumerate(dfs):
        if (i == 0): #only perform fit_transform on training data
            qt_dfs[i] = pd.DataFrame(qt_transformer.fit_transform(df))
        else:
            qt_dfs[i] = pd.DataFrame(qt_transformer.transform(df))
        qt_dfs[i].columns = df.columns.values
        qt_dfs[i].index = df.index.values
    return qt_dfs[0], qt_dfs[1], qt_dfs[2] #X_train, X_test, X

# %%
X_train, X_test, X = transform_quantile(X_train, X_test, X)

# %% [markdown]
# ## Feature Scaling
#
# karena menggunakan Quatile transformation dengan output gaussian, masing masing kolom secara otomatis ditransformasi ke distribusi normal baku, atau distribusi normal dengan rataan nol dan standar deviasi 1, oleh karena itu tidak diperlukan tambahan scaling.

# %%
X_train.describe()
# Out:
#                CALI          DRHO            GR            MR     NPHI_corr  \
# count  12800.000000  12800.000000  12800.000000  12800.000000  12800.000000
# mean      -0.004441      0.000861     -0.007489     -0.002734      0.000473
# std        0.998543      1.000866      1.003078      1.006486      0.999122
# min       -5.199338     -5.199338     -5.199338     -5.199338     -5.199338
# 25%       -0.677099     -0.672763     -0.681865     -0.680137     -0.671070
# 50%       -0.003949     -0.004363     -0.010359     -0.000824      0.002761
# 75%        0.670457      0.679187      0.670434      0.674048      0.675664
# max        5.199338      5.199338      5.199338      5.199338      5.199338
#
#                 PEF     RHOB_CORR           ROP
# count  12800.000000  12800.000000  12800.000000
# mean       0.000592      0.003607     -0.013303
# std        1.006211      1.005268      1.001010
# min       -5.199338     -5.199338     -5.199338
# 25%       -0.667113     -0.668083     -0.685984
# 50%        0.002337      0.001048     -0.013872
# 75%        0.664728      0.671746      0.657617
# max        5.199338      5.199338      5.199338

# %% [markdown]
# # Training setup

# %%
import time
import numpy as np
from sklearn.model_selection import GridSearchCV


sk_train_accuracy={}
sk_test_accuracy={}

cu_train_accuracy={}
cu_test_accuracy={}

sk_crossValidation_accuracy={}
cu_crossValidation_accuracy={}

sk_models = {} #sklearn models
cu_models = {} #cuml models

sk_times = {}
cu_times = {}

sk_pred = {}
cu_pred = {}

sk_pred_times = {}
cu_pred_times = {}

# %%
# test CuML availability & is working
try:
    import cuml
    kmeans = cuml.KMeans(n_clusters=2)
    # Create minimal dummy data
    dummy_data = np.array([[1, 2], [1.5, 1.8], [5, 8], [8, 8]])
    kmeans.fit(dummy_data)
    # Attempt to fit the model
    has_cuml = True
    print("cuML is found and working")
except ImportError:
    has_cuml = False
    print("cuML not found. Please ensure cuML is installed.")
except Exception as e:
    has_cuml = False
    print(f"cuML couldn't be initialized or used. Error: {e}")
# Out:
# cuML is found and working
# /usr/local/lib/python3.11/dist-packages/cuml/internals/api_decorators.py:195: FutureWarning: The default value of `n_init` will change from 1 to 'auto' in 25.04. Set the value of `n_init` explicitly to suppress this warning.
#   return func(*args, **kwargs)

# %% [markdown]
# # Models

# %% [markdown]
# ## SVM

# %%
model_name = "SVM"

# %%
from sklearn.svm import SVC as SklearnSVC
# Attempt to import cuML's SVC
try:
    from cuml.svm import SVC as cuMLSVC
except ImportError:
    print("cuML SVC not available. Please ensure cuML is installed and compatible with your environment.")

# %%
# Parameter grid for both models
param_grid = {
    'C': [0.1, 1, 10],
    'gamma': ['scale', 'auto']
}

# 1) scikit-learn SVM with GridSearchCV
sk_models[model_name] = GridSearchCV(
    estimator=SklearnSVC(kernel='rbf'),
    param_grid=param_grid,
    cv=5,
    verbose=3,
    n_jobs=-1
)

time_start = time.time()
sk_models[model_name].fit(X_train, y_train)
time_end = time.time()
sk_times[model_name] = time_end - time_start

# 2) cuML SVM with the same GridSearchCV
if has_cuml:
    cu_models[model_name] = GridSearchCV(
        estimator=cuMLSVC(kernel='rbf'),
        param_grid=param_grid,
        cv=5,
        verbose=3,
        # Note: cuML estimator runs on GPU; this grid search runs on CPU orchestrating GPU calls
        n_jobs=1  # avoid multiprocessing issues with GPU
    )

    time_start = time.time()
    cu_models[model_name].fit(X_train, y_train)
    time_end = time.time()
    cu_times[model_name] = time_end - time_start
    print(f"cuml GridSearchCV training time ({model_name}) : {cu_times[model_name]:.2f} seconds")
    print(f"cuml Best parameters ({model_name}): {cu_models[model_name].best_params_}")
else:
    print("cuML is not installed or GPU not available. Please install RAPIDS cuML to run this benchmark.")

print(f"scikit-learn GridSearchCV training time ({model_name}) : {sk_times[model_name]:.2f} seconds")
print(f"scikit-learn Best parameters ({model_name}): {sk_models[model_name].best_params_}")
# Out:
# Fitting 5 folds for each of 6 candidates, totalling 30 fits
# Fitting 5 folds for each of 6 candidates, totalling 30 fits
# [CV 1/5] END ................C=0.1, gamma=scale;, score=0.502 total time=   3.5s
# [CV 2/5] END ................C=0.1, gamma=scale;, score=0.506 total time=   0.2s
# [CV 3/5] END ................C=0.1, gamma=scale;, score=0.507 total time=   0.2s
# [CV 4/5] END ................C=0.1, gamma=scale;, score=0.511 total time=   0.2s
# [CV 5/5] END ................C=0.1, gamma=scale;, score=0.500 total time=   0.2s
# [CV 1/5] END .................C=0.1, gamma=auto;, score=0.501 total time=   0.2s
# [CV 2/5] END .................C=0.1, gamma=auto;, score=0.505 total time=   0.2s
# [CV 3/5] END .................C=0.1, gamma=auto;, score=0.507 total time=   0.2s
# [CV 4/5] END .................C=0.1, gamma=auto;, score=0.512 total time=   0.2s
# [CV 5/5] END .................C=0.1, gamma=auto;, score=0.502 total time=   0.2s
# [CV 1/5] END ..................C=1, gamma=scale;, score=0.510 total time=   0.3s
# [CV 2/5] END ..................C=1, gamma=scale;, score=0.511 total time=   0.3s
# [CV 3/5] END ..................C=1, gamma=scale;, score=0.510 total time=   0.3s
# [CV 4/5] END ..................C=1, gamma=scale;, score=0.519 total time=   0.3s
# [CV 5/5] END ..................C=1, gamma=scale;, score=0.511 total time=   0.3s
# [CV 1/5] END ...................C=1, gamma=auto;, score=0.509 total time=   0.3s
# [CV 2/5] END ...................C=1, gamma=auto;, score=0.511 total time=   0.3s
# [CV 3/5] END ...................C=1, gamma=auto;, score=0.509 total time=   0.3s
# [CV 4/5] END ...................C=1, gamma=auto;, score=0.519 total time=   0.3s
# [CV 5/5] END ...................C=1, gamma=auto;, score=0.511 total time=   0.3s
# [CV 1/5] END .................C=10, gamma=scale;, score=0.512 total time=   1.9s
# [CV 2/5] END .................C=10, gamma=scale;, score=0.498 total time=   1.9s
# [CV 3/5] END .................C=10, gamma=scale;, score=0.512 total time=   1.9s
# [CV 4/5] END .................C=10, gamma=scale;, score=0.521 total time=   1.9s
# [CV 5/5] END .................C=10, gamma=scale;, score=0.514 total time=   1.9s
# [CV 1/5] END ..................C=10, gamma=auto;, score=0.513 total time=   1.9s
# [CV 2/5] END ..................C=10, gamma=auto;, score=0.498 total time=   1.9s
# [CV 3/5] END ..................C=10, gamma=auto;, score=0.513 total time=   1.8s
# [CV 4/5] END ..................C=10, gamma=auto;, score=0.520 total time=   2.0s
# [CV 5/5] END ..................C=10, gamma=auto;, score=0.514 total time=   1.9s
# cuml GridSearchCV training time (SVM) : 27.86 seconds
# cuml Best parameters (SVM): {'C': 1, 'gamma': 'scale'}
# scikit-learn GridSearchCV training time (SVM) : 173.83 seconds
# scikit-learn Best parameters (SVM): {'C': 1, 'gamma': 'scale'}

# %% [markdown]
# ## K-Nearest Neighbors

# %%
model_name = "KNN"

# %%
from sklearn.neighbors import KNeighborsClassifier as SklearnKNeighborsClassifier
# Attempt to import cuML's KNeighborsClassifier
try:
    from cuml.neighbors import KNeighborsClassifier as cuMLKNeighborsClassifier
    # has_cuml is already defined from SVM section, assuming if SVM cuml is available, KNN cuml is too.
except ImportError:
    # If cuML was previously found but KNN specific part is missing, update has_cuml for KNN context if necessary
    # For simplicity, we rely on the initial has_cuml check. If specific components are missing,
    # the cuML KNN block will be skipped or error out, which is acceptable.
    # A more robust check could be:
    # try: from cuml.svm import SVC as cuMLSVC; has_cuml_svm = True except: has_cuml_svm = False
    # try: from cuml.neighbors import KNeighborsClassifier as cuMLKNeighborsClassifier; has_cuml_knn = True except: has_cuml_knn = False
    pass # Rely on global has_cuml

# %%
# Parameter grid for KNN
param_grid_knn = {
    'n_neighbors': [3, 5, 7, 9, 11],
    'weights': ['uniform', 'distance'],
    'metric': ['euclidean', 'manhattan']
}

# 1) scikit-learn KNN with GridSearchCV
sk_models[model_name] = GridSearchCV(
    estimator=SklearnKNeighborsClassifier(),
    param_grid=param_grid_knn,
    cv=5,
    verbose=3,
    n_jobs=-1
)

time_start = time.time()
sk_models[model_name].fit(X_train, y_train)
time_end = time.time()
sk_times[model_name] = time_end - time_start

# 2) cuML KNN with the same GridSearchCV (adapted for cuML)
if has_cuml:
    try:
        # Ensure cuMLKNeighborsClassifier was imported
        cuMLKNeighborsClassifier

        cu_models[model_name] = GridSearchCV(
            estimator=cuMLKNeighborsClassifier(), # cuML KNN
            param_grid=param_grid_knn, # Using the same grid, ensure params are compatible
            cv=5,
            verbose=3,
            n_jobs=1 # Potentially can be >1 if managed carefully, but 1 is safer for GPU resources with GridSearchCV
        )

        time_start = time.time()
        # cuML's KNN might prefer numpy arrays or cuDF dataframes
        # X_train and y_train are pandas, which cuml usually handles.
        # If issues arise, convert: X_train_cu = X_train.to_numpy(), y_train_cu = y_train.to_numpy()
        cu_models[model_name].fit(X_train, y_train)
        time_end = time.time()
        cu_times[model_name] = time_end - time_start
        print(f"cuml GridSearchCV training time ({model_name}) : {cu_times[model_name]:.2f} seconds")
        print(f"cuml Best parameters ({model_name}): {cu_models[model_name].best_params_}")
    except NameError: # handles if cuMLKNeighborsClassifier was not imported
        print(f"cuML KNeighborsClassifier not available. Skipping cuML {model_name} training.")
    except Exception as e:
        print(f"An error occurred during cuML {model_name} training: {e}")
        # Optionally, remove the model key if setup failed partway
        if model_name in cu_models: del cu_models[model_name]
        if model_name in cu_times: del cu_times[model_name]

else:
    print(f"cuML is not installed or GPU not available. Skipping cuML {model_name} benchmark.")

print(f"scikit-learn GridSearchCV training time ({model_name}) : {sk_times[model_name]:.2f} seconds")
print(f"scikit-learn Best parameters ({model_name}): {sk_models[model_name].best_params_}")
# Out:
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# [2025-05-27 15:19:55.407] [CUML] [info] Unused keyword parameter: n_jobs during cuML estimator initialization
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# [2025-05-27 15:19:55.410] [CUML] [info] Unused keyword parameter: n_jobs during cuML estimator initialization
# [CV 1/5] END metric=euclidean, n_neighbors=3, weights=uniform;, score=0.505 total time=   1.6s
# [2025-05-27 15:19:57.003] [CUML] [info] Unused keyword parameter: n_jobs during cuML estimator initialization
# [CV 2/5] END metric=euclidean, n_neighbors=3, weights=uniform;, score=0.519 total time=   0.0s
# [2025-05-27 15:19:57.016] [CUML] [info] Unused keyword parameter: n_jobs during cuML estimator initialization
# [CV 3/5] END metric=euclidean, n_neighbors=3, weights=uniform;, score=0.503 total time=   0.0s
# [2025-05-27 15:19:57.029] [CUML] [info] Unused keyword parameter: n_jobs during cuML estimator initialization
# [CV 4/5] END metric=euclidean, n_neighbors=3, weights=uniform;, score=0.502 total time=   0.0s
# [2025-05-27 15:19:57.039] [CUML] [info] Unused keyword parameter: n_jobs during cuML estimator initialization
# [CV 5/5] END metric=euclidean, n_neighbors=3, weights=uniform;, score=0.511 total time=   0.0s
# [2025-05-27 15:19:57.051] [CUML] [info] Unused keyword parameter: n_jobs during cuML estimator initialization
# [CV 1/5] END metric=euclidean, n_neighbors=3, weights=distance;, score=0.505 total time=   0.0s
# [2025-05-27 15:19:57.061] [CUML] [info] Unused keyword parameter: n_jobs during cuML estimator initialization
# [CV 2/5] END metric=euclidean, n_neighbors=3, weights=distance;, score=0.519 total time=   0.0s
# [2025-05-27 15:19:57.072] [CUML] [info] Unused keyword parameter: n_jobs during cuML estimator initialization
# [CV 3/5] END metric=euclidean, n_neighbors=3, weights=distance;, score=0.503 total time=   0.0s
# [2025-05-27 15:19:57.083] [CUML] [info] Unused keyword parameter: n_jobs during cuML estimator initialization
# [CV 4/5] END metric=euclidean, n_neighbors=3, weights=distance;, score=0.502 total time=   0.0s
# [2025-05-27 15:19:57.094] [CUML] [info] Unused keyword parameter: n_jobs during cuML estimator initialization
# [CV 5/5] END metric=euclidean, n_neighbors=3, weights=distance;, score=0.511 total time=   0.0s
# [2025-05-27 15:19:57.105] [CUML] [info] Unused keyword parameter: n_jobs during cuML estimator initialization
# [CV 1/5] END metric=euclidean, n_neighbors=5, weights=uniform;, score=0.496 total time=   0.0s
# [2025-05-27 15:19:57.116] [CUML] [info] Unused keyword parameter: n_jobs during cuML estimator initialization
# [CV 2/5] END metric=euclidean, n_neighbors=5, weights=uniform;, score=0.500 total time=   0.0s
# [2025-05-27 15:19:57.127] [CUML] [info] Unused keyword parameter: n_jobs during cuML estimator initialization
# [CV 3/5] END metric=euclidean, n_neighbors=5, weights=uniform;, score=0.502 total time=   0.0s
# [2025-05-27 15:19:57.138] [CUML] [info] Unused keyword parameter: n_jobs during cuML estimator initialization
# [CV 4/5] END metric=euclidean, n_neighbors=5, weights=uniform;, score=0.509 total time=   0.0s
# [2025-05-27 15:19:57.148] [CUML] [info] Unused keyword parameter: n_jobs during cuML estimator initialization
# [CV 5/5] END metric=euclidean, n_neighbors=5, weights=uniform;, score=0.511 total time=   0.0s
# [2025-05-27 15:19:57.160] [CUML] [info] Unused keyword parameter: n_jobs during cuML estimator initialization
# [CV 1/5] END metric=euclidean, n_neighbors=5, weights=distance;, score=0.496 total time=   0.0s
# [2025-05-27 15:19:57.170] [CUML] [info] Unused keyword parameter: n_jobs during cuML estimator initialization
# [CV 2/5] END metric=euclidean, n_neighbors=5, weights=distance;, score=0.500 total time=   0.0s
# [2025-05-27 15:19:57.182] [CUML] [info] Unused keyword parameter: n_jobs during cuML estimator initialization
# [CV 3/5] END metric=euclidean, n_neighbors=5, weights=distance;, score=0.502 total time=   0.0s
# [2025-05-27 15:19:57.193] [CUML] [info] Unused keyword parameter: n_jobs during cuML estimator initialization
# [CV 4/5] END metric=euclidean, n_neighbors=5, weights=distance;, score=0.509 total time=   0.0s
# [2025-05-27 15:19:57.204] [CUML] [info] Unused keyword parameter: n_jobs during cuML estimator initialization
# [CV 5/5] END metric=euclidean, n_neighbors=5, weights=distance;, score=0.511 total time=   0.0s
# [2025-05-27 15:19:57.216] [CUML] [info] Unused keyword parameter: n_jobs during cuML estimator initialization
# [CV 1/5] END metric=euclidean, n_neighbors=7, weights=uniform;, score=0.496 total time=   0.0s
# [2025-05-27 15:19:57.228] [CUML] [info] Unused keyword parameter: n_jobs during cuML estimator initialization
# [CV 2/5] END metric=euclidean, n_neighbors=7, weights=uniform;, score=0.508 total time=   0.0s
# [2025-05-27 15:19:57.239] [CUML] [info] Unused keyword parameter: n_jobs during cuML estimator initialization
# [CV 3/5] END metric=euclidean, n_neighbors=7, weights=uniform;, score=0.521 total time=   0.0s
# [2025-05-27 15:19:57.250] [CUML] [info] Unused keyword parameter: n_jobs during cuML estimator initialization
# [CV 4/5] END metric=euclidean, n_neighbors=7, weights=uniform;, score=0.512 total time=   0.0s
# [2025-05-27 15:19:57.261] [CUML] [info] Unused keyword parameter: n_jobs during cuML estimator initialization
# [CV 5/5] END metric=euclidean, n_neighbors=7, weights=uniform;, score=0.510 total time=   0.0s
# [2025-05-27 15:19:57.272] [CUML] [info] Unused keyword parameter: n_jobs during cuML estimator initialization
# [CV 1/5] END metric=euclidean, n_neighbors=7, weights=distance;, score=0.496 total time=   0.0s
# [2025-05-27 15:19:57.284] [CUML] [info] Unused keyword parameter: n_jobs during cuML estimator initialization
# [CV 2/5] END metric=euclidean, n_neighbors=7, weights=distance;, score=0.508 total time=   0.0s
# [2025-05-27 15:19:57.295] [CUML] [info] Unused keyword parameter: n_jobs during cuML estimator initialization
# [CV 3/5] END metric=euclidean, n_neighbors=7, weights=distance;, score=0.521 total time=   0.0s
# [2025-05-27 15:19:57.309] [CUML] [info] Unused keyword parameter: n_jobs during cuML estimator initialization
# [CV 4/5] END metric=euclidean, n_neighbors=7, weights=distance;, score=0.512 total time=   0.0s
# [2025-05-27 15:19:57.321] [CUML] [info] Unused keyword parameter: n_jobs during cuML estimator initialization
# [CV 5/5] END metric=euclidean, n_neighbors=7, weights=distance;, score=0.510 total time=   0.0s
# [2025-05-27 15:19:57.332] [CUML] [info] Unused keyword parameter: n_jobs during cuML estimator initialization
# [CV 1/5] END metric=euclidean, n_neighbors=9, weights=uniform;, score=0.503 total time=   0.0s
# [2025-05-27 15:19:57.343] [CUML] [info] Unused keyword parameter: n_jobs during cuML estimator initialization
# [CV 2/5] END metric=euclidean, n_neighbors=9, weights=uniform;, score=0.507 total time=   0.0s
# [2025-05-27 15:19:57.354] [CUML] [info] Unused keyword parameter: n_jobs during cuML estimator initialization
# [CV 3/5] END metric=euclidean, n_neighbors=9, weights=uniform;, score=0.521 total time=   0.0s
# [2025-05-27 15:19:57.366] [CUML] [info] Unused keyword parameter: n_jobs during cuML estimator initialization
# [CV 4/5] END metric=euclidean, n_neighbors=9, weights=uniform;, score=0.507 total time=   0.0s
# [2025-05-27 15:19:57.377] [CUML] [info] Unused keyword parameter: n_jobs during cuML estimator initialization
# [CV 5/5] END metric=euclidean, n_neighbors=9, weights=uniform;, score=0.508 total time=   0.0s
# [2025-05-27 15:19:57.388] [CUML] [info] Unused keyword parameter: n_jobs during cuML estimator initialization
# [CV 1/5] END metric=euclidean, n_neighbors=9, weights=distance;, score=0.503 total time=   0.0s
# [2025-05-27 15:19:57.399] [CUML] [info] Unused keyword parameter: n_jobs during cuML estimator initialization
# [CV 2/5] END metric=euclidean, n_neighbors=9, weights=distance;, score=0.507 total time=   0.0s
# [2025-05-27 15:19:57.410] [CUML] [info] Unused keyword parameter: n_jobs during cuML estimator initialization
# [CV 3/5] END metric=euclidean, n_neighbors=9, weights=distance;, score=0.521 total time=   0.0s
# [2025-05-27 15:19:57.423] [CUML] [info] Unused keyword parameter: n_jobs during cuML estimator initialization
# [CV 4/5] END metric=euclidean, n_neighbors=9, weights=distance;, score=0.507 total time=   0.0s
# [2025-05-27 15:19:57.434] [CUML] [info] Unused keyword parameter: n_jobs during cuML estimator initialization
# [CV 5/5] END metric=euclidean, n_neighbors=9, weights=distance;, score=0.508 total time=   0.0s
# [2025-05-27 15:19:57.446] [CUML] [info] Unused keyword parameter: n_jobs during cuML estimator initialization
# [CV 1/5] END metric=euclidean, n_neighbors=11, weights=uniform;, score=0.493 total time=   0.0s
# [2025-05-27 15:19:57.458] [CUML] [info] Unused keyword parameter: n_jobs during cuML estimator initialization
# [CV 2/5] END metric=euclidean, n_neighbors=11, weights=uniform;, score=0.508 total time=   0.0s
# [2025-05-27 15:19:57.469] [CUML] [info] Unused keyword parameter: n_jobs during cuML estimator initialization
# [CV 3/5] END metric=euclidean, n_neighbors=11, weights=uniform;, score=0.520 total time=   0.0s
# [2025-05-27 15:19:57.481] [CUML] [info] Unused keyword parameter: n_jobs during cuML estimator initialization
# [CV 4/5] END metric=euclidean, n_neighbors=11, weights=uniform;, score=0.516 total time=   0.0s
# [2025-05-27 15:19:57.492] [CUML] [info] Unused keyword parameter: n_jobs during cuML estimator initialization
# [CV 5/5] END metric=euclidean, n_neighbors=11, weights=uniform;, score=0.489 total time=   0.0s
# [2025-05-27 15:19:57.504] [CUML] [info] Unused keyword parameter: n_jobs during cuML estimator initialization
# [CV 1/5] END metric=euclidean, n_neighbors=11, weights=distance;, score=0.493 total time=   0.0s
# [2025-05-27 15:19:57.515] [CUML] [info] Unused keyword parameter: n_jobs during cuML estimator initialization
# [CV 2/5] END metric=euclidean, n_neighbors=11, weights=distance;, score=0.508 total time=   0.0s
# [2025-05-27 15:19:57.527] [CUML] [info] Unused keyword parameter: n_jobs during cuML estimator initialization
# [CV 3/5] END metric=euclidean, n_neighbors=11, weights=distance;, score=0.520 total time=   0.0s
# [2025-05-27 15:19:57.538] [CUML] [info] Unused keyword parameter: n_jobs during cuML estimator initialization
# [CV 4/5] END metric=euclidean, n_neighbors=11, weights=distance;, score=0.516 total time=   0.0s
# [2025-05-27 15:19:57.549] [CUML] [info] Unused keyword parameter: n_jobs during cuML estimator initialization
# [CV 5/5] END metric=euclidean, n_neighbors=11, weights=distance;, score=0.489 total time=   0.0s
# [2025-05-27 15:19:57.561] [CUML] [info] Unused keyword parameter: n_jobs during cuML estimator initialization
# [CV 1/5] END metric=manhattan, n_neighbors=3, weights=uniform;, score=0.507 total time=   0.1s
# [2025-05-27 15:19:57.666] [CUML] [info] Unused keyword parameter: n_jobs during cuML estimator initialization
# [CV 2/5] END metric=manhattan, n_neighbors=3, weights=uniform;, score=0.496 total time=   0.0s
# [2025-05-27 15:19:57.682] [CUML] [info] Unused keyword parameter: n_jobs during cuML estimator initialization
# [CV 3/5] END metric=manhattan, n_neighbors=3, weights=uniform;, score=0.512 total time=   0.0s
# [2025-05-27 15:19:57.695] [CUML] [info] Unused keyword parameter: n_jobs during cuML estimator initialization
# [CV 4/5] END metric=manhattan, n_neighbors=3, weights=uniform;, score=0.512 total time=   0.0s
# [2025-05-27 15:19:57.708] [CUML] [info] Unused keyword parameter: n_jobs during cuML estimator initialization
# [CV 5/5] END metric=manhattan, n_neighbors=3, weights=uniform;, score=0.515 total time=   0.0s
# [2025-05-27 15:19:57.721] [CUML] [info] Unused keyword parameter: n_jobs during cuML estimator initialization
# [CV 1/5] END metric=manhattan, n_neighbors=3, weights=distance;, score=0.507 total time=   0.0s
# [2025-05-27 15:19:57.733] [CUML] [info] Unused keyword parameter: n_jobs during cuML estimator initialization
# [CV 2/5] END metric=manhattan, n_neighbors=3, weights=distance;, score=0.496 total time=   0.0s
# [2025-05-27 15:19:57.747] [CUML] [info] Unused keyword parameter: n_jobs during cuML estimator initialization
# [CV 3/5] END metric=manhattan, n_neighbors=3, weights=distance;, score=0.512 total time=   0.0s
# [2025-05-27 15:19:57.759] [CUML] [info] Unused keyword parameter: n_jobs during cuML estimator initialization
# [CV 4/5] END metric=manhattan, n_neighbors=3, weights=distance;, score=0.512 total time=   0.0s
# [2025-05-27 15:19:57.773] [CUML] [info] Unused keyword parameter: n_jobs during cuML estimator initialization
# [CV 5/5] END metric=manhattan, n_neighbors=3, weights=distance;, score=0.515 total time=   0.0s
# [2025-05-27 15:19:57.786] [CUML] [info] Unused keyword parameter: n_jobs during cuML estimator initialization
# [CV 1/5] END metric=manhattan, n_neighbors=5, weights=uniform;, score=0.500 total time=   0.0s
# [2025-05-27 15:19:57.799] [CUML] [info] Unused keyword parameter: n_jobs during cuML estimator initialization
# [CV 2/5] END metric=manhattan, n_neighbors=5, weights=uniform;, score=0.498 total time=   0.0s
# [2025-05-27 15:19:57.812] [CUML] [info] Unused keyword parameter: n_jobs during cuML estimator initialization
# [CV 3/5] END metric=manhattan, n_neighbors=5, weights=uniform;, score=0.499 total time=   0.0s
# [2025-05-27 15:19:57.825] [CUML] [info] Unused keyword parameter: n_jobs during cuML estimator initialization
# [CV 4/5] END metric=manhattan, n_neighbors=5, weights=uniform;, score=0.514 total time=   0.0s
# [2025-05-27 15:19:57.837] [CUML] [info] Unused keyword parameter: n_jobs during cuML estimator initialization
# [CV 5/5] END metric=manhattan, n_neighbors=5, weights=uniform;, score=0.510 total time=   0.0s
# [2025-05-27 15:19:57.850] [CUML] [info] Unused keyword parameter: n_jobs during cuML estimator initialization
# [CV 1/5] END metric=manhattan, n_neighbors=5, weights=distance;, score=0.500 total time=   0.0s
# [2025-05-27 15:19:57.863] [CUML] [info] Unused keyword parameter: n_jobs during cuML estimator initialization
# [CV 2/5] END metric=manhattan, n_neighbors=5, weights=distance;, score=0.498 total time=   0.0s
# [2025-05-27 15:19:57.877] [CUML] [info] Unused keyword parameter: n_jobs during cuML estimator initialization
# [CV 3/5] END metric=manhattan, n_neighbors=5, weights=distance;, score=0.499 total time=   0.0s
# [2025-05-27 15:19:57.890] [CUML] [info] Unused keyword parameter: n_jobs during cuML estimator initialization
# [CV 4/5] END metric=manhattan, n_neighbors=5, weights=distance;, score=0.514 total time=   0.0s
# [2025-05-27 15:19:57.903] [CUML] [info] Unused keyword parameter: n_jobs during cuML estimator initialization
# [CV 5/5] END metric=manhattan, n_neighbors=5, weights=distance;, score=0.510 total time=   0.0s
# [2025-05-27 15:19:57.915] [CUML] [info] Unused keyword parameter: n_jobs during cuML estimator initialization
# [CV 1/5] END metric=manhattan, n_neighbors=7, weights=uniform;, score=0.496 total time=   0.0s
# [2025-05-27 15:19:57.928] [CUML] [info] Unused keyword parameter: n_jobs during cuML estimator initialization
# [CV 2/5] END metric=manhattan, n_neighbors=7, weights=uniform;, score=0.505 total time=   0.0s
# [2025-05-27 15:19:57.940] [CUML] [info] Unused keyword parameter: n_jobs during cuML estimator initialization
# [CV 3/5] END metric=manhattan, n_neighbors=7, weights=uniform;, score=0.512 total time=   0.0s
# [2025-05-27 15:19:57.953] [CUML] [info] Unused keyword parameter: n_jobs during cuML estimator initialization
# [CV 4/5] END metric=manhattan, n_neighbors=7, weights=uniform;, score=0.516 total time=   0.0s
# [2025-05-27 15:19:57.966] [CUML] [info] Unused keyword parameter: n_jobs during cuML estimator initialization
# [CV 5/5] END metric=manhattan, n_neighbors=7, weights=uniform;, score=0.507 total time=   0.0s
# [2025-05-27 15:19:57.978] [CUML] [info] Unused keyword parameter: n_jobs during cuML estimator initialization
# [CV 1/5] END metric=manhattan, n_neighbors=7, weights=distance;, score=0.496 total time=   0.0s
# [2025-05-27 15:19:57.990] [CUML] [info] Unused keyword parameter: n_jobs during cuML estimator initialization
# [CV 2/5] END metric=manhattan, n_neighbors=7, weights=distance;, score=0.505 total time=   0.0s
# [2025-05-27 15:19:58.002] [CUML] [info] Unused keyword parameter: n_jobs during cuML estimator initialization
# [CV 3/5] END metric=manhattan, n_neighbors=7, weights=distance;, score=0.512 total time=   0.0s
# [2025-05-27 15:19:58.017] [CUML] [info] Unused keyword parameter: n_jobs during cuML estimator initialization
# [CV 4/5] END metric=manhattan, n_neighbors=7, weights=distance;, score=0.516 total time=   0.0s
# [2025-05-27 15:19:58.034] [CUML] [info] Unused keyword parameter: n_jobs during cuML estimator initialization
# [CV 5/5] END metric=manhattan, n_neighbors=7, weights=distance;, score=0.507 total time=   0.0s
# [2025-05-27 15:19:58.048] [CUML] [info] Unused keyword parameter: n_jobs during cuML estimator initialization
# [CV 1/5] END metric=manhattan, n_neighbors=9, weights=uniform;, score=0.500 total time=   0.0s
# [2025-05-27 15:19:58.060] [CUML] [info] Unused keyword parameter: n_jobs during cuML estimator initialization
# [CV 2/5] END metric=manhattan, n_neighbors=9, weights=uniform;, score=0.510 total time=   0.0s
# [2025-05-27 15:19:58.073] [CUML] [info] Unused keyword parameter: n_jobs during cuML estimator initialization
# [CV 3/5] END metric=manhattan, n_neighbors=9, weights=uniform;, score=0.513 total time=   0.0s
# [2025-05-27 15:19:58.086] [CUML] [info] Unused keyword parameter: n_jobs during cuML estimator initialization
# [CV 4/5] END metric=manhattan, n_neighbors=9, weights=uniform;, score=0.520 total time=   0.0s
# [2025-05-27 15:19:58.099] [CUML] [info] Unused keyword parameter: n_jobs during cuML estimator initialization
# [CV 5/5] END metric=manhattan, n_neighbors=9, weights=uniform;, score=0.506 total time=   0.0s
# [2025-05-27 15:19:58.112] [CUML] [info] Unused keyword parameter: n_jobs during cuML estimator initialization
# [CV 1/5] END metric=manhattan, n_neighbors=9, weights=distance;, score=0.500 total time=   0.0s
# [2025-05-27 15:19:58.124] [CUML] [info] Unused keyword parameter: n_jobs during cuML estimator initialization
# [CV 2/5] END metric=manhattan, n_neighbors=9, weights=distance;, score=0.510 total time=   0.0s
# [2025-05-27 15:19:58.137] [CUML] [info] Unused keyword parameter: n_jobs during cuML estimator initialization
# [CV 3/5] END metric=manhattan, n_neighbors=9, weights=distance;, score=0.513 total time=   0.0s
# [2025-05-27 15:19:58.149] [CUML] [info] Unused keyword parameter: n_jobs during cuML estimator initialization
# [CV 4/5] END metric=manhattan, n_neighbors=9, weights=distance;, score=0.520 total time=   0.0s
# [2025-05-27 15:19:58.162] [CUML] [info] Unused keyword parameter: n_jobs during cuML estimator initialization
# [CV 5/5] END metric=manhattan, n_neighbors=9, weights=distance;, score=0.506 total time=   0.0s
# [2025-05-27 15:19:58.174] [CUML] [info] Unused keyword parameter: n_jobs during cuML estimator initialization
# [CV 1/5] END metric=manhattan, n_neighbors=11, weights=uniform;, score=0.498 total time=   0.0s
# [2025-05-27 15:19:58.186] [CUML] [info] Unused keyword parameter: n_jobs during cuML estimator initialization
# [CV 2/5] END metric=manhattan, n_neighbors=11, weights=uniform;, score=0.518 total time=   0.0s
# [2025-05-27 15:19:58.199] [CUML] [info] Unused keyword parameter: n_jobs during cuML estimator initialization
# [CV 3/5] END metric=manhattan, n_neighbors=11, weights=uniform;, score=0.513 total time=   0.0s
# [2025-05-27 15:19:58.211] [CUML] [info] Unused keyword parameter: n_jobs during cuML estimator initialization
# [CV 4/5] END metric=manhattan, n_neighbors=11, weights=uniform;, score=0.516 total time=   0.0s
# [2025-05-27 15:19:58.223] [CUML] [info] Unused keyword parameter: n_jobs during cuML estimator initialization
# [CV 5/5] END metric=manhattan, n_neighbors=11, weights=uniform;, score=0.503 total time=   0.0s
# [2025-05-27 15:19:58.235] [CUML] [info] Unused keyword parameter: n_jobs during cuML estimator initialization
# [CV 1/5] END metric=manhattan, n_neighbors=11, weights=distance;, score=0.498 total time=   0.0s
# [2025-05-27 15:19:58.248] [CUML] [info] Unused keyword parameter: n_jobs during cuML estimator initialization
# [CV 2/5] END metric=manhattan, n_neighbors=11, weights=distance;, score=0.518 total time=   0.0s
# [2025-05-27 15:19:58.260] [CUML] [info] Unused keyword parameter: n_jobs during cuML estimator initialization
# [CV 3/5] END metric=manhattan, n_neighbors=11, weights=distance;, score=0.513 total time=   0.0s
# [2025-05-27 15:19:58.273] [CUML] [info] Unused keyword parameter: n_jobs during cuML estimator initialization
# [CV 4/5] END metric=manhattan, n_neighbors=11, weights=distance;, score=0.516 total time=   0.0s
# [2025-05-27 15:19:58.285] [CUML] [info] Unused keyword parameter: n_jobs during cuML estimator initialization
# [CV 5/5] END metric=manhattan, n_neighbors=11, weights=distance;, score=0.503 total time=   0.0s
# [2025-05-27 15:19:58.300] [CUML] [info] Unused keyword parameter: n_jobs during cuML estimator initialization
# cuml GridSearchCV training time (KNN) : 2.90 seconds
# cuml Best parameters (KNN): {'metric': 'manhattan', 'n_neighbors': 9, 'weights': 'uniform'}
# scikit-learn GridSearchCV training time (KNN) : 33.77 seconds
# scikit-learn Best parameters (KNN): {'metric': 'manhattan', 'n_neighbors': 11, 'weights': 'distance'}

# %% [markdown]
# ## Random Forest

# %%
model_name = "RF"

# %%
from sklearn.ensemble import RandomForestClassifier as SklearnRandomForestClassifier
# Attempt to import cuML's RandomForestClassifier
try:
    from cuml.ensemble import RandomForestClassifier as cuMLRandomForestClassifier
    # has_cuml is already defined, assuming if previous cuML models are available, RF is too.
except ImportError:
    # Pass, relying on global has_cuml. Specific check for cuMLRandomForestClassifier will happen in the training block.
    pass

# %%
# Parameter grid for Random Forest
param_grid_rf = {
    'n_estimators': [100, 200], # Number of trees in the forest
    'max_depth': [None, 10, 20],    # Maximum depth of the tree
    'min_samples_split': [2, 5], # Minimum number of samples required to split an internal node
    'min_samples_leaf': [1, 2],   # Minimum number of samples required to be at a leaf node
    # 'max_features': ['auto', 'sqrt'] # Number of features to consider when looking for the best split (cuML might have different defaults/options)
    # For cuML compatibility, specific parameters like 'max_features' might need adjustment or careful selection.
    # cuML RandomForestClassifier has slightly different parameter names or accepted values for some arguments.
    # e.g. max_features in cuML can be int, float, or 'auto' (auto is sqrt(n_features)).
}

# 1) scikit-learn RandomForest with GridSearchCV
sk_models[model_name] = GridSearchCV(
    estimator=SklearnRandomForestClassifier(random_state=42),
    param_grid=param_grid_rf,
    cv=5, # Using 3-fold CV for RF due to potentially longer training times
    verbose=3,
    n_jobs=-1
)

time_start = time.time()
sk_models[model_name].fit(X_train, y_train)
time_end = time.time()
sk_times[model_name] = time_end - time_start


# 2) cuML RandomForest with GridSearchCV (adapted for cuML)
if has_cuml:
    try:
        # Ensure cuMLRandomForestClassifier was imported
        cuMLRandomForestClassifier

        # cuML specific parameter adjustments if necessary.
        # For example, cuML's RandomForestClassifier might not support all string options for max_features like sklearn.
        # It typically supports int (number of features) or float (fraction of features). 'auto' is often sqrt(n_features).
        # Let's use a simplified grid or ensure compatibility.
        # The provided param_grid_rf should generally work if 'max_features' is omitted or set to a compatible value.

        cu_models[model_name] = GridSearchCV(
            estimator=cuMLRandomForestClassifier(random_state=42), # cuML RandomForest
            param_grid=param_grid_rf, # Ensure parameters are compatible with cuML RF
            cv=5, # Using 3-fold CV
            verbose=3,
            n_jobs=1 # Safer for GPU resources with GridSearchCV
        )

        time_start = time.time()
        cu_models[model_name].fit(X_train, y_train) # X_train, y_train are pandas, cuML handles this
        time_end = time.time()
        cu_times[model_name] = time_end - time_start
        print(f"cuml GridSearchCV training time ({model_name}) : {cu_times[model_name]:.2f} seconds")
        print(f"cuml Best parameters ({model_name}): {cu_models[model_name].best_params_}")
    except NameError:
        print(f"cuML RandomForestClassifier not available. Skipping cuML {model_name} training.")
    except Exception as e:
        print(f"An error occurred during cuML {model_name} training: {e}")
        if model_name in cu_models: del cu_models[model_name]
        if model_name in cu_times: del cu_times[model_name]
else:
    print(f"cuML is not installed or GPU not available. Skipping cuML {model_name} benchmark.")

print(f"scikit-learn GridSearchCV training time ({model_name}) : {sk_times[model_name]:.2f} seconds")
print(f"scikit-learn Best parameters ({model_name}): {sk_models[model_name].best_params_}")
# Out:
# Fitting 5 folds for each of 24 candidates, totalling 120 fits
# /usr/local/lib/python3.11/dist-packages/cuml/internals/api_decorators.py:368: UserWarning: For reproducible results in Random Forest Classifier or for almost reproducible results in Random Forest Regressor, n_streams=1 is recommended. If n_streams is > 1, results may vary due to stream/thread timing differences, even when random_state is set
#   return init_func(self, *args, **kwargs)
# /usr/local/lib/python3.11/dist-packages/cuml/internals/api_decorators.py:368: UserWarning: For reproducible results in Random Forest Classifier or for almost reproducible results in Random Forest Regressor, n_streams=1 is recommended. If n_streams is > 1, results may vary due to stream/thread timing differences, even when random_state is set
#   return init_func(self, *args, **kwargs)
# /usr/local/lib/python3.11/dist-packages/cuml/internals/api_decorators.py:368: UserWarning: For reproducible results in Random Forest Classifier or for almost reproducible results in Random Forest Regressor, n_streams=1 is recommended. If n_streams is > 1, results may vary due to stream/thread timing differences, even when random_state is set
#   return init_func(self, *args, **kwargs)
# Fitting 5 folds for each of 24 candidates, totalling 120 fits
# [CV 1/5] END max_depth=None, min_samples_leaf=1, min_samples_split=2, n_estimators=100;, score=nan total time=   0.2s
# [CV 2/5] END max_depth=None, min_samples_leaf=1, min_samples_split=2, n_estimators=100;, score=nan total time=   0.0s
# [CV 3/5] END max_depth=None, min_samples_leaf=1, min_samples_split=2, n_estimators=100;, score=nan total time=   0.0s
# [CV 4/5] END max_depth=None, min_samples_leaf=1, min_samples_split=2, n_estimators=100;, score=nan total time=   0.0s
# [CV 5/5] END max_depth=None, min_samples_leaf=1, min_samples_split=2, n_estimators=100;, score=nan total time=   0.0s
# [CV 1/5] END max_depth=None, min_samples_leaf=1, min_samples_split=2, n_estimators=200;, score=nan total time=   0.0s
# [CV 2/5] END max_depth=None, min_samples_leaf=1, min_samples_split=2, n_estimators=200;, score=nan total time=   0.0s
# [CV 3/5] END max_depth=None, min_samples_leaf=1, min_samples_split=2, n_estimators=200;, score=nan total time=   0.0s
# [CV 4/5] END max_depth=None, min_samples_leaf=1, min_samples_split=2, n_estimators=200;, score=nan total time=   0.0s
# [CV 5/5] END max_depth=None, min_samples_leaf=1, min_samples_split=2, n_estimators=200;, score=nan total time=   0.0s
# [CV 1/5] END max_depth=None, min_samples_leaf=1, min_samples_split=5, n_estimators=100;, score=nan total time=   0.0s
# [CV 2/5] END max_depth=None, min_samples_leaf=1, min_samples_split=5, n_estimators=100;, score=nan total time=   0.0s
# [CV 3/5] END max_depth=None, min_samples_leaf=1, min_samples_split=5, n_estimators=100;, score=nan total time=   0.0s
# [CV 4/5] END max_depth=None, min_samples_leaf=1, min_samples_split=5, n_estimators=100;, score=nan total time=   0.0s
# [CV 5/5] END max_depth=None, min_samples_leaf=1, min_samples_split=5, n_estimators=100;, score=nan total time=   0.0s
# [CV 1/5] END max_depth=None, min_samples_leaf=1, min_samples_split=5, n_estimators=200;, score=nan total time=   0.0s
# [CV 2/5] END max_depth=None, min_samples_leaf=1, min_samples_split=5, n_estimators=200;, score=nan total time=   0.0s
# [CV 3/5] END max_depth=None, min_samples_leaf=1, min_samples_split=5, n_estimators=200;, score=nan total time=   0.0s
# [CV 4/5] END max_depth=None, min_samples_leaf=1, min_samples_split=5, n_estimators=200;, score=nan total time=   0.0s
# [CV 5/5] END max_depth=None, min_samples_leaf=1, min_samples_split=5, n_estimators=200;, score=nan total time=   0.0s
# [CV 1/5] END max_depth=None, min_samples_leaf=2, min_samples_split=2, n_estimators=100;, score=nan total time=   0.0s
# [CV 2/5] END max_depth=None, min_samples_leaf=2, min_samples_split=2, n_estimators=100;, score=nan total time=   0.0s
# [CV 3/5] END max_depth=None, min_samples_leaf=2, min_samples_split=2, n_estimators=100;, score=nan total time=   0.0s
# [CV 4/5] END max_depth=None, min_samples_leaf=2, min_samples_split=2, n_estimators=100;, score=nan total time=   0.0s
# [CV 5/5] END max_depth=None, min_samples_leaf=2, min_samples_split=2, n_estimators=100;, score=nan total time=   0.0s
# [CV 1/5] END max_depth=None, min_samples_leaf=2, min_samples_split=2, n_estimators=200;, score=nan total time=   0.0s
# [CV 2/5] END max_depth=None, min_samples_leaf=2, min_samples_split=2, n_estimators=200;, score=nan total time=   0.0s
# [CV 3/5] END max_depth=None, min_samples_leaf=2, min_samples_split=2, n_estimators=200;, score=nan total time=   0.0s
# [CV 4/5] END max_depth=None, min_samples_leaf=2, min_samples_split=2, n_estimators=200;, score=nan total time=   0.0s
# [CV 5/5] END max_depth=None, min_samples_leaf=2, min_samples_split=2, n_estimators=200;, score=nan total time=   0.0s
# [CV 1/5] END max_depth=None, min_samples_leaf=2, min_samples_split=5, n_estimators=100;, score=nan total time=   0.0s
# [CV 2/5] END max_depth=None, min_samples_leaf=2, min_samples_split=5, n_estimators=100;, score=nan total time=   0.0s
# [CV 3/5] END max_depth=None, min_samples_leaf=2, min_samples_split=5, n_estimators=100;, score=nan total time=   0.0s
# [CV 4/5] END max_depth=None, min_samples_leaf=2, min_samples_split=5, n_estimators=100;, score=nan total time=   0.0s
# [CV 5/5] END max_depth=None, min_samples_leaf=2, min_samples_split=5, n_estimators=100;, score=nan total time=   0.0s
# [CV 1/5] END max_depth=None, min_samples_leaf=2, min_samples_split=5, n_estimators=200;, score=nan total time=   0.0s
# [CV 2/5] END max_depth=None, min_samples_leaf=2, min_samples_split=5, n_estimators=200;, score=nan total time=   0.0s
# [CV 3/5] END max_depth=None, min_samples_leaf=2, min_samples_split=5, n_estimators=200;, score=nan total time=   0.0s
# [CV 4/5] END max_depth=None, min_samples_leaf=2, min_samples_split=5, n_estimators=200;, score=nan total time=   0.0s
# [CV 5/5] END max_depth=None, min_samples_leaf=2, min_samples_split=5, n_estimators=200;, score=nan total time=   0.0s
# [CV 1/5] END max_depth=10, min_samples_leaf=1, min_samples_split=2, n_estimators=100;, score=0.512 total time=   0.4s
# [CV 2/5] END max_depth=10, min_samples_leaf=1, min_samples_split=2, n_estimators=100;, score=0.505 total time=   0.2s
# [CV 3/5] END max_depth=10, min_samples_leaf=1, min_samples_split=2, n_estimators=100;, score=0.505 total time=   0.2s
# [CV 4/5] END max_depth=10, min_samples_leaf=1, min_samples_split=2, n_estimators=100;, score=0.507 total time=   0.2s
# [CV 5/5] END max_depth=10, min_samples_leaf=1, min_samples_split=2, n_estimators=100;, score=0.525 total time=   0.2s
# [CV 1/5] END max_depth=10, min_samples_leaf=1, min_samples_split=2, n_estimators=200;, score=0.501 total time=   0.4s
# [CV 2/5] END max_depth=10, min_samples_leaf=1, min_samples_split=2, n_estimators=200;, score=0.503 total time=   0.4s
# [CV 3/5] END max_depth=10, min_samples_leaf=1, min_samples_split=2, n_estimators=200;, score=0.507 total time=   0.4s
# [CV 4/5] END max_depth=10, min_samples_leaf=1, min_samples_split=2, n_estimators=200;, score=0.505 total time=   0.4s
# [CV 5/5] END max_depth=10, min_samples_leaf=1, min_samples_split=2, n_estimators=200;, score=0.516 total time=   0.4s
# [CV 1/5] END max_depth=10, min_samples_leaf=1, min_samples_split=5, n_estimators=100;, score=0.504 total time=   0.2s
# [CV 2/5] END max_depth=10, min_samples_leaf=1, min_samples_split=5, n_estimators=100;, score=0.511 total time=   0.2s
# [CV 3/5] END max_depth=10, min_samples_leaf=1, min_samples_split=5, n_estimators=100;, score=0.514 total time=   0.2s
# [CV 4/5] END max_depth=10, min_samples_leaf=1, min_samples_split=5, n_estimators=100;, score=0.504 total time=   0.2s
# [CV 5/5] END max_depth=10, min_samples_leaf=1, min_samples_split=5, n_estimators=100;, score=0.513 total time=   0.2s
# [CV 1/5] END max_depth=10, min_samples_leaf=1, min_samples_split=5, n_estimators=200;, score=0.507 total time=   0.4s
# [CV 2/5] END max_depth=10, min_samples_leaf=1, min_samples_split=5, n_estimators=200;, score=0.514 total time=   0.4s
# [CV 3/5] END max_depth=10, min_samples_leaf=1, min_samples_split=5, n_estimators=200;, score=0.508 total time=   0.4s
# [CV 4/5] END max_depth=10, min_samples_leaf=1, min_samples_split=5, n_estimators=200;, score=0.510 total time=   0.4s
# [CV 5/5] END max_depth=10, min_samples_leaf=1, min_samples_split=5, n_estimators=200;, score=0.511 total time=   0.4s
# [CV 1/5] END max_depth=10, min_samples_leaf=2, min_samples_split=2, n_estimators=100;, score=0.497 total time=   0.2s
# [CV 2/5] END max_depth=10, min_samples_leaf=2, min_samples_split=2, n_estimators=100;, score=0.502 total time=   0.2s
# [CV 3/5] END max_depth=10, min_samples_leaf=2, min_samples_split=2, n_estimators=100;, score=0.517 total time=   0.2s
# [CV 4/5] END max_depth=10, min_samples_leaf=2, min_samples_split=2, n_estimators=100;, score=0.506 total time=   0.2s
# [CV 5/5] END max_depth=10, min_samples_leaf=2, min_samples_split=2, n_estimators=100;, score=0.520 total time=   0.2s
# [CV 1/5] END max_depth=10, min_samples_leaf=2, min_samples_split=2, n_estimators=200;, score=0.502 total time=   0.4s
# [CV 2/5] END max_depth=10, min_samples_leaf=2, min_samples_split=2, n_estimators=200;, score=0.514 total time=   0.5s
# [CV 3/5] END max_depth=10, min_samples_leaf=2, min_samples_split=2, n_estimators=200;, score=0.509 total time=   0.5s
# [CV 4/5] END max_depth=10, min_samples_leaf=2, min_samples_split=2, n_estimators=200;, score=0.512 total time=   0.5s
# [CV 5/5] END max_depth=10, min_samples_leaf=2, min_samples_split=2, n_estimators=200;, score=0.521 total time=   0.5s
# [CV 1/5] END max_depth=10, min_samples_leaf=2, min_samples_split=5, n_estimators=100;, score=0.507 total time=   0.3s
# [CV 2/5] END max_depth=10, min_samples_leaf=2, min_samples_split=5, n_estimators=100;, score=0.511 total time=   0.2s
# [CV 3/5] END max_depth=10, min_samples_leaf=2, min_samples_split=5, n_estimators=100;, score=0.509 total time=   0.2s
# [CV 4/5] END max_depth=10, min_samples_leaf=2, min_samples_split=5, n_estimators=100;, score=0.508 total time=   0.3s
# [CV 5/5] END max_depth=10, min_samples_leaf=2, min_samples_split=5, n_estimators=100;, score=0.513 total time=   0.3s
# [CV 1/5] END max_depth=10, min_samples_leaf=2, min_samples_split=5, n_estimators=200;, score=0.500 total time=   0.4s
# [CV 2/5] END max_depth=10, min_samples_leaf=2, min_samples_split=5, n_estimators=200;, score=0.516 total time=   0.4s
# [CV 3/5] END max_depth=10, min_samples_leaf=2, min_samples_split=5, n_estimators=200;, score=0.509 total time=   0.4s
# [CV 4/5] END max_depth=10, min_samples_leaf=2, min_samples_split=5, n_estimators=200;, score=0.509 total time=   0.4s
# [CV 5/5] END max_depth=10, min_samples_leaf=2, min_samples_split=5, n_estimators=200;, score=0.510 total time=   0.4s
# [CV 1/5] END max_depth=20, min_samples_leaf=1, min_samples_split=2, n_estimators=100;, score=0.508 total time=   0.3s
# [CV 2/5] END max_depth=20, min_samples_leaf=1, min_samples_split=2, n_estimators=100;, score=0.502 total time=   0.3s
# [CV 3/5] END max_depth=20, min_samples_leaf=1, min_samples_split=2, n_estimators=100;, score=0.501 total time=   0.3s
# [CV 4/5] END max_depth=20, min_samples_leaf=1, min_samples_split=2, n_estimators=100;, score=0.497 total time=   0.3s
# [CV 5/5] END max_depth=20, min_samples_leaf=1, min_samples_split=2, n_estimators=100;, score=0.529 total time=   0.3s
# [CV 1/5] END max_depth=20, min_samples_leaf=1, min_samples_split=2, n_estimators=200;, score=0.504 total time=   0.7s
# [CV 2/5] END max_depth=20, min_samples_leaf=1, min_samples_split=2, n_estimators=200;, score=0.504 total time=   0.7s
# [CV 3/5] END max_depth=20, min_samples_leaf=1, min_samples_split=2, n_estimators=200;, score=0.499 total time=   0.6s
# [CV 4/5] END max_depth=20, min_samples_leaf=1, min_samples_split=2, n_estimators=200;, score=0.502 total time=   0.7s
# [CV 5/5] END max_depth=20, min_samples_leaf=1, min_samples_split=2, n_estimators=200;, score=0.530 total time=   0.6s
# [CV 1/5] END max_depth=20, min_samples_leaf=1, min_samples_split=5, n_estimators=100;, score=0.512 total time=   0.3s
# [CV 2/5] END max_depth=20, min_samples_leaf=1, min_samples_split=5, n_estimators=100;, score=0.514 total time=   0.3s
# [CV 3/5] END max_depth=20, min_samples_leaf=1, min_samples_split=5, n_estimators=100;, score=0.505 total time=   0.3s
# [CV 4/5] END max_depth=20, min_samples_leaf=1, min_samples_split=5, n_estimators=100;, score=0.501 total time=   0.3s
# [CV 5/5] END max_depth=20, min_samples_leaf=1, min_samples_split=5, n_estimators=100;, score=0.507 total time=   0.3s
# [CV 1/5] END max_depth=20, min_samples_leaf=1, min_samples_split=5, n_estimators=200;, score=0.498 total time=   0.6s
# [CV 2/5] END max_depth=20, min_samples_leaf=1, min_samples_split=5, n_estimators=200;, score=0.511 total time=   0.6s
# [CV 3/5] END max_depth=20, min_samples_leaf=1, min_samples_split=5, n_estimators=200;, score=0.507 total time=   0.8s
# [CV 4/5] END max_depth=20, min_samples_leaf=1, min_samples_split=5, n_estimators=200;, score=0.509 total time=   0.8s
# [CV 5/5] END max_depth=20, min_samples_leaf=1, min_samples_split=5, n_estimators=200;, score=0.515 total time=   0.8s
# [CV 1/5] END max_depth=20, min_samples_leaf=2, min_samples_split=2, n_estimators=100;, score=0.505 total time=   0.5s
# [CV 2/5] END max_depth=20, min_samples_leaf=2, min_samples_split=2, n_estimators=100;, score=0.505 total time=   0.4s
# [CV 3/5] END max_depth=20, min_samples_leaf=2, min_samples_split=2, n_estimators=100;, score=0.511 total time=   0.3s
# [CV 4/5] END max_depth=20, min_samples_leaf=2, min_samples_split=2, n_estimators=100;, score=0.505 total time=   0.3s
# [CV 5/5] END max_depth=20, min_samples_leaf=2, min_samples_split=2, n_estimators=100;, score=0.520 total time=   0.3s
# [CV 1/5] END max_depth=20, min_samples_leaf=2, min_samples_split=2, n_estimators=200;, score=0.489 total time=   0.7s
# [CV 2/5] END max_depth=20, min_samples_leaf=2, min_samples_split=2, n_estimators=200;, score=0.512 total time=   0.7s
# [CV 3/5] END max_depth=20, min_samples_leaf=2, min_samples_split=2, n_estimators=200;, score=0.502 total time=   0.7s
# [CV 4/5] END max_depth=20, min_samples_leaf=2, min_samples_split=2, n_estimators=200;, score=0.504 total time=   0.6s
# [CV 5/5] END max_depth=20, min_samples_leaf=2, min_samples_split=2, n_estimators=200;, score=0.520 total time=   0.6s
# [CV 1/5] END max_depth=20, min_samples_leaf=2, min_samples_split=5, n_estimators=100;, score=0.504 total time=   0.3s
# [CV 2/5] END max_depth=20, min_samples_leaf=2, min_samples_split=5, n_estimators=100;, score=0.512 total time=   0.3s
# [CV 3/5] END max_depth=20, min_samples_leaf=2, min_samples_split=5, n_estimators=100;, score=0.516 total time=   0.3s
# [CV 4/5] END max_depth=20, min_samples_leaf=2, min_samples_split=5, n_estimators=100;, score=0.507 total time=   0.3s
# [CV 5/5] END max_depth=20, min_samples_leaf=2, min_samples_split=5, n_estimators=100;, score=0.513 total time=   0.3s
# [CV 1/5] END max_depth=20, min_samples_leaf=2, min_samples_split=5, n_estimators=200;, score=0.499 total time=   0.6s
# [CV 2/5] END max_depth=20, min_samples_leaf=2, min_samples_split=5, n_estimators=200;, score=0.509 total time=   0.6s
# [CV 3/5] END max_depth=20, min_samples_leaf=2, min_samples_split=5, n_estimators=200;, score=0.514 total time=   0.6s
# [CV 4/5] END max_depth=20, min_samples_leaf=2, min_samples_split=5, n_estimators=200;, score=0.515 total time=   0.6s
# [CV 5/5] END max_depth=20, min_samples_leaf=2, min_samples_split=5, n_estimators=200;, score=0.528 total time=   0.6s
# /usr/local/lib/python3.11/dist-packages/sklearn/model_selection/_validation.py:528: FitFailedWarning:
# 40 fits failed out of a total of 120.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 40 fits failed with the following error:
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.11/dist-packages/sklearn/model_selection/_validation.py", line 866, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/usr/local/lib/python3.11/dist-packages/nvtx/nvtx.py", line 122, in inner
#     result = func(*args, **kwargs)
#              ^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/cuml/internals/api_decorators.py", line 193, in wrapper
#     ret = func(*args, **kwargs)
#           ^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/cuml/internals/api_decorators.py", line 416, in dispatch
#     return self.dispatch_func(func_name, gpu_func, *args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/cuml/internals/api_decorators.py", line 195, in wrapper
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "base.pyx", line 764, in cuml.internals.base.UniversalBase.dispatch_func
#   File "randomforestclassifier.pyx", line 493, in cuml.ensemble.randomforestclassifier.RandomForestClassifier.fit
# TypeError: an integer is required
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# /usr/local/lib/python3.11/dist-packages/sklearn/model_selection/_search.py:1108: UserWarning: One or more of the test scores are non-finite: [       nan        nan        nan        nan        nan        nan
#         nan        nan 0.51070311 0.5065625  0.50921874 0.50999999
#  0.50843751 0.51148436 0.50960938 0.50890625 0.50742188 0.50749999
#  0.5078125  0.50773438 0.50929686 0.50523437 0.51031251 0.51304687]
#   warnings.warn(
# cuml GridSearchCV training time (RF) : 33.72 seconds
# cuml Best parameters (RF): {'max_depth': 20, 'min_samples_leaf': 2, 'min_samples_split': 5, 'n_estimators': 200}
# scikit-learn GridSearchCV training time (RF) : 468.75 seconds
# scikit-learn Best parameters (RF): {'max_depth': None, 'min_samples_leaf': 1, 'min_samples_split': 5, 'n_estimators': 100}

# %% [markdown]
# # Prediction & Model Evaluation

# %%
from sklearn.metrics import accuracy_score, confusion_matrix, ConfusionMatrixDisplay
import matplotlib.pyplot as plt

# --- Comparison and Evaluation ---
model_names = list(sk_models.keys()) # Assuming cu_models will have the same keys if cuML is available

for model_name in model_names:
    print(f"--- Evaluating: {model_name} ---")

    # --- scikit-learn model ---
    if model_name in sk_models:
        print("\n-- scikit-learn --")
        best_sk_model = sk_models[model_name].best_estimator_

        # Predictions
        y_pred_train_sk = best_sk_model.predict(X_train)
        y_pred_test_sk = best_sk_model.predict(X_test)
        start_time = time.time()
        sk_pred[model_name] = best_sk_model.predict(X)
        end_time = time.time()
        sk_pred_times[model_name] = end_time - start_time
        print(f"Prediction Duration: {sk_pred_times[model_name]:.2f} seconds")

        # Accuracy
        train_accuracy_sk = accuracy_score(y_train, y_pred_train_sk)
        test_accuracy_sk = accuracy_score(y_test, y_pred_test_sk)
        sk_train_accuracy[model_name] = train_accuracy_sk
        sk_test_accuracy[model_name] = test_accuracy_sk
        print(f"Train Accuracy: {train_accuracy_sk:.4f}")
        print(f"Test Accuracy: {test_accuracy_sk:.4f}")

        # Cross-validation score
        cv_score_sk = sk_models[model_name].best_score_
        sk_crossValidation_accuracy[model_name] = cv_score_sk
        print(f"Best Cross-Validation Score: {cv_score_sk:.4f}")

        # Duration
        print(f"Training Duration: {sk_times[model_name]:.2f} seconds")

        # Confusion Matrix
        print("Confusion Matrix (Test Set):")
        cm_sk = confusion_matrix(y_test, y_pred_test_sk)
        disp_sk = ConfusionMatrixDisplay(confusion_matrix=cm_sk, display_labels=best_sk_model.classes_)
        disp_sk.plot()
        plt.title(f"scikit-learn {model_name} - Confusion Matrix")
        plt.show()


    # --- cuML model ---
    print("\n-- cuML --")
    if has_cuml and model_name in cu_models:
        best_cu_model = cu_models[model_name].best_estimator_

        # Predictions

        # Note: cuML predict might require cuDF DataFrame or NumPy array
        # Ensuring X_train and X_test are in a compatible format (e.g., NumPy)
        # If they are pandas DataFrames, cuML usually handles them, but explicit conversion can be safer.
        y_pred_train_cu = best_cu_model.predict(X_train.to_numpy() if hasattr(X_train, 'to_numpy') else X_train)
        y_pred_test_cu = best_cu_model.predict(X_test.to_numpy() if hasattr(X_test, 'to_numpy') else X_test)
        start_time = time.time()
        cu_pred[model_name] = best_cu_model.predict(X.to_numpy() if hasattr(X, 'to_numpy') else X)
        end_time = time.time()
        cu_pred_times[model_name] = end_time - start_time
        print(f"Prediction Duration: {cu_pred_times[model_name]:.2f} seconds")

        # If predictions are cuPy arrays, convert them to NumPy for scikit-learn metrics
        if hasattr(y_pred_train_cu, 'get'): # Check if it's a cuPy array
            y_pred_train_cu = y_pred_train_cu.get()
        if hasattr(y_pred_test_cu, 'get'): # Check if it's a cuPy array
            y_pred_test_cu = y_pred_test_cu.get()


        # Accuracy
        train_accuracy_cu = accuracy_score(y_train, y_pred_train_cu) # y_train is pandas Series, compatible
        test_accuracy_cu = accuracy_score(y_test, y_pred_test_cu)   # y_test is pandas Series, compatible
        cu_train_accuracy[model_name] = train_accuracy_cu
        cu_test_accuracy[model_name] = test_accuracy_cu
        print(f"Train Accuracy: {train_accuracy_cu:.4f}")
        print(f"Test Accuracy: {test_accuracy_cu:.4f}")

        # Cross-validation score
        cv_score_cu = cu_models[model_name].best_score_
        cu_crossValidation_accuracy[f"cu_{model_name}"] = cv_score_cu
        print(f"Best Cross-Validation Score: {cv_score_cu:.4f}")

        # Duration
        # if model_name in cu_times: # Check if cu_times was populated
        print(f"Training Duration: {cu_times[model_name]:.2f} seconds")

        # Confusion Matrix
        print("Confusion Matrix (Test Set):")
        cm_cu = confusion_matrix(y_test, y_pred_test_cu)
        # Ensure classes are correctly obtained for cuML model if different from sklearn
        # For SVC, .classes_ should be available after fitting.
        disp_cu = ConfusionMatrixDisplay(confusion_matrix=cm_cu, display_labels=best_cu_model.classes_)
        disp_cu.plot()
        plt.title(f"cuML {model_name} - Confusion Matrix")
        plt.show()
    else:
        print(f"cuML {model_name} was not run as cuML model for it is not available.")

    print("\n" + "="*40 + "\n")

print("\nSummary of Accuracies and Times:")
print("scikit-learn Train Accuracies:", sk_train_accuracy)
print("CuML Train Accuracies:", cu_train_accuracy)
print("scikit-learn Test Accuracies:", sk_test_accuracy)
print("CuML Test Accuracies:", cu_test_accuracy)
print("scikit-learn Cross-Validation Accuracies:", sk_crossValidation_accuracy)
print("CuML Cross-Validation Accuracies:", cu_crossValidation_accuracy)
print("scikit-learn Training Times:", sk_times)
print("cuML Training Times:", cu_times)
print("scikit-learn Prediction Times:", sk_pred_times)
print("cuML Prediction Times:", cu_pred_times)
# Out:
# --- Evaluating: SVM ---
#
# -- scikit-learn --
# Prediction Duration: 9.53 seconds
# Train Accuracy: 0.5873
# Test Accuracy: 0.5009
# Best Cross-Validation Score: 0.5121
# Training Duration: 173.83 seconds
# Confusion Matrix (Test Set):
# -- cuML --
# Prediction Duration: 0.08 seconds
# Train Accuracy: 0.5874
# Test Accuracy: 0.5009
# Best Cross-Validation Score: 0.5121
# Training Duration: 27.86 seconds
# Confusion Matrix (Test Set):
# ========================================
#
# --- Evaluating: KNN ---
#
# -- scikit-learn --
# Prediction Duration: 2.71 seconds
# Train Accuracy: 1.0000
# Test Accuracy: 0.4753
# Best Cross-Validation Score: 0.5109
# Training Duration: 33.77 seconds
# Confusion Matrix (Test Set):
# -- cuML --
# Prediction Duration: 0.04 seconds
# Train Accuracy: 0.6384
# Test Accuracy: 0.4781
# Best Cross-Validation Score: 0.5099
# Training Duration: 2.90 seconds
# Confusion Matrix (Test Set):
# ========================================
#
# --- Evaluating: RF ---
#
# -- scikit-learn --
# Prediction Duration: 0.26 seconds
# Train Accuracy: 1.0000
# Test Accuracy: 0.5072
# Best Cross-Validation Score: 0.5157
# Training Duration: 468.75 seconds
# Confusion Matrix (Test Set):
# -- cuML --
# Prediction Duration: 0.07 seconds
# Train Accuracy: 1.0000
# Test Accuracy: 0.4981
# Best Cross-Validation Score: 0.5130
# Training Duration: 33.72 seconds
# Confusion Matrix (Test Set):
# ========================================
#
#
# Summary of Accuracies and Times:
# scikit-learn Train Accuracies: {'SVM': 0.58734375, 'KNN': 1.0, 'RF': 1.0}
# CuML Train Accuracies: {'SVM': 0.587421875, 'KNN': 0.638359375, 'RF': 1.0}
# scikit-learn Test Accuracies: {'SVM': 0.5009375, 'KNN': 0.4753125, 'RF': 0.5071875}
# CuML Test Accuracies: {'SVM': 0.5009375, 'KNN': 0.478125, 'RF': 0.498125}
# scikit-learn Cross-Validation Accuracies: {'SVM': np.float64(0.512109375), 'KNN': np.float64(0.510859375), 'RF': np.float64(0.5157031249999999)}
# CuML Cross-Validation Accuracies: {'cu_SVM': np.float64(0.5121093630790711), 'cu_KNN': np.float64(0.5099218726158142), 'cu_RF': np.float64(0.5130468726158142)}
# scikit-learn Training Times: {'SVM': 173.83004879951477, 'KNN': 33.77407455444336, 'RF': 468.74550700187683}
# cuML Training Times: {'SVM': 27.861396551132202, 'KNN': 2.8978147506713867, 'RF': 33.71573281288147}
# scikit-learn Prediction Times: {'SVM': 9.53032660484314, 'KNN': 2.7131381034851074, 'RF': 0.2646033763885498}
# cuML Prediction Times: {'SVM': 0.08041071891784668, 'KNN': 0.03516387939453125, 'RF': 0.07242465019226074}

# %%
import matplotlib.pyplot as plt
import matplotlib.colors as mcolors
import pandas as pd

# Ensure all necessary variables are defined from previous cells:
# data, df, y, sk_pred, cu_pred, has_cuml (for cuML models)
# X (to get the index for aligning predictions if they are numpy arrays)

if 'DEPT' not in data.columns:
    print("Error: 'DEPT' column not found in data DataFrame. Cannot generate depth plots.")
else:
    depth_column = data['DEPT']
    feature_names = df.columns.tolist()

    # Prepare labels and predictions (same as before)
    true_labels = y
    all_predictions_to_plot = {}
    all_predictions_to_plot['True Labels'] = true_labels
    for model_name, preds in sk_pred.items():
        all_predictions_to_plot[f'SK: {model_name}'] = preds
    if has_cuml and cu_pred:
        for model_name, preds_cu in cu_pred.items():
            if hasattr(preds_cu, 'get'):
                preds_np = preds_cu.get()
            else:
                preds_np = preds_cu
            all_predictions_to_plot[f'CU: {model_name}'] = preds_np

    # Define colors for classes (same as before)
    if isinstance(true_labels, np.ndarray):
        unique_classes = np.sort(np.unique(true_labels))
    else:
        unique_classes = np.sort(true_labels.unique())

    if len(unique_classes) == 1:
        plot_colors = ['gold']
    elif len(unique_classes) == 2:
        plot_colors = ['gold', 'darkorange']
    else:
        cmap_tab10 = plt.cm.get_cmap('tab10', len(unique_classes))
        plot_colors = [mcolors.to_hex(cmap_tab10(i)) for i in range(len(unique_classes))]

    class_to_int = {cls: i for i, cls in enumerate(unique_classes)}
    cmap_listed = mcolors.ListedColormap(plot_colors[:len(unique_classes)])


    # --- Figure 1: feature Tracks ---
    num_feature_plots = len(feature_names)
    if num_feature_plots > 0:
        fig_features, axes_features = plt.subplots(1, num_feature_plots, figsize=(num_feature_plots * 2.5, 10), sharey=True)
        if num_feature_plots == 1: # Handle single feature case for axes indexing
            axes_features = [axes_features]
        fig_features.suptitle("Feature Tracks", fontsize=16, y=0.98)

        for i, feature_name in enumerate(feature_names):
            ax = axes_features[i]
            ax.plot(data[feature_name].loc[X.index], depth_column.loc[X.index])
            ax.set_title(feature_name, fontsize=10)
            ax.set_xlabel("Value", fontsize=8)
            if i == 0:
                ax.set_ylabel("DEPT (feet)", fontsize=10)
            ax.grid(True, linestyle='--', alpha=0.7)
            ax.tick_params(axis='x', labelsize=8)
            ax.tick_params(axis='y', labelsize=8)

        axes_features[0].invert_yaxis()
        plt.tight_layout(rect=[0, 0.03, 1, 0.95])
        plt.show()
    else:
        print("No features to plot for feature tracks.")

    # --- Figure 2: scaled feature Tracks ---
    num_feature_plots = len(feature_names)
    if num_feature_plots > 0:
        fig_features, axes_features = plt.subplots(1, num_feature_plots, figsize=(num_feature_plots * 2.5, 10), sharey=True)
        if num_feature_plots == 1: # Handle single feature case for axes indexing
            axes_features = [axes_features]
        fig_features.suptitle("Scaled Feature Tracks", fontsize=16, y=0.98)

        for i, feature_name in enumerate(feature_names):
            ax = axes_features[i]
            ax.plot(X[feature_name].loc[X.index], depth_column.loc[X.index])
            ax.set_title(feature_name, fontsize=10)
            ax.set_xlabel("Value", fontsize=8)
            if i == 0:
                ax.set_ylabel("DEPT (feet)", fontsize=10)
            ax.grid(True, linestyle='--', alpha=0.7)
            ax.tick_params(axis='x', labelsize=8)
            ax.tick_params(axis='y', labelsize=8)

        axes_features[0].invert_yaxis()
        plt.tight_layout(rect=[0, 0.03, 1, 0.95])
        plt.show()
    else:
        print("No features to plot for scaled feature tracks.")

    # --- Figure 3: Classification Tracks ---
    num_classification_plots = len(all_predictions_to_plot)
    if num_classification_plots > 0:
        # Adjust figsize: width per plot can be smaller for classification tracks
        fig_class, axes_class = plt.subplots(1, num_classification_plots, figsize=(num_classification_plots * 1.2, 10), sharey=True)
        if num_classification_plots == 1: # Handle single classification plot case
            axes_class = [axes_class]
        fig_class.suptitle("Classification Tracks", fontsize=16, y=0.98)

        plot_order = ['True Labels'] + [k for k in all_predictions_to_plot.keys() if k != 'True Labels']

        for i, title in enumerate(plot_order):
            predictions_data = all_predictions_to_plot[title]
            ax = axes_class[i]

            if isinstance(predictions_data, pd.Series):
                if not predictions_data.index.equals(X.index):
                    # This should ideally not happen with consistent data handling
                    # For safety, one might reindex or ensure alignment upstream
                    print(f"Warning: Index mismatch for {title}. Plotting may be incorrect.")
                mapped_preds = predictions_data.map(class_to_int).fillna(-1)
            elif isinstance(predictions_data, np.ndarray):
                temp_series = pd.Series(predictions_data, index=X.index)
                mapped_preds = temp_series.map(class_to_int).fillna(-1)
            else:
                print(f"Warning: Data for {title} is of unexpected type: {type(predictions_data)}")
                continue

            labels_int = mapped_preds.values.reshape(-1, 1)
            vmin = 0
            vmax = len(plot_colors) - 1

            ax.imshow(labels_int, aspect='auto', cmap=cmap_listed,
                      extent=[0, 1, depth_column.loc[X.index].max(), depth_column.loc[X.index].min()],
                      interpolation='none', vmin=vmin, vmax=vmax)

            if title == 'True Labels':
                ax.set_title("True Class", fontsize=10)
            else:
                ax.set_title(title, fontsize=10)

            ax.set_xticks([])
            ax.set_xlabel("")
            ax.tick_params(axis='y', labelsize=8)
            if i == 0: # Set Y-axis label only for the first plot in this figure
                ax.set_ylabel("DEPT (feet)", fontsize=10)


        axes_class[0].invert_yaxis()

        if unique_classes is not None and len(unique_classes) > 0:
            patches = [plt.Rectangle((0,0),1,1, color=plot_colors[class_to_int[cls]]) for cls in unique_classes]
            legend_labels = [str(cls) for cls in unique_classes]
            fig_class.legend(patches, legend_labels, loc='lower center', ncol=len(unique_classes), bbox_to_anchor=(0.5, -0.02), title="Classes")

        plt.tight_layout(rect=[0, 0.03, 1, 0.93])
        plt.show()
    else:
        print("No classification data to plot.")

# %% [markdown]
# # Shutdown colab runtime

# %%
# Execution time
end_notebook = time.time()
print(f"Total notebook execution time: {end_notebook - start_notebook:.2f} seconds")
# Out:
# Total notebook execution time: 784.54 seconds

# %%
if is_running_on_colab:
    from google.colab import runtime
    runtime.unassign()
